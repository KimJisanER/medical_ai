# %% [markdown]
# <a href="https://colab.research.google.com/github/KimJisanER/medical_ai/blob/main/KOHI_221001_%EC%8B%A4%EC%8A%B5%EC%BD%94%EB%93%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #KOHI 2022 10/1 실습 코드
# ## 실습 내용
#
#
# *   데이터 클랜징 및 Cohort 분석
#   * 데이터 클랜징 - 이상값 제거, Outlier 처리
#   * Cohort 분석 - 연령대별 통계분석, 성별에 따른 통계분석, ICU Type에 따른 통계분석
# *   데이터 레이블링 및 학습 데이터 생성
#   * 데이터 레이블링 - 사망, 저혈압
#   * 시계열 형태의 학습 데이터 만들기

# %% [markdown]
# # 데이터 클랜징 - 이상값 제거, Outlier 처리

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# Data Download
FILE_IDS = ["1-91Ad_3yQQ0T6ROnlxqbbgEFc6tiZAsY",
            "1-RbUxW2hF2ayWDhkMqGfKZvzEKwiLqQX",
            "1r76_XuYikaeswLAIpIbPpkx_kXgJob3a",
            "1-I25PxwI6qpDrNtDJD_jEnLl_MXh9hjH",
            "1-3YZEp8xFYplMjvFSfzb637WwA8OwW_2",
            "1-HhOwcDMse4BevovRkxOBICe5zZ3YraZ",
            "1GO4MIIzgNOB8zDvtgldU5JdLZbMlnczz"]
FILE_NAMES = ['PATIENTS.csv', 'LABEVENTS.csv', 'CHARTEVENTS.csv',
              'D_ITEMS.csv', 'D_LABITEMS.csv', 'ADMISSIONS.csv', 'ICUSTAYS.csv']
for f_id, f_name in tqdm(zip(FILE_IDS, FILE_NAMES), desc="Download Files...", total=len(FILE_IDS), ncols=75):
  download_file = drive.CreateFile({'id': f_id})
  download_file.GetContentFile(f_name)
# Out:
# Download Files...: 100%|█████████████████████| 7/7 [00:23<00:00,  3.38s/it]

# %%
import os
import csv
import numpy as np
import pandas as pd
from datetime import datetime, timedelta

#ITEMID for MIMIC-III
VITAL_SIGNS = {'PULSE': ['220045', '211'],
               'RESP': ['220210', '618'],
               'SBP': ['220050', '220179', '225309', '51', '455'],
               'DBP': ['220051', '220180', '225310', '8368', '8441'],
               'FiO2': ['223835', '189', '190'],
               'MAP': ['220052', '1321', '438']
               }
LABS = {'BILIRUBIN': ['50885'],
        'LACTATE': ['50813'],
        'pH': ['50820', '50831'],
        'SODIUM': ['50983'],
        'POTASSIUM': ['50971'],
        'CREATININE': ['50912'],
        'WBC': ['51301'],
        'HEMATOCRIT': ['51221']
        }
ITEM_IDS = {
    '220045': 'PULSE', 
    '211': 'PULSE',
    '220210': 'RESP', 
    '618': 'RESP',
    '220050': 'SBP',
    '220179': 'SBP',
    '225309': 'SBP',
    '51': 'SBP',
    '455': 'SBP',
    '220051': 'DBP',
    '220180': 'DBP',
    '225310': 'DBP',
    '8368': 'DBP',
    '8441': 'DBP',
    '223835': 'FiO2',
    '189': 'FiO2',
    '190': 'FiO2',
    '220052': 'MAP',
    '1321': 'MAP',
    '438': 'MAP',
    '50885': 'BILIRUBIN',
    '50813': 'LACTATE',
    '50820': 'pH',
    '50831': 'pH',
    '50983': 'SODIUM',
    '50971': 'POTASSIUM',
    '50912': 'CREATININE',
    '51301': 'WBC',
    '51221': 'HEMATOCRIT'
}

# %%
# Load Chartevents and Labevents Table
CHARTEVENTS = pd.read_csv('CHARTEVENTS.csv', low_memory=False, dtype='str', keep_default_na=False) #string 형식으로 통일해서 불러옴 , #null 빈 문자열 형식으로 불러옴
LABEVENTS = pd.read_csv('LABEVENTS.csv', low_memory=False, dtype='str', keep_default_na=False)

# %%
# Make Checking float value function
def is_float(value):
  try:
    float(value)
    return True
  except:
    return False

# %%
# Get Only float values for VitalSign
float_VS = CHARTEVENTS[CHARTEVENTS['VALUENUM'].apply(lambda x: is_float(x))].reset_index()
float_VS
# Out:
#            index     ROW_ID SUBJECT_ID HADM_ID ICUSTAY_ID  ITEMID  \
# 0              0     147286       1257  160336     237955  220734
# 1              1     147287       1257  160336     237955  227471
# 2              2     147288       1257  160336     237955  223834
# 3              3     147289       1257  160336     237955  223835
# 4              4     147290       1257  160336     237955  220179
# ...          ...        ...        ...     ...        ...     ...
# 3100999  7241337  329919200      99312  150103     293902  224055
# 3101000  7241338  329919201      99312  150103     293902  224056
# 3101001  7241339  329919202      99312  150103     293902  224057
# 3101002  7241340  329919203      99312  150103     293902  224058
# 3101003  7241341  329919204      99312  150103     293902  224059
#
#                    CHARTTIME            STORETIME   CGID                VALUE  \
# 0        2196-11-21 12:27:00  2196-11-21 13:43:00  20889                    6
# 1        2196-11-21 12:27:00  2196-11-21 13:19:00  20889                 1.01
# 2        2196-11-21 13:00:00  2196-11-21 15:21:00  15652                   10
# 3        2196-11-21 13:00:00  2196-11-21 15:21:00  15652                  100
# 4        2196-11-21 13:21:00  2196-11-21 13:25:00  15652                  139
# ...                      ...                  ...    ...                  ...
# 3100999  2157-05-07 08:04:00  2157-05-07 09:05:00  17250   Occasionally Moist
# 3101000  2157-05-07 08:04:00  2157-05-07 09:05:00  17250              Bedfast
# 3101001  2157-05-07 08:04:00  2157-05-07 09:05:00  17250  Completely Immobile
# 3101002  2157-05-07 08:04:00  2157-05-07 09:05:00  17250  Probably Inadequate
# 3101003  2157-05-07 08:04:00  2157-05-07 09:05:00  17250              Problem
#
#         VALUENUM VALUEUOM WARNING ERROR RESULTSTATUS STOPPED
# 0              6    units       0     0
# 1           1.01                0     0
# 2             10    L/min       0     0
# 3            100                0     0
# 4            139     mmHg       0     0
# ...          ...      ...     ...   ...          ...     ...
# 3100999        3                0     0
# 3101000        1                0     0
# 3101001        1                0     0
# 3101002        2                0     0
# 3101003        1                0     0
#
# [3101004 rows x 16 columns]

# %%
# Get Only float values for Lab
float_LAB = LABEVENTS[LABEVENTS['VALUENUM'].apply(lambda x: is_float(x))].reset_index()
float_LAB
# Out:
#          index    ROW_ID SUBJECT_ID HADM_ID ITEMID            CHARTTIME VALUE  \
# 0            0     24146         55          51248  2138-05-28 18:14:00  27.0
# 1            1     24147         55          51249  2138-05-28 18:14:00  33.0
# 2            2     24148         55          51250  2138-05-28 18:14:00    82
# 3            3     24149         55          51254  2138-05-28 18:14:00   4.5
# 4            4     24150         55          51256  2138-05-28 18:14:00  66.7
# ...        ...       ...        ...     ...    ...                  ...   ...
# 550936  615323  27799406      99231  102589  51275  2149-11-12 12:02:00  29.0
# 550937  615324  27799407      99231  102589  50861  2149-11-13 09:53:00    21
# 550938  615325  27799408      99231  102589  50863  2149-11-13 09:53:00    59
# 550939  615326  27799409      99231  102589  50868  2149-11-13 09:53:00    11
# 550940  615327  27799410      99231  102589  50878  2149-11-13 09:53:00    17
#
#        VALUENUM VALUEUOM FLAG
# 0            27       pg
# 1            33        %
# 2            82       fL
# 3           4.5        %
# 4          66.7        %
# ...         ...      ...  ...
# 550936       29      sec
# 550937       21     IU/L
# 550938       59     IU/L
# 550939       11    mEq/L
# 550940       17     IU/L
#
# [550941 rows x 10 columns]

# %%
# Print examples of non-float values for VitalSign and Lab
nonfloat_VS = CHARTEVENTS[CHARTEVENTS['VALUENUM'].apply(lambda x: not is_float(x))].reset_index()
print(nonfloat_VS.head(5))

nonfloat_LAB = LABEVENTS[LABEVENTS['VALUENUM'].apply(lambda x: not is_float(x))].reset_index()
print(nonfloat_LAB.head(5))
# Out:
#     index    ROW_ID SUBJECT_ID HADM_ID ICUSTAY_ID ITEMID            CHARTTIME  \
# 0  615352  34514448         87  190659     277633   3519  2191-03-17 00:30:00
# 1  615355  34514451         87  190659     277633   3559  2191-03-17 00:30:00
# 2  615356  34514452         87  190659     277633   3568  2191-03-17 00:30:00
# 3  615357  34514453         87  190659     277633   3572  2191-03-17 00:30:00
# 4  615363  34514459         87  190659     277633   3607  2191-03-17 00:30:00
#
#              STORETIME   CGID        VALUE VALUENUM VALUEUOM WARNING ERROR  \
# 0  2191-03-17 01:24:00  20296  Symmetrical
# 1  2191-03-17 01:24:00  20296         None
# 2  2191-03-17 01:24:00  20296       Normal
# 3  2191-03-17 01:24:00  20296       Stable
# 4  2191-03-17 01:24:00  20296    Subcostal
#
#   RESULTSTATUS   STOPPED
# 0               NotStopd
# 1               NotStopd
# 2               NotStopd
# 3               NotStopd
# 4               NotStopd
#    index ROW_ID SUBJECT_ID HADM_ID ITEMID            CHARTTIME    VALUE  \
# 0     16  24162         55          50911  2138-05-29 05:50:00  NotDone
# 1     23  24169         55          51003  2138-05-29 05:50:00    <0.01
# 2     34  24180         55          51464  2138-05-31 03:00:00      NEG
# 3     35  24181         55          51466  2138-05-31 03:00:00      NEG
# 4     36  24182         55          51478  2138-05-31 03:00:00      NEG
#
#   VALUENUM VALUEUOM FLAG
# 0             ng/mL
# 1             ng/mL
# 2             mg/dL
# 3
# 4             mg/dL

# %%
# Get input features only
INPUT_ITEMIDS = list()
for kk, vv in VITAL_SIGNS.items():
  INPUT_ITEMIDS += vv
for kk, vv in LABS.items():
  INPUT_ITEMIDS += vv

INPUT_ITEMIDS = set(INPUT_ITEMIDS)
print(INPUT_ITEMIDS)

input_VS = float_VS[float_VS['ITEMID'].isin(INPUT_ITEMIDS)].reset_index()
input_LAB = float_LAB[float_LAB['ITEMID'].isin(INPUT_ITEMIDS)].reset_index()

print(input_VS)
print(input_LAB)
# Out:
# {'220051', '50971', '1321', '220180', '220052', '220210', '220050', '220179', '50885', '50983', '220045', '225310', '8368', '211', '455', '223835', '51221', '438', '50813', '8441', '50912', '225309', '51', '618', '189', '50820', '190', '50831', '51301'}
#         level_0    index     ROW_ID SUBJECT_ID HADM_ID ICUSTAY_ID  ITEMID  \
# 0             3        3     147289       1257  160336     237955  223835
# 1             4        4     147290       1257  160336     237955  220179
# 2             5        5     147291       1257  160336     237955  220180
# 3             7        7     147293       1257  160336     237955  220210
# 4             8        8     147294       1257  160336     237955  220045
# ...         ...      ...        ...        ...     ...        ...     ...
# 603541  2806811  5569641  255155407      32292  196589     241669    8441
# 603542  2806816  5569650  255155416      32292  196589     241669    8441
# 603543  2806821  5569655  255155421      32292  196589     241669    8441
# 603544  2806826  5569660  255155426      32292  196589     241669    8441
# 603545  2806835  5569671  255155437      32292  196589     241669    8441
#
#                   CHARTTIME            STORETIME   CGID VALUE VALUENUM  \
# 0       2196-11-21 13:00:00  2196-11-21 15:21:00  15652   100      100
# 1       2196-11-21 13:21:00  2196-11-21 13:25:00  15652   139      139
# 2       2196-11-21 13:21:00  2196-11-21 13:25:00  15652    71       71
# 3       2196-11-21 13:22:00  2196-11-21 13:25:00  15652    23       23
# 4       2196-11-21 13:23:00  2196-11-21 13:25:00  15652   123      123
# ...                     ...                  ...    ...   ...      ...
# 603541  2145-03-05 08:00:00  2145-03-05 07:38:00  19689    38       38
# 603542  2145-03-05 09:00:00  2145-03-05 08:49:00  19689    37       37
# 603543  2145-03-05 10:00:00  2145-03-05 10:57:00  19689    30       30
# 603544  2145-03-05 11:00:00  2145-03-05 10:57:00  19689    29       29
# 603545  2145-03-05 13:00:00  2145-03-05 13:25:00  19689    25       25
#
#         VALUEUOM WARNING ERROR RESULTSTATUS   STOPPED
# 0                      0     0
# 1           mmHg       0     0
# 2           mmHg       0     0
# 3       insp/min       0     0
# 4            bpm       0     0
# ...          ...     ...   ...          ...       ...
# 603541      mmHg                             NotStopd
# 603542      mmHg                             NotStopd
# 603543      mmHg                             NotStopd
# 603544      mmHg                             NotStopd
# 603545      mmHg                             NotStopd
#
# [603546 rows x 17 columns]
#         level_0   index    ROW_ID SUBJECT_ID HADM_ID ITEMID  \
# 0             8       8     24154         55          51301
# 1             9       9     24155         55          50813
# 2            16      17     24163         55          50912
# 3            20      21     24167         55          50971
# 4            21      22     24168         55          50983
# ...         ...     ...       ...        ...     ...    ...
# 110731   550918  615304  27798277      99231  168976  51301
# 110732   550926  615313  27798286      99231  168976  50912
# 110733   550930  615317  27798290      99231  168976  50971
# 110734   550931  615318  27798291      99231  168976  50983
# 110735   550933  615320  27799403      99231  102589  51301
#
#                   CHARTTIME VALUE VALUENUM VALUEUOM      FLAG
# 0       2138-05-28 18:14:00  10.3     10.3     K/uL
# 1       2138-05-28 18:19:00   2.0        2   mmol/L
# 2       2138-05-29 05:50:00   0.9       .9    mg/dL
# 3       2138-05-29 05:50:00   4.1      4.1    mEq/L
# 4       2138-05-29 05:50:00   143      143    mEq/L
# ...                     ...   ...      ...      ...       ...
# 110731  2149-08-04 21:59:00   2.9      2.9     K/uL  abnormal
# 110732  2149-08-05 03:53:00   7.3      7.3    mg/dL  abnormal
# 110733  2149-08-05 03:53:00   4.2      4.2    mEq/L
# 110734  2149-08-05 03:53:00   140      140    mEq/L
# 110735  2149-11-12 05:10:00   2.9      2.9     K/uL  abnormal
#
# [110736 rows x 11 columns]

# %% [markdown]
# ### Outlier 제거 실습
#
#
# 1.   정상 범위를 이용한 Outlier 제거
# 2.   IQR를 이용한 Outlier 제거

# %%
# 정상범위를 이용한 Outlier 제거
# Feature별 정상범위 설정
feature_range = dict({
    'AGE': (18, 90),
    'PULSE': (0, 300),
    'RESP': (0, 120),
    'SBP': (0, 300),
    'DBP': (0, 300),
    'MAP': (0, 300),
    'FiO2': (0, 100),
    'BILIRUBIN': (0, 75),
    'LACTATE': (0, 20),
    'SODIUM': (0, 500),
    'POTASSIUM': (0, 15),
    'CREATININE': (0, 20),
    'HEMATOCRIT': (0, 100),
    'WBC': (0, 100),
    'pH': (0, 14),
  })

# %%
# Make function that checking normal range for each value
def is_in_range(value_ranges, feature_key, feature_value):
  if feature_key not in value_ranges:
      raise AssertionError(feature_key)
  value_min, value_max = value_ranges[feature_key]
  return value_min <= feature_value <= value_max

# %%
invalid_input_vs = list()
invalid_input_lab = list()

for (idx, row) in tqdm(input_VS.iterrows(), desc='Filtering VS'):
  itemID = row['ITEMID']
  feature_name = ITEM_IDS[itemID]
  feature_value = float(row['VALUENUM'])
  if is_in_range(feature_range, feature_name, feature_value):
    continue
  else:
    invalid_input_vs.append(idx)

for (idx, row) in tqdm(input_LAB.iterrows(), desc='Filtering LAB'):
  itemID = row['ITEMID']
  feature_name = ITEM_IDS[itemID]
  feature_value = float(row['VALUENUM'])
  if is_in_range(feature_range, feature_name, feature_value):
    continue
  else:
    invalid_input_lab.append(idx)
# Out:
# Filtering VS: 603546it [00:50, 12039.08it/s]
# Filtering LAB: 110736it [00:09, 12237.75it/s]

# %%
print(len(invalid_input_vs))
print(len(input_VS))
valid_input_VS = input_VS.drop(input_VS.index[invalid_input_vs])
print(len(valid_input_VS))

print(len(invalid_input_lab))
print(len(input_LAB))
valid_input_LAB = input_LAB.drop(input_LAB.index[invalid_input_lab])
print(len(valid_input_LAB))
# Out:
# 136
# 603546
# 603410
# 22
# 110736
# 110714

# %% [markdown]
# 여기까지 진행을 했고 그다음에 이 밑에 내용은 이제 이것도 이제 나중에 뒤에서 실습을 진행하는 데 좀 편리하게 하기 위해서 진행하는 부분이라고 보시면 되겠는데요 바이탈 사인이랑 이벤트를 그러니까 전체 테이블을 다 가지고 나중에 환자 단위로 그 값을 가지고 오고 하다 보면 이게
# 시간이 오래 걸리는 문제가 있어서 그 전에 앞서서 각 hadm id를 기준으로 내원 번호를 기준으로 해당 내원번호를 갖는 바이탈 사인 랩만 따로 따로 추출해서 더 작은 단위의 테이블로 미리 변환을 해놓는 부분이라고 보시면 될 것 같습니다 그래서 어드미션 테이블로부터 hadm id 전체를 가지고 오고
# 매번 전체 테이블을 다 서칭 할 필요가 없이 그 해당 내원번호를 갖는 테이블만 서칭을 하면 돼서 속도가 훨씬 빨라지고요 그리고 나중에는 이렇게 데이터들을 만들어 놓으시면 hadm id를 기준으로 해서 그냥 멀티프로세싱을 돌려서 동시에 여러 hadm id에 대해서 그냥 다 처리를 할 수 있어요

# %%
# split features by hadm_id
hadm_VS = dict()
hadm_LAB = dict()

admissions = pd.read_csv('ADMISSIONS.csv', low_memory=False, dtype='str', keep_default_na=False)
hadm_ids = admissions['HADM_ID'].values

for hadm_id in tqdm(hadm_ids, desc='Split Features by HADM_ID'):
  vs = valid_input_VS[valid_input_VS['HADM_ID'] == hadm_id]
  lab = valid_input_LAB[valid_input_LAB['HADM_ID'] == hadm_id]

  hadm_VS[hadm_id] = vs
  hadm_LAB[hadm_id] = lab


  #해당 hadm id만 불러올 수 있어 여러모로 편리한 방법
# Out:
# Split Features by HADM_ID: 100%|██████████| 1262/1262 [01:21<00:00, 15.58it/s]

# %%
# IQR을 이용한 Outlier 제거
# Feautre별로 IQR 구하기, Box Plot 그려보기
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline #colab 안에서 plot을 표시해주기 위한 line

# %%
fig1, ax1 = plt.subplots()
sns.boxplot(data = float_VS[float_VS['ITEMID'].isin(VITAL_SIGNS['PULSE'])]['VALUENUM'].values, ax=ax1, orient='h') #orient h 삭제하면 세로로 그려짐

# %%
fig1, ax1 = plt.subplots()
sns.boxplot(data = float_VS[float_VS['ITEMID'].isin(VITAL_SIGNS['FiO2'])]['VALUENUM'].values, ax=ax1, orient='h') #orient h 삭제하면 세로로 그려짐

# %%
fig1, ax1 = plt.subplots()
sns.boxplot(data = float_LAB[float_LAB['ITEMID'].isin(LABS['WBC'])]['VALUENUM'].values, ax=ax1, orient='h') #orient h 삭제하면 세로로 그려짐

# %%
def get_min_max_iqr(values):
  q1 = np.quantile(values, 0.25)
  q3 = np.quantile(values, 0.75)
  iqr = q3 - q1
  min = q1 - (1.5 * iqr)
  max = q3 + (1.5 * iqr)
  return min, max

# %%
#IQR을 이용한 Feature별 Range 구하기
def make_feature_range_iqr(feature_range, values, feature_name):
  min, max = get_min_max_iqr(values)
  feature_range[feature_name] = (min, max)
  return feature_range

feature_names = list(VITAL_SIGNS.keys()) + list(LABS.keys())
feature_range = dict()

for feature_name in feature_names:
  if feature_name in VITAL_SIGNS:
    values = float_VS[float_VS['ITEMID'].isin(VITAL_SIGNS[feature_name])]['VALUENUM'].values
  elif feature_name in LABS:
    values = float_LAB[float_LAB['ITEMID'].isin(LABS[feature_name])]['VALUENUM'].values
  
  values = values.astype('float32')
  feature_range = make_feature_range_iqr(feature_range, values, feature_name)

feature_range
# Out:
# {'PULSE': (23.5, 171.5),
#  'RESP': (4.0, 36.0),
#  'SBP': (54.5, 186.5),
#  'DBP': (21.5, 97.5),
#  'FiO2': (-58.99999998509884, 99.3999999910593),
#  'MAP': (37.5, 121.5),
#  'BILIRUBIN': (-3.0500000566244125, 6.150000110268593),
#  'LACTATE': (-1.1999998092651367, 5.199999809265137),
#  'pH': (7.164999723434448, 7.605000257492065),
#  'SODIUM': (127.0, 151.0),
#  'POTASSIUM': (2.649999976158142, 5.450000166893005),
#  'CREATININE': (-0.6500000655651093, 2.950000077486038),
#  'WBC': (-3.049999475479126, 22.149999380111694),
#  'HEMATOCRIT': (17.2375009059906, 44.537498235702515)}

# %%
def is_in_range_iqr(value_ranges, feature_key, feature_value):
  if feature_key not in value_ranges:
      raise AssertionError(feature_key)
  value_min, value_max = value_ranges[feature_key]
  return value_min <= feature_value <= value_max

# %% [markdown]
# # 정규식 실습

# %%
import re

sample_txt = "Hello everyone, this is practical session for KOHI2022. 2022-10-01"

print("[a-z]:", re.findall("[a-z]", sample_txt))
print("[a-z]+:", re.findall("[a-z]+", sample_txt))
print("[0-9]:", re.findall("[0-9]", sample_txt))
print("[0-9]+:", re.findall("[0-9]+", sample_txt))
print("[A-Z]:", re.findall("[A-Z]", sample_txt))
print("[a-zA-Z]+:", re.findall("[a-zA-Z]+", sample_txt))
print("[\w]+:", re.findall("[\w]+", sample_txt))
print("[\d]+:", re.findall("[\d]+", sample_txt))

## Checking valid e-mail address
# def email_checking(email):
#   try:
#     if re.findall(r'[\w.-]+@[\w.-]+.\w+', email)[0] != email:
#       print('{}: It is not a valid E-mail address'.format(email))
#       return
#   except:
#       print('{}: It is not a valid E-mail address'.format(email))
#       return
#   print('{}: It is a valid E-mail address'.format(email))


def number_checking(number):
  try:
    if re.findall(r'^\d{3}-^\d{4}-^\d{4}', number)[0] != number:
      print('{}: It is not a valid number'.format(number))
      return
  except:
      print('{}: It is not a valid valid number'.format(number))
      return
  print('{}: It is a valid number'.format(number))



number_checking('010-8681-0000')
# Out:
# [a-z]: ['e', 'l', 'l', 'o', 'e', 'v', 'e', 'r', 'y', 'o', 'n', 'e', 't', 'h', 'i', 's', 'i', 's', 'p', 'r', 'a', 'c', 't', 'i', 'c', 'a', 'l', 's', 'e', 's', 's', 'i', 'o', 'n', 'f', 'o', 'r']
# [a-z]+: ['ello', 'everyone', 'this', 'is', 'practical', 'session', 'for']
# [0-9]: ['2', '0', '2', '2', '2', '0', '2', '2', '1', '0', '0', '1']
# [0-9]+: ['2022', '2022', '10', '01']
# [A-Z]: ['H', 'K', 'O', 'H', 'I']
# [a-zA-Z]+: ['Hello', 'everyone', 'this', 'is', 'practical', 'session', 'for', 'KOHI']
# [\w]+: ['Hello', 'everyone', 'this', 'is', 'practical', 'session', 'for', 'KOHI2022', '2022', '10', '01']
# [\d]+: ['2022', '2022', '10', '01']
# 010-8681-0000: It is not a valid valid number

# %%
def is_float_regex(value):
  try:
    float(re.findall("\d+\.\d+|\d+", value)[0])
    return False
  except:
    return True

# %% [markdown]
# # Cohort 분석
# ## - Cohort 정의 & Patients Flow chart
# ## - Cohort 별 데이터 통계 작성

# %%
import pandas as pd
admissions = pd.read_csv('ADMISSIONS.csv')
print(admissions.head(5))
patients = pd.read_csv('PATIENTS.csv')
print(patients.head(5))
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0      54          55   190665  2136-04-03 18:35:00  2136-04-05 14:30:00
# 1      83          82   110641  2150-06-24 23:31:00  2150-06-29 15:00:00
# 2      90          87   190659  2191-02-25 20:30:00  2191-04-25 15:18:00
# 3     198         148   199488  2107-09-05 14:58:00  2107-10-08 13:35:00
# 4     630         505   116719  2154-03-30 14:59:00  2154-04-01 16:00:00
#
#   DEATHTIME ADMISSION_TYPE         ADMISSION_LOCATION   DISCHARGE_LOCATION  \
# 0       NaN      EMERGENCY  CLINIC REFERRAL/PREMATURE                 HOME
# 1       NaN        NEWBORN  PHYS REFERRAL/NORMAL DELI                 HOME
# 2       NaN        NEWBORN  PHYS REFERRAL/NORMAL DELI  SHORT TERM HOSPITAL
# 3       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM                  SNF
# 4       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM     HOME HEALTH CARE
#
#   INSURANCE LANGUAGE      RELIGION MARITAL_STATUS              ETHNICITY  \
# 0  Medicare     ENGL      CATHOLIC        MARRIED                  WHITE
# 1   Private      NaN  UNOBTAINABLE            NaN                  OTHER
# 2   Private      NaN  UNOBTAINABLE            NaN  UNKNOWN/NOT SPECIFIED
# 3  Medicare      NaN  UNOBTAINABLE            NaN  UNKNOWN/NOT SPECIFIED
# 4   Private     ENGL      CATHOLIC        MARRIED                  WHITE
#
#   EDREGTIME EDOUTTIME                                         DIAGNOSIS  \
# 0       NaN       NaN                CAROTID STENOSIS\CAROTID ANGIOGRAM
# 1       NaN       NaN                                           NEWBORN
# 2       NaN       NaN                                           NEWBORN
# 3       NaN       NaN                           THROMBOCYTOPENIA;ANEMIA
# 4       NaN       NaN  ACUTE MENTAL STATUS CHANGES/RESPIRATORY DISTRESS
#
#    HOSPITAL_EXPIRE_FLAG  HAS_CHARTEVENTS_DATA
# 0                     0                     1
# 1                     0                     1
# 2                     0                     1
# 3                     0                     1
# 4                     0                     1
#    ROW_ID  SUBJECT_ID GENDER                  DOB                  DOD  \
# 0   42961       86381      F  2126-01-03 00:00:00                  NaN
# 1   35892       59198      M  2135-12-13 00:00:00                  NaN
# 2   42871       85987      M  2104-11-18 00:00:00                  NaN
# 3   17821       18862      M  2073-02-23 00:00:00                  NaN
# 4   19714       20896      M  2036-07-19 00:00:00  2113-10-18 00:00:00
#
#   DOD_HOSP              DOD_SSN  EXPIRE_FLAG
# 0      NaN                  NaN            0
# 1      NaN                  NaN            0
# 2      NaN                  NaN            0
# 3      NaN                  NaN            0
# 4      NaN  2113-10-18 00:00:00            1

# %%
from datetime import datetime

NOT_CONVERTED = 'NOT_CONVERTED'

def str2datetime(s):
    def _convert(_s, _dformat):
        try:
            converted_dt = datetime.strptime(_s, _dformat)
        except Exception:
            return NOT_CONVERTED

        return converted_dt

    if isinstance(s, datetime):
        return s

    dformats = [
        '%Y-%m-%d %p %I:%M:%S',
        '%Y-%m-%d %H:%M:%S.%f',
        '%Y-%m-%d %H:%M:%S',
        '%Y-%m-%d %H:%M',
        '%y-%m-%d %H:%M',
        '%Y-%m-%d',
        '%Y%m%d',
        '%Y-%m-%d +%H:%M',
        '%Y%m%d %H%M',
        '%Y%m%d%H%M%S',
        ]

    s = s.split('.')[0]
    s = s.replace('오전', 'am').replace('오후', 'pm')
    for dformat in dformats:
        dt = _convert(s, dformat)
        if dt != NOT_CONVERTED:
            return dt

    return NOT_CONVERTED

# %%
# Inclusion Criteria
## AGE >= 18, First MAP > 65
## Make Patients DataFrame with SUBJECT_ID, HADM_ID, AGE, First MAP
admissions = pd.read_csv('ADMISSIONS.csv')
patients = pd.read_csv('PATIENTS.csv')
patients_info = admissions[['SUBJECT_ID', 'HADM_ID']]
patients_info['AGE'] = ''
patients_info['FIRST_MAP'] = ''

# Update Patient's AGE and MAP
for (idx, row) in tqdm(patients_info.iterrows(), desc='make patients info table'):
  subject_id = row['SUBJECT_ID']
  hadm_id = row['HADM_ID']
  admin_date = admissions[admissions['HADM_ID'] == hadm_id]['ADMITTIME'].values[0]
  dob = patients[patients['SUBJECT_ID'] == subject_id]['DOB'].values[0]
  age = int((str2datetime(admin_date) - str2datetime(dob)).total_seconds() / (3600. * 24 * 365))
  patients_info.loc[idx, 'AGE'] = age

  # If there are no map values, calculate map with sbp & dpb
  # MAP = SBP + 2 (DBP) / 3
  map_list = hadm_VS[str(hadm_id)][hadm_VS[str(hadm_id)]['ITEMID'].isin(VITAL_SIGNS['MAP'])]
  map_list.sort_values(by=['CHARTTIME'])
  if len(map_list) == 0:
    sbp_list = hadm_VS[str(hadm_id)][hadm_VS[str(hadm_id)]['ITEMID'].isin(VITAL_SIGNS['SBP'])]
    sbp_list.sort_values(by=['CHARTTIME'])
    dbp_list = hadm_VS[str(hadm_id)][hadm_VS[str(hadm_id)]['ITEMID'].isin(VITAL_SIGNS['DBP'])]
    dbp_list.sort_values(by=['CHARTTIME'])
    if (len(sbp_list) == 0) or (len(dbp_list) == 0):
      map = np.nan
    else:
      sbp = int(sbp_list['VALUENUM'].values[0])
      dbp = int(dbp_list['VALUENUM'].values[0])
      map = (sbp + (2*dbp)) / 3
  else:
    map = int(map_list['VALUENUM'].values[0])
  
  patients_info.loc[idx, 'FIRST_MAP'] = map

patients_info
# Out:
# make patients info table: 1262it [00:10, 116.38it/s]
#       SUBJECT_ID  HADM_ID AGE  FIRST_MAP
# 0             55   190665  64      104.0
# 1             82   110641   0        NaN
# 2             87   190659   0        NaN
# 3            148   199488  78  63.333333
# 4            505   116719  56       61.0
# ...          ...      ...  ..        ...
# 1257       99830   176834  49         86
# 1258       93784   172532  63         99
# 1259       95413   187979  55  80.333333
# 1260       98644   109643  49       75.0
# 1261       98697   166893  73       88.0
#
# [1262 rows x 4 columns]

# %%
# Find Included Patients and Exclueded Patients
total_patients_n = len(patients_info)
adult_patients = patients_info[patients_info['AGE'] >= 18]
adult_patients_n = len(adult_patients)
map_normal_patients = adult_patients[adult_patients['FIRST_MAP'] > 65]
map_normal_patients_n = len(map_normal_patients)

print('Total Patients Number: ', total_patients_n)
print('Total AGE >= 18 Patients Number: ', adult_patients_n)
print('\t Excluded by AGE: ', total_patients_n - adult_patients_n)
print('Total Normal MAP Patients Number: ', map_normal_patients_n)
print('\t Excluded by MAP: ', adult_patients_n - map_normal_patients_n)
# Out:
# Total Patients Number:  1262
# Total AGE >= 18 Patients Number:  1109
# 	 Excluded by AGE:  153
# Total Normal MAP Patients Number:  914
# 	 Excluded by MAP:  195

# %%
# Make Patients Group by Age
# Age Groups: <30, <40, <50, <60, <70, <80, <90, >=90
group_list = ['<30', '<40', '<50', '<60', '<70', '<80', '<90', '>=90']
age_group = dict()

for group in tqdm(group_list, desc='Grouping by Age'):
  if group == '<30':
    hadm_ids = map_normal_patients[map_normal_patients['AGE'] < 30]['HADM_ID'].values
    age_group[group] = hadm_ids
    print('# of Patients <30: ', len(hadm_ids))
  elif group == '<40':
    hadm_ids = map_normal_patients[map_normal_patients['AGE'] < 40]['HADM_ID'].values
    age_group[group] = hadm_ids
    print('# of Patients <40: ', len(hadm_ids))
  elif group == '<50':
    hadm_ids = map_normal_patients[map_normal_patients['AGE'] < 50]['HADM_ID'].values
    age_group[group] = hadm_ids
    print('# of Patients <50: ', len(hadm_ids))
  elif group == '<60':
    hadm_ids = map_normal_patients[map_normal_patients['AGE'] < 60]['HADM_ID'].values
    age_group[group] = hadm_ids
    print('# of Patients <60: ', len(hadm_ids))
  elif group == '<70':
    hadm_ids = map_normal_patients[map_normal_patients['AGE'] < 70]['HADM_ID'].values
    age_group[group] = hadm_ids
    print('# of Patients <70: ', len(hadm_ids))
  elif group == '<80':
    hadm_ids = map_normal_patients[map_normal_patients['AGE'] < 80]['HADM_ID'].values
    age_group[group] = hadm_ids
    print('# of Patients <80: ', len(hadm_ids))
  elif group == '<90':
    hadm_ids = map_normal_patients[map_normal_patients['AGE'] < 90]['HADM_ID'].values
    age_group[group] = hadm_ids
    print('# of Patients <90: ', len(hadm_ids))
  else:
    hadm_ids = map_normal_patients[map_normal_patients['AGE'] >= 90]['HADM_ID'].values
    age_group[group] = hadm_ids
    print('# of Patients >=90: ', len(hadm_ids))
# Out:
# Grouping by Age: 100%|██████████| 8/8 [00:00<00:00, 330.97it/s]
# # of Patients <30:  48
# # of Patients <40:  94
# # of Patients <50:  200
# # of Patients <60:  382
# # of Patients <70:  565
# # of Patients <80:  745
# # of Patients <90:  875
# # of Patients >=90:  39

# %%
# Calculate feature statistics for each Group of Patients
# PULSE
feature_statistics = dict()
feature_name = 'PULSE'
for group in tqdm(group_list, desc='Calculate feature statistics by Age Group'):
  group_hadm_ids = age_group[group]
  feature_values = list()
  for hadm_id in group_hadm_ids:
    vs_table = hadm_VS[str(hadm_id)]
    feature_list = list((vs_table[vs_table['ITEMID'].isin(VITAL_SIGNS[feature_name])]['VALUENUM'].values).astype('float32'))
    feature_values += feature_list
  feature_statistics[group] = dict()
  feature_statistics[group][feature_name] = dict({
      'MEAN': np.mean(feature_values),
      'STD': np.std(feature_values),
      'MIN': np.min(feature_values),
      'MAX': np.max(feature_values),
  })
# Out:
# Calculate feature statistics by Age Group: 100%|██████████| 8/8 [00:02<00:00,  3.29it/s]

# %%
feature_statistics
# Out:
# {'<30': {'PULSE': {'MEAN': 100.68296,
#    'STD': 18.467218,
#    'MIN': 28.0,
#    'MAX': 196.0}},
#  '<40': {'PULSE': {'MEAN': 96.06703,
#    'STD': 19.411335,
#    'MIN': 0.0,
#    'MAX': 196.0}},
#  '<50': {'PULSE': {'MEAN': 91.73535,
#    'STD': 19.322868,
#    'MIN': 0.0,
#    'MAX': 196.0}},
#  '<60': {'PULSE': {'MEAN': 90.18136,
#    'STD': 18.485464,
#    'MIN': 0.0,
#    'MAX': 214.0}},
#  '<70': {'PULSE': {'MEAN': 89.340965,
#    'STD': 18.096758,
#    'MIN': 0.0,
#    'MAX': 214.0}},
#  '<80': {'PULSE': {'MEAN': 88.71068,
#    'STD': 17.884577,
#    'MIN': 0.0,
#    'MAX': 214.0}},
#  '<90': {'PULSE': {'MEAN': 88.15716,
#    'STD': 17.771423,
#    'MIN': 0.0,
#    'MAX': 214.0}},
#  '>=90': {'PULSE': {'MEAN': 88.13594,
#    'STD': 19.700163,
#    'MIN': 0.0,
#    'MAX': 160.0}}}

# %%
feature_statistics_2 = dict()
feature_name = 'FiO2'
for group in tqdm(group_list, desc='Calculate feature statistics by Age Group'):
  group_hadm_ids = age_group[group]
  feature_values = list()
  for hadm_id in group_hadm_ids:
    vs_table = hadm_VS[str(hadm_id)]
    feature_list = list((vs_table[vs_table['ITEMID'].isin(VITAL_SIGNS[feature_name])]['VALUENUM'].values).astype('float32'))
    feature_values += feature_list
  feature_statistics_2[group] = dict()
  feature_statistics_2[group][feature_name] = dict({
      'MEAN': np.mean(feature_values),
      'STD': np.std(feature_values),
      'MIN': np.min(feature_values),
      'MAX': np.max(feature_values),
  })
# Out:
# Calculate feature statistics by Age Group: 100%|██████████| 8/8 [00:03<00:00,  2.43it/s]

# %%
feature_statistics_2
# Out:
# {'<30': {'FiO2': {'MEAN': 15.905503,
#    'STD': 25.241135,
#    'MIN': 0.3,
#    'MAX': 100.0}},
#  '<40': {'FiO2': {'MEAN': 12.803642,
#    'STD': 23.450182,
#    'MIN': 0.3,
#    'MAX': 100.0}},
#  '<50': {'FiO2': {'MEAN': 16.267525,
#    'STD': 25.698183,
#    'MIN': 0.0,
#    'MAX': 100.0}},
#  '<60': {'FiO2': {'MEAN': 17.859505,
#    'STD': 25.34781,
#    'MIN': 0.0,
#    'MAX': 100.0}},
#  '<70': {'FiO2': {'MEAN': 16.427124,
#    'STD': 24.406816,
#    'MIN': 0.0,
#    'MAX': 100.0}},
#  '<80': {'FiO2': {'MEAN': 15.96348,
#    'STD': 24.557056,
#    'MIN': 0.0,
#    'MAX': 100.0}},
#  '<90': {'FiO2': {'MEAN': 16.727083,
#    'STD': 24.803514,
#    'MIN': 0.0,
#    'MAX': 100.0}},
#  '>=90': {'FiO2': {'MEAN': 28.77793,
#    'STD': 26.845196,
#    'MIN': 0.21,
#    'MAX': 100.0}}}

# %% [markdown]
# # 데이터 레이블링 실습
#
#
# 1.   사망 레이블
# 2.   저혈압 레이블

# %%
# Make Label DataFrame with SUBJECT_ID, HADM_ID, LABEL, DEATH_TIME
death_label = map_normal_patients[['SUBJECT_ID', 'HADM_ID']]
admissions = pd.read_csv('ADMISSIONS.csv')
death_label = pd.merge(left = death_label, right = admissions[['HADM_ID', 'DEATHTIME', 'HOSPITAL_EXPIRE_FLAG']], how='left', left_on='HADM_ID', right_on='HADM_ID')
death_label = death_label.rename(columns = {'DEATHTIME': 'DEATH_TIME', 'HOSPITAL_EXPIRE_FLAG': 'LABEL'})

# %%
death_label
# Out:
#      SUBJECT_ID  HADM_ID           DEATH_TIME  LABEL
# 0            55   190665                  NaN      0
# 1           505   103194  2154-08-29 11:10:00      1
# 2           201   161473                  NaN      0
# 3           901   107952                  NaN      0
# 4           540   160169                  NaN      0
# ..          ...      ...                  ...    ...
# 909       99830   176834                  NaN      0
# 910       93784   172532                  NaN      0
# 911       95413   187979                  NaN      0
# 912       98644   109643                  NaN      0
# 913       98697   166893                  NaN      0
#
# [914 rows x 4 columns]

# %%
def get_map_with_time(hadm_id):
  map_list = list()
  map_table = hadm_VS[str(hadm_id)][hadm_VS[str(hadm_id)]['ITEMID'].isin(VITAL_SIGNS['MAP'])]
  for (idx, row) in map_table.iterrows():
    chart_time = str2datetime(row['CHARTTIME'])
    feature_value = float(row['VALUENUM'])
    map_list.append((chart_time, feature_value))
  return map_list

# %%
def get_sbp_with_time(hadm_id):
  sbp_list = list()
  sbp_table = hadm_VS[str(hadm_id)][hadm_VS[str(hadm_id)]['ITEMID'].isin(VITAL_SIGNS['SBP'])]
  for (idx, row) in sbp_table.iterrows():
    chart_time = str2datetime(row['CHARTTIME'])
    feature_value = float(row['VALUENUM'])
    sbp_list.append((chart_time, feature_value))
  return sbp_list

# %%
def get_dbp_with_time(hadm_id):
  dbp_list = list()
  dbp_table = hadm_VS[str(hadm_id)][hadm_VS[str(hadm_id)]['ITEMID'].isin(VITAL_SIGNS['DBP'])]
  for (idx, row) in dbp_table.iterrows():
    chart_time = str2datetime(row['CHARTTIME'])
    feature_value = float(row['VALUENUM'])
    dbp_list.append((chart_time, feature_value))
  return dbp_list

# %%
import random
def checking_hypotension(map_list):
  map_list = sorted(map_list, key=lambda x: x[0])
  for idx in range(1, len(map_list)):
    if (map_list[idx-1][1] < 65) and (map_list[idx][1] < 65):
      return True, map_list[idx-1][0]
  
  return False, random.choice(map_list)[0]

# %%
def make_map_with_sbp_dbp(admin_time, disch_time, sbp_list, dbp_list):
  start = admin_time
  end = disch_time
  los = int((end - start).total_seconds() / 3600.)
  dbp_list = list()
  for i in range(los):
    window_start = start + timedelta(hours=i)
    window_end = window_start + timedelta(hours=1)
    sbps = list(filter(lambda x: window_start <= x[0] <= window_end, sbp_list))
    dbps = list(filter(lambda x: window_start <= x[0] <= window_end, sbp_list))

    if (len(sbps) == 0) or (len(dbps) == 0):
      continue
    sbp = np.mean([x[1] for x in sbps])
    dbp = np.mean([x[1] for x in dbps])
    # MAP = SBP + 2 (DBP) / 3
    map = (sbp + (2*dbp)) / 3
    map_list.append((window_start, map))
  return map_list

# %%
# Make Label DataFrame with SUBJECT_ID, HADM_ID, LABEL, HYPOTENSION_TIME
hypotension_label = map_normal_patients[['SUBJECT_ID', 'HADM_ID']]
hypotension_label['LABEL'] = ''
hypotension_label['HYPOTENSION_TIME'] = ''
admissions = pd.read_csv('ADMISSIONS.csv')
# Make MAP DATA for each patients
hadm_ids = hypotension_label['HADM_ID'].values
for hadm_id in tqdm(hadm_ids, desc='Checking Hypotension'):
  admin_time = str2datetime(admissions[admissions['HADM_ID'] == hadm_id]['ADMITTIME'].values[0])
  disch_time = str2datetime(admissions[admissions['HADM_ID'] == hadm_id]['DISCHTIME'].values[0])
  map_list = get_map_with_time(hadm_id)
  if len(map_list) == 0:
    sbp_list = get_sbp_with_time(hadm_id)
    dbp_list = get_dbp_with_time(hadm_id)

  if len(map_list) != 0:
    event_yn, event_time = checking_hypotension(map_list)
  else:
    map_list = make_map_with_sbp_dbp(admin_time, disch_time, sbp_list, dbp_list)
    event_yn, event_time = checking_hypotension(map_list)

  if event_yn:
    hypotension_label.loc[hypotension_label['HADM_ID'] == hadm_id, 'LABEL'] = 1
    hypotension_label.loc[hypotension_label['HADM_ID'] == hadm_id, 'HYPOTENSION_TIME'] = event_time
  else:
    hypotension_label.loc[hypotension_label['HADM_ID'] == hadm_id, 'LABEL'] = 0
    hypotension_label.loc[hypotension_label['HADM_ID'] == hadm_id, 'HYPOTENSION_TIME'] = event_time

print(hypotension_label)
print(sum(hypotension_label['LABEL'].values))
# Out:
# Checking Hypotension: 100%|██████████| 914/914 [00:55<00:00, 16.51it/s]
#       SUBJECT_ID  HADM_ID LABEL     HYPOTENSION_TIME
# 0             55   190665     0  2136-04-04 15:35:00
# 5            505   103194     0  2154-08-24 08:01:00
# 6            201   161473     0  2185-01-09 09:00:00
# 10           901   107952     0  2195-02-11 02:59:00
# 12           540   160169     0  2151-02-08 12:45:00
# ...          ...      ...   ...                  ...
# 1257       99830   176834     1  2187-08-21 05:45:00
# 1258       93784   172532     1  2111-04-14 15:38:00
# 1259       95413   187979     0  2180-03-28 12:17:00
# 1260       98644   109643     0  2194-10-13 03:19:00
# 1261       98697   166893     0  2195-09-09 06:31:00
#
# [914 rows x 4 columns]
# 103

# %% [markdown]
# # Input Data 만들기

# %%
# SPLIT Development, Test set with Subject level (8:2)
subject_ids = hypotension_label['SUBJECT_ID'].unique()
pos_subjects = list()
neg_subjects = list()

for subject_id in subject_ids:
  label = sum(hypotension_label[hypotension_label['SUBJECT_ID'] == subject_id]['LABEL'].values)
  if label == 0:
    neg_subjects.append(subject_id)
  else:
    pos_subjects.append(subject_id)

pos_train_idx = random.sample(range(len(pos_subjects)), int(len(pos_subjects) * 0.8))
neg_train_idx = random.sample(range(len(neg_subjects)), int(len(neg_subjects) * 0.8))

print(pos_train_idx)
print(neg_train_idx)

pos_train = list()
pos_test = list()

neg_train = list()
neg_test = list()

for idx, subject_id in enumerate(pos_subjects):
  if idx in pos_train_idx:
    pos_train.append(subject_id)
  else:
    pos_test.append(subject_id)

for idx, subject_id in enumerate(neg_subjects):
  if idx in neg_train_idx:
    neg_train.append(subject_id)
  else:
    neg_test.append(subject_id)

develop_subject = pos_train + neg_train
test_subject = pos_test + neg_test

print(len(develop_subject))
print(len(test_subject))
# Out:
# [52, 37, 66, 79, 97, 5, 30, 54, 70, 69, 90, 29, 32, 42, 71, 24, 45, 81, 86, 28, 13, 39, 10, 72, 1, 78, 9, 40, 75, 38, 87, 63, 33, 53, 94, 68, 61, 8, 47, 65, 21, 15, 41, 0, 14, 55, 4, 92, 27, 91, 12, 64, 26, 49, 16, 58, 51, 83, 7, 18, 2, 43, 93, 31, 80, 17, 85, 60, 88, 11, 46, 20, 34, 59, 48, 6, 36, 95]
# [157, 581, 162, 539, 27, 641, 127, 215, 140, 2, 497, 536, 486, 549, 265, 31, 483, 389, 95, 388, 323, 107, 92, 16, 202, 289, 42, 318, 173, 287, 570, 87, 76, 201, 191, 313, 144, 123, 37, 379, 291, 577, 7, 67, 550, 132, 171, 85, 138, 208, 351, 387, 170, 637, 276, 491, 629, 312, 64, 256, 525, 401, 288, 543, 237, 207, 4, 71, 120, 278, 370, 538, 8, 630, 565, 634, 347, 432, 517, 457, 302, 540, 245, 452, 125, 246, 310, 45, 411, 403, 293, 372, 284, 139, 341, 412, 203, 463, 422, 281, 614, 501, 47, 1, 587, 337, 513, 583, 383, 40, 96, 590, 478, 333, 131, 73, 362, 314, 631, 529, 217, 296, 344, 79, 20, 561, 355, 599, 190, 548, 503, 226, 55, 141, 100, 638, 472, 551, 104, 390, 128, 178, 304, 617, 381, 357, 14, 391, 48, 454, 506, 121, 647, 476, 459, 151, 571, 297, 576, 473, 530, 375, 80, 586, 371, 404, 444, 589, 553, 480, 135, 446, 213, 51, 74, 450, 410, 97, 200, 180, 329, 453, 142, 519, 236, 612, 247, 205, 155, 309, 109, 210, 467, 416, 72, 61, 605, 474, 33, 311, 606, 211, 408, 148, 595, 300, 53, 204, 114, 161, 305, 601, 23, 356, 15, 165, 377, 231, 192, 578, 439, 206, 188, 584, 223, 317, 275, 642, 62, 515, 11, 360, 415, 274, 181, 426, 435, 484, 58, 541, 258, 528, 398, 175, 261, 492, 420, 494, 414, 364, 572, 282, 461, 380, 224, 233, 319, 394, 368, 430, 465, 449, 613, 28, 557, 182, 423, 230, 628, 537, 624, 555, 328, 343, 481, 611, 99, 117, 335, 507, 373, 290, 54, 632, 359, 225, 77, 535, 315, 235, 625, 509, 91, 580, 84, 66, 504, 626, 292, 57, 146, 294, 0, 521, 158, 17, 348, 220, 49, 50, 640, 172, 384, 88, 266, 196, 299, 564, 340, 569, 184, 283, 153, 443, 221, 130, 616, 12, 477, 167, 469, 218, 417, 321, 216, 493, 295, 582, 25, 68, 325, 608, 346, 243, 150, 160, 575, 500, 98, 502, 559, 648, 402, 436, 604, 620, 137, 239, 26, 455, 618, 166, 126, 470, 518, 392, 495, 350, 185, 397, 219, 594, 468, 591, 413, 475, 407, 32, 183, 241, 24, 445, 393, 248, 21, 353, 253, 421, 429, 179, 65, 386, 83, 327, 59, 259, 442, 194, 646, 574, 635, 405, 280, 514, 94, 406, 10, 345, 75, 376, 298, 320, 101, 382, 209, 43, 105, 499, 9, 198, 498, 268, 152, 301, 427, 212, 593, 451, 597, 471, 110, 119, 238, 86, 566, 122, 38, 639, 349, 164, 460, 286, 44, 563, 534, 342, 112, 93, 34, 623, 643, 103, 524, 385, 556, 512, 5, 596, 277, 462, 622, 232, 374, 358, 334, 163, 558, 615, 82, 102, 244, 133, 254, 396, 260, 279, 352, 273, 522, 330, 603, 19, 81, 262, 63, 511, 187, 168, 316, 149, 489, 89, 176, 579, 134, 147, 545, 645, 533, 458, 145, 186, 482, 466, 199, 18, 365, 354, 35, 598, 106, 542, 197, 505, 270, 177, 272, 552, 434]
# 597
# 150

# %%
# Get Features from Admission time to Prediction time
INPUT_FEATURES = list(VITAL_SIGNS.keys()) + list(LABS.keys())
subject_id = develop_subject[2]

hadm_ids = hypotension_label[hypotension_label['SUBJECT_ID'] == subject_id]['HADM_ID'].values
print(len(hadm_ids))
hadm_input = dict()
for hadm_id in tqdm(hadm_ids, desc='make input features'):
  admin_time = str2datetime(admissions[admissions['HADM_ID'] == hadm_id]['ADMITTIME'].values[0])
  print(admin_time)
  label = hypotension_label[hypotension_label['HADM_ID'] == hadm_id]['LABEL']
  event_time = hypotension_label[hypotension_label['HADM_ID'] == hadm_id]['HYPOTENSION_TIME'].values[0]
  print(event_time)
  seq_len = int((event_time - admin_time).total_seconds() / 3600.)
  print(seq_len)

  features = dict()

  vs = hadm_VS[str(hadm_id)]
  lab = hadm_LAB[str(hadm_id)]
  
  for input_kk in INPUT_FEATURES:
    if input_kk == 'MAP':
      continue
    if input_kk in VITAL_SIGNS:
      feature_vv = hadm_VS[str(hadm_id)][hadm_VS[str(hadm_id)]['ITEMID'].isin(VITAL_SIGNS[input_kk])]
      feature_list = list()

      for (idx, row) in feature_vv.iterrows():
        tt = str2datetime(row['CHARTTIME'])
        vv = float(row['VALUENUM'])
        feature_list.append((tt, vv))
    else:
      feature_vv = hadm_LAB[str(hadm_id)][hadm_LAB[str(hadm_id)]['ITEMID'].isin(LABS[input_kk])]
      feature_list = list()

      for (idx, row) in feature_vv.iterrows():
        tt = str2datetime(row['CHARTTIME'])
        vv = float(row['VALUENUM'])
        feature_list.append((tt, vv))
    
    feature_list = sorted(feature_list, key=lambda x: x[0])
    _feature_list = list()

    for seq_id in range(seq_len):
      start = admin_time + timedelta(hours=seq_id)
      end = start + timedelta(hours=1)
      time_features = list(filter(lambda x: start <= x[0] <= end, feature_list))
      if len(time_features) > 0:
        _feature_list.append((start, time_features[-1][1]))
      else:
        _feature_list.append((start, np.nan))

    features[input_kk] = _feature_list
  
  hadm_input[hadm_id] = features
# Out:
# 3
# make input features:   0%|          | 0/3 [00:00<?, ?it/s]
# 2133-02-16 10:17:00
# 2133-02-23 16:17:00
# 174
# make input features:  33%|███▎      | 1/3 [00:00<00:00,  4.41it/s]
# 2133-03-03 16:04:00
# 2133-03-03 16:04:00
# 0
# 2133-03-31 20:45:00
# 2133-05-14 08:45:00
# 1044
# make input features: 100%|██████████| 3/3 [00:02<00:00,  1.21it/s]

# %%
features
# Out:
# {'PULSE': [(datetime.datetime(2133, 3, 31, 20, 45), 93.0),
#   (datetime.datetime(2133, 3, 31, 21, 45), 98.0),
#   (datetime.datetime(2133, 3, 31, 22, 45), 88.0),
#   (datetime.datetime(2133, 3, 31, 23, 45), 89.0),
#   (datetime.datetime(2133, 4, 1, 0, 45), 86.0),
#   (datetime.datetime(2133, 4, 1, 1, 45), 76.0),
#   (datetime.datetime(2133, 4, 1, 2, 45), 76.0),
#   (datetime.datetime(2133, 4, 1, 3, 45), 76.0),
#   (datetime.datetime(2133, 4, 1, 4, 45), 76.0),
#   (datetime.datetime(2133, 4, 1, 5, 45), 73.0),
#   (datetime.datetime(2133, 4, 1, 6, 45), 76.0),
#   (datetime.datetime(2133, 4, 1, 7, 45), 79.0),
#   (datetime.datetime(2133, 4, 1, 8, 45), 71.0),
#   (datetime.datetime(2133, 4, 1, 9, 45), 75.0),
#   (datetime.datetime(2133, 4, 1, 10, 45), 77.0),
#   (datetime.datetime(2133, 4, 1, 11, 45), 81.0),
#   (datetime.datetime(2133, 4, 1, 12, 45), 84.0),
#   (datetime.datetime(2133, 4, 1, 13, 45), 85.0),
#   (datetime.datetime(2133, 4, 1, 14, 45), 84.0),
#   (datetime.datetime(2133, 4, 1, 15, 45), 86.0),
#   (datetime.datetime(2133, 4, 1, 16, 45), 88.0),
#   (datetime.datetime(2133, 4, 1, 17, 45), 71.0),
#   (datetime.datetime(2133, 4, 1, 18, 45), 72.0),
#   (datetime.datetime(2133, 4, 1, 19, 45), 73.0),
#   (datetime.datetime(2133, 4, 1, 20, 45), 75.0),
#   (datetime.datetime(2133, 4, 1, 21, 45), 79.0),
#   (datetime.datetime(2133, 4, 1, 22, 45), 78.0),
#   (datetime.datetime(2133, 4, 1, 23, 45), 77.0),
#   (datetime.datetime(2133, 4, 2, 0, 45), 79.0),
#   (datetime.datetime(2133, 4, 2, 1, 45), 74.0),
#   (datetime.datetime(2133, 4, 2, 2, 45), 71.0),
#   (datetime.datetime(2133, 4, 2, 3, 45), 70.0),
#   (datetime.datetime(2133, 4, 2, 4, 45), 73.0),
#   (datetime.datetime(2133, 4, 2, 5, 45), 76.0),
#   (datetime.datetime(2133, 4, 2, 6, 45), 78.0),
#   (datetime.datetime(2133, 4, 2, 7, 45), 74.0),
#   (datetime.datetime(2133, 4, 2, 8, 45), 75.0),
#   (datetime.datetime(2133, 4, 2, 9, 45), 75.0),
#   (datetime.datetime(2133, 4, 2, 10, 45), 74.0),
#   (datetime.datetime(2133, 4, 2, 11, 45), 74.0),
#   (datetime.datetime(2133, 4, 2, 12, 45), 73.0),
#   (datetime.datetime(2133, 4, 2, 13, 45), 77.0),
#   (datetime.datetime(2133, 4, 2, 14, 45), 82.0),
#   (datetime.datetime(2133, 4, 2, 15, 45), 78.0),
#   (datetime.datetime(2133, 4, 2, 16, 45), 77.0),
#   (datetime.datetime(2133, 4, 2, 17, 45), 76.0),
#   (datetime.datetime(2133, 4, 2, 18, 45), 78.0),
#   (datetime.datetime(2133, 4, 2, 19, 45), 79.0),
#   (datetime.datetime(2133, 4, 2, 20, 45), 80.0),
#   (datetime.datetime(2133, 4, 2, 21, 45), 83.0),
#   (datetime.datetime(2133, 4, 2, 22, 45), 88.0),
#   (datetime.datetime(2133, 4, 2, 23, 45), 85.0),
#   (datetime.datetime(2133, 4, 3, 0, 45), 83.0),
#   (datetime.datetime(2133, 4, 3, 1, 45), 89.0),
#   (datetime.datetime(2133, 4, 3, 2, 45), 98.0),
#   (datetime.datetime(2133, 4, 3, 3, 45), 93.0),
#   (datetime.datetime(2133, 4, 3, 4, 45), 91.0),
#   (datetime.datetime(2133, 4, 3, 5, 45), 91.0),
#   (datetime.datetime(2133, 4, 3, 6, 45), 90.0),
#   (datetime.datetime(2133, 4, 3, 7, 45), 92.0),
#   (datetime.datetime(2133, 4, 3, 8, 45), 92.0),
#   (datetime.datetime(2133, 4, 3, 9, 45), 92.0),
#   (datetime.datetime(2133, 4, 3, 10, 45), 91.0),
#   (datetime.datetime(2133, 4, 3, 11, 45), 74.0),
#   (datetime.datetime(2133, 4, 3, 12, 45), 77.0),
#   (datetime.datetime(2133, 4, 3, 13, 45), 77.0),
#   (datetime.datetime(2133, 4, 3, 14, 45), 79.0),
#   (datetime.datetime(2133, 4, 3, 15, 45), 81.0),
#   (datetime.datetime(2133, 4, 3, 16, 45), 81.0),
#   (datetime.datetime(2133, 4, 3, 17, 45), 86.0),
#   (datetime.datetime(2133, 4, 3, 18, 45), 85.0),
#   (datetime.datetime(2133, 4, 3, 19, 45), 79.0),
#   (datetime.datetime(2133, 4, 3, 20, 45), 75.0),
#   (datetime.datetime(2133, 4, 3, 21, 45), 75.0),
#   (datetime.datetime(2133, 4, 3, 22, 45), 78.0),
#   (datetime.datetime(2133, 4, 3, 23, 45), 81.0),
#   (datetime.datetime(2133, 4, 4, 0, 45), 76.0),
#   (datetime.datetime(2133, 4, 4, 1, 45), 77.0),
#   (datetime.datetime(2133, 4, 4, 2, 45), 82.0),
#   (datetime.datetime(2133, 4, 4, 3, 45), 87.0),
#   (datetime.datetime(2133, 4, 4, 4, 45), 89.0),
#   (datetime.datetime(2133, 4, 4, 5, 45), 87.0),
#   (datetime.datetime(2133, 4, 4, 6, 45), 90.0),
#   (datetime.datetime(2133, 4, 4, 7, 45), 89.0),
#   (datetime.datetime(2133, 4, 4, 8, 45), 80.0),
#   (datetime.datetime(2133, 4, 4, 9, 45), 89.0),
#   (datetime.datetime(2133, 4, 4, 10, 45), 90.0),
#   (datetime.datetime(2133, 4, 4, 11, 45), 93.0),
#   (datetime.datetime(2133, 4, 4, 12, 45), 93.0),
#   (datetime.datetime(2133, 4, 4, 13, 45), 90.0),
#   (datetime.datetime(2133, 4, 4, 14, 45), 87.0),
#   (datetime.datetime(2133, 4, 4, 15, 45), 86.0),
#   (datetime.datetime(2133, 4, 4, 16, 45), 88.0),
#   (datetime.datetime(2133, 4, 4, 17, 45), 91.0),
#   (datetime.datetime(2133, 4, 4, 18, 45), 95.0),
#   (datetime.datetime(2133, 4, 4, 19, 45), 94.0),
#   (datetime.datetime(2133, 4, 4, 20, 45), 97.0),
#   (datetime.datetime(2133, 4, 4, 21, 45), 98.0),
#   (datetime.datetime(2133, 4, 4, 22, 45), 95.0),
#   (datetime.datetime(2133, 4, 4, 23, 45), 93.0),
#   (datetime.datetime(2133, 4, 5, 0, 45), 90.0),
#   (datetime.datetime(2133, 4, 5, 1, 45), 89.0),
#   (datetime.datetime(2133, 4, 5, 2, 45), 95.0),
#   (datetime.datetime(2133, 4, 5, 3, 45), 101.0),
#   (datetime.datetime(2133, 4, 5, 4, 45), 98.0),
#   (datetime.datetime(2133, 4, 5, 5, 45), 99.0),
#   (datetime.datetime(2133, 4, 5, 6, 45), 101.0),
#   (datetime.datetime(2133, 4, 5, 7, 45), 102.0),
#   (datetime.datetime(2133, 4, 5, 8, 45), 98.0),
#   (datetime.datetime(2133, 4, 5, 9, 45), 98.0),
#   (datetime.datetime(2133, 4, 5, 10, 45), 100.0),
#   (datetime.datetime(2133, 4, 5, 11, 45), 98.0),
#   (datetime.datetime(2133, 4, 5, 12, 45), 104.0),
#   (datetime.datetime(2133, 4, 5, 13, 45), 108.0),
#   (datetime.datetime(2133, 4, 5, 14, 45), 103.0),
#   (datetime.datetime(2133, 4, 5, 15, 45), 105.0),
#   (datetime.datetime(2133, 4, 5, 16, 45), 104.0),
#   (datetime.datetime(2133, 4, 5, 17, 45), 110.0),
#   (datetime.datetime(2133, 4, 5, 18, 45), 109.0),
#   (datetime.datetime(2133, 4, 5, 19, 45), 101.0),
#   (datetime.datetime(2133, 4, 5, 20, 45), 113.0),
#   (datetime.datetime(2133, 4, 5, 21, 45), 102.0),
#   (datetime.datetime(2133, 4, 5, 22, 45), 104.0),
#   (datetime.datetime(2133, 4, 5, 23, 45), 105.0),
#   (datetime.datetime(2133, 4, 6, 0, 45), 104.0),
#   (datetime.datetime(2133, 4, 6, 1, 45), 104.0),
#   (datetime.datetime(2133, 4, 6, 2, 45), 107.0),
#   (datetime.datetime(2133, 4, 6, 3, 45), 114.0),
#   (datetime.datetime(2133, 4, 6, 4, 45), 107.0),
#   (datetime.datetime(2133, 4, 6, 5, 45), 111.0),
#   (datetime.datetime(2133, 4, 6, 6, 45), 111.0),
#   (datetime.datetime(2133, 4, 6, 7, 45), 110.0),
#   (datetime.datetime(2133, 4, 6, 8, 45), 104.0),
#   (datetime.datetime(2133, 4, 6, 9, 45), 105.0),
#   (datetime.datetime(2133, 4, 6, 10, 45), 115.0),
#   (datetime.datetime(2133, 4, 6, 11, 45), 116.0),
#   (datetime.datetime(2133, 4, 6, 12, 45), 107.0),
#   (datetime.datetime(2133, 4, 6, 13, 45), 109.0),
#   (datetime.datetime(2133, 4, 6, 14, 45), 98.0),
#   (datetime.datetime(2133, 4, 6, 15, 45), 99.0),
#   (datetime.datetime(2133, 4, 6, 16, 45), 96.0),
#   (datetime.datetime(2133, 4, 6, 17, 45), 96.0),
#   (datetime.datetime(2133, 4, 6, 18, 45), 99.0),
#   (datetime.datetime(2133, 4, 6, 19, 45), 104.0),
#   (datetime.datetime(2133, 4, 6, 20, 45), 94.0),
#   (datetime.datetime(2133, 4, 6, 21, 45), 91.0),
#   (datetime.datetime(2133, 4, 6, 22, 45), 85.0),
#   (datetime.datetime(2133, 4, 6, 23, 45), 91.0),
#   (datetime.datetime(2133, 4, 7, 0, 45), 89.0),
#   (datetime.datetime(2133, 4, 7, 1, 45), 86.0),
#   (datetime.datetime(2133, 4, 7, 2, 45), 88.0),
#   (datetime.datetime(2133, 4, 7, 3, 45), 87.0),
#   (datetime.datetime(2133, 4, 7, 4, 45), 96.0),
#   (datetime.datetime(2133, 4, 7, 5, 45), 104.0),
#   (datetime.datetime(2133, 4, 7, 6, 45), 90.0),
#   (datetime.datetime(2133, 4, 7, 7, 45), 90.0),
#   (datetime.datetime(2133, 4, 7, 8, 45), 90.0),
#   (datetime.datetime(2133, 4, 7, 9, 45), 92.0),
#   (datetime.datetime(2133, 4, 7, 10, 45), 90.0),
#   (datetime.datetime(2133, 4, 7, 11, 45), 93.0),
#   (datetime.datetime(2133, 4, 7, 12, 45), 91.0),
#   (datetime.datetime(2133, 4, 7, 13, 45), 91.0),
#   (datetime.datetime(2133, 4, 7, 14, 45), 84.0),
#   (datetime.datetime(2133, 4, 7, 15, 45), 88.0),
#   (datetime.datetime(2133, 4, 7, 16, 45), 104.0),
#   (datetime.datetime(2133, 4, 7, 17, 45), 105.0),
#   (datetime.datetime(2133, 4, 7, 18, 45), 103.0),
#   (datetime.datetime(2133, 4, 7, 19, 45), 96.0),
#   (datetime.datetime(2133, 4, 7, 20, 45), 97.0),
#   (datetime.datetime(2133, 4, 7, 21, 45), 94.0),
#   (datetime.datetime(2133, 4, 7, 22, 45), 83.0),
#   (datetime.datetime(2133, 4, 7, 23, 45), 86.0),
#   (datetime.datetime(2133, 4, 8, 0, 45), 94.0),
#   (datetime.datetime(2133, 4, 8, 1, 45), 97.0),
#   (datetime.datetime(2133, 4, 8, 2, 45), 96.0),
#   (datetime.datetime(2133, 4, 8, 3, 45), 88.0),
#   (datetime.datetime(2133, 4, 8, 4, 45), 102.0),
#   (datetime.datetime(2133, 4, 8, 5, 45), 111.0),
#   (datetime.datetime(2133, 4, 8, 6, 45), 107.0),
#   (datetime.datetime(2133, 4, 8, 7, 45), 93.0),
#   (datetime.datetime(2133, 4, 8, 8, 45), 89.0),
#   (datetime.datetime(2133, 4, 8, 9, 45), 93.0),
#   (datetime.datetime(2133, 4, 8, 10, 45), 96.0),
#   (datetime.datetime(2133, 4, 8, 11, 45), 98.0),
#   (datetime.datetime(2133, 4, 8, 12, 45), 91.0),
#   (datetime.datetime(2133, 4, 8, 13, 45), 95.0),
#   (datetime.datetime(2133, 4, 8, 14, 45), 91.0),
#   (datetime.datetime(2133, 4, 8, 15, 45), 94.0),
#   (datetime.datetime(2133, 4, 8, 16, 45), 89.0),
#   (datetime.datetime(2133, 4, 8, 17, 45), 95.0),
#   (datetime.datetime(2133, 4, 8, 18, 45), 99.0),
#   (datetime.datetime(2133, 4, 8, 19, 45), 102.0),
#   (datetime.datetime(2133, 4, 8, 20, 45), 105.0),
#   (datetime.datetime(2133, 4, 8, 21, 45), 99.0),
#   (datetime.datetime(2133, 4, 8, 22, 45), 101.0),
#   (datetime.datetime(2133, 4, 8, 23, 45), 96.0),
#   (datetime.datetime(2133, 4, 9, 0, 45), 97.0),
#   (datetime.datetime(2133, 4, 9, 1, 45), 101.0),
#   (datetime.datetime(2133, 4, 9, 2, 45), 106.0),
#   (datetime.datetime(2133, 4, 9, 3, 45), 107.0),
#   (datetime.datetime(2133, 4, 9, 4, 45), 108.0),
#   (datetime.datetime(2133, 4, 9, 5, 45), 108.0),
#   (datetime.datetime(2133, 4, 9, 6, 45), 95.0),
#   (datetime.datetime(2133, 4, 9, 7, 45), 92.0),
#   (datetime.datetime(2133, 4, 9, 8, 45), 99.0),
#   (datetime.datetime(2133, 4, 9, 9, 45), 97.0),
#   (datetime.datetime(2133, 4, 9, 10, 45), 97.0),
#   (datetime.datetime(2133, 4, 9, 11, 45), 96.0),
#   (datetime.datetime(2133, 4, 9, 12, 45), 101.0),
#   (datetime.datetime(2133, 4, 9, 13, 45), 99.0),
#   (datetime.datetime(2133, 4, 9, 14, 45), 89.0),
#   (datetime.datetime(2133, 4, 9, 15, 45), nan),
#   (datetime.datetime(2133, 4, 9, 16, 45), 91.0),
#   (datetime.datetime(2133, 4, 9, 17, 45), 92.0),
#   (datetime.datetime(2133, 4, 9, 18, 45), 91.0),
#   (datetime.datetime(2133, 4, 9, 19, 45), 103.0),
#   (datetime.datetime(2133, 4, 9, 20, 45), 101.0),
#   (datetime.datetime(2133, 4, 9, 21, 45), 102.0),
#   (datetime.datetime(2133, 4, 9, 22, 45), 94.0),
#   (datetime.datetime(2133, 4, 9, 23, 45), 95.0),
#   (datetime.datetime(2133, 4, 10, 0, 45), 102.0),
#   (datetime.datetime(2133, 4, 10, 1, 45), 106.0),
#   (datetime.datetime(2133, 4, 10, 2, 45), 114.0),
#   (datetime.datetime(2133, 4, 10, 3, 45), 106.0),
#   (datetime.datetime(2133, 4, 10, 4, 45), 111.0),
#   (datetime.datetime(2133, 4, 10, 5, 45), 113.0),
#   (datetime.datetime(2133, 4, 10, 6, 45), 110.0),
#   (datetime.datetime(2133, 4, 10, 7, 45), 105.0),
#   (datetime.datetime(2133, 4, 10, 8, 45), 106.0),
#   (datetime.datetime(2133, 4, 10, 9, 45), 104.0),
#   (datetime.datetime(2133, 4, 10, 10, 45), 97.0),
#   (datetime.datetime(2133, 4, 10, 11, 45), 89.0),
#   (datetime.datetime(2133, 4, 10, 12, 45), 94.0),
#   (datetime.datetime(2133, 4, 10, 13, 45), 90.0),
#   (datetime.datetime(2133, 4, 10, 14, 45), 92.0),
#   (datetime.datetime(2133, 4, 10, 15, 45), 94.0),
#   (datetime.datetime(2133, 4, 10, 16, 45), 98.0),
#   (datetime.datetime(2133, 4, 10, 17, 45), 102.0),
#   (datetime.datetime(2133, 4, 10, 18, 45), 106.0),
#   (datetime.datetime(2133, 4, 10, 19, 45), 110.0),
#   (datetime.datetime(2133, 4, 10, 20, 45), 95.0),
#   (datetime.datetime(2133, 4, 10, 21, 45), 96.0),
#   (datetime.datetime(2133, 4, 10, 22, 45), 109.0),
#   (datetime.datetime(2133, 4, 10, 23, 45), 103.0),
#   (datetime.datetime(2133, 4, 11, 0, 45), 109.0),
#   (datetime.datetime(2133, 4, 11, 1, 45), 103.0),
#   (datetime.datetime(2133, 4, 11, 2, 45), 101.0),
#   (datetime.datetime(2133, 4, 11, 3, 45), 102.0),
#   (datetime.datetime(2133, 4, 11, 4, 45), 94.0),
#   (datetime.datetime(2133, 4, 11, 5, 45), 97.0),
#   (datetime.datetime(2133, 4, 11, 6, 45), 96.0),
#   (datetime.datetime(2133, 4, 11, 7, 45), 99.0),
#   (datetime.datetime(2133, 4, 11, 8, 45), 102.0),
#   (datetime.datetime(2133, 4, 11, 9, 45), 97.0),
#   (datetime.datetime(2133, 4, 11, 10, 45), 95.0),
#   (datetime.datetime(2133, 4, 11, 11, 45), 94.0),
#   (datetime.datetime(2133, 4, 11, 12, 45), 95.0),
#   (datetime.datetime(2133, 4, 11, 13, 45), 90.0),
#   (datetime.datetime(2133, 4, 11, 14, 45), 92.0),
#   (datetime.datetime(2133, 4, 11, 15, 45), 92.0),
#   (datetime.datetime(2133, 4, 11, 16, 45), 98.0),
#   (datetime.datetime(2133, 4, 11, 17, 45), 125.0),
#   (datetime.datetime(2133, 4, 11, 18, 45), 122.0),
#   (datetime.datetime(2133, 4, 11, 19, 45), 100.0),
#   (datetime.datetime(2133, 4, 11, 20, 45), 93.0),
#   (datetime.datetime(2133, 4, 11, 21, 45), 90.0),
#   (datetime.datetime(2133, 4, 11, 22, 45), 91.0),
#   (datetime.datetime(2133, 4, 11, 23, 45), 99.0),
#   (datetime.datetime(2133, 4, 12, 0, 45), 104.0),
#   (datetime.datetime(2133, 4, 12, 1, 45), 101.0),
#   (datetime.datetime(2133, 4, 12, 2, 45), 98.0),
#   (datetime.datetime(2133, 4, 12, 3, 45), 92.0),
#   (datetime.datetime(2133, 4, 12, 4, 45), 97.0),
#   (datetime.datetime(2133, 4, 12, 5, 45), 99.0),
#   (datetime.datetime(2133, 4, 12, 6, 45), 96.0),
#   (datetime.datetime(2133, 4, 12, 7, 45), 88.0),
#   (datetime.datetime(2133, 4, 12, 8, 45), 85.0),
#   (datetime.datetime(2133, 4, 12, 9, 45), 88.0),
#   (datetime.datetime(2133, 4, 12, 10, 45), 95.0),
#   (datetime.datetime(2133, 4, 12, 11, 45), 98.0),
#   (datetime.datetime(2133, 4, 12, 12, 45), 95.0),
#   (datetime.datetime(2133, 4, 12, 13, 45), 93.0),
#   (datetime.datetime(2133, 4, 12, 14, 45), 87.0),
#   (datetime.datetime(2133, 4, 12, 15, 45), 87.0),
#   (datetime.datetime(2133, 4, 12, 16, 45), 86.0),
#   (datetime.datetime(2133, 4, 12, 17, 45), 85.0),
#   (datetime.datetime(2133, 4, 12, 18, 45), 87.0),
#   (datetime.datetime(2133, 4, 12, 19, 45), 100.0),
#   (datetime.datetime(2133, 4, 12, 20, 45), 97.0),
#   (datetime.datetime(2133, 4, 12, 21, 45), 92.0),
#   (datetime.datetime(2133, 4, 12, 22, 45), 94.0),
#   (datetime.datetime(2133, 4, 12, 23, 45), 84.0),
#   (datetime.datetime(2133, 4, 13, 0, 45), 87.0),
#   (datetime.datetime(2133, 4, 13, 1, 45), 90.0),
#   (datetime.datetime(2133, 4, 13, 2, 45), 91.0),
#   (datetime.datetime(2133, 4, 13, 3, 45), 100.0),
#   (datetime.datetime(2133, 4, 13, 4, 45), 105.0),
#   (datetime.datetime(2133, 4, 13, 5, 45), 105.0),
#   (datetime.datetime(2133, 4, 13, 6, 45), 105.0),
#   (datetime.datetime(2133, 4, 13, 7, 45), 92.0),
#   (datetime.datetime(2133, 4, 13, 8, 45), 94.0),
#   (datetime.datetime(2133, 4, 13, 9, 45), 103.0),
#   (datetime.datetime(2133, 4, 13, 10, 45), 115.0),
#   (datetime.datetime(2133, 4, 13, 11, 45), 120.0),
#   (datetime.datetime(2133, 4, 13, 12, 45), 119.0),
#   (datetime.datetime(2133, 4, 13, 13, 45), 123.0),
#   (datetime.datetime(2133, 4, 13, 14, 45), 114.0),
#   (datetime.datetime(2133, 4, 13, 15, 45), 107.0),
#   (datetime.datetime(2133, 4, 13, 16, 45), 98.0),
#   (datetime.datetime(2133, 4, 13, 17, 45), 105.0),
#   (datetime.datetime(2133, 4, 13, 18, 45), 116.0),
#   (datetime.datetime(2133, 4, 13, 19, 45), 109.0),
#   (datetime.datetime(2133, 4, 13, 20, 45), 110.0),
#   (datetime.datetime(2133, 4, 13, 21, 45), 103.0),
#   (datetime.datetime(2133, 4, 13, 22, 45), 91.0),
#   (datetime.datetime(2133, 4, 13, 23, 45), 87.0),
#   (datetime.datetime(2133, 4, 14, 0, 45), 87.0),
#   (datetime.datetime(2133, 4, 14, 1, 45), 88.0),
#   (datetime.datetime(2133, 4, 14, 2, 45), 99.0),
#   (datetime.datetime(2133, 4, 14, 3, 45), 97.0),
#   (datetime.datetime(2133, 4, 14, 4, 45), 93.0),
#   (datetime.datetime(2133, 4, 14, 5, 45), 91.0),
#   (datetime.datetime(2133, 4, 14, 6, 45), 97.0),
#   (datetime.datetime(2133, 4, 14, 7, 45), 83.0),
#   (datetime.datetime(2133, 4, 14, 8, 45), 84.0),
#   (datetime.datetime(2133, 4, 14, 9, 45), 89.0),
#   (datetime.datetime(2133, 4, 14, 10, 45), 93.0),
#   (datetime.datetime(2133, 4, 14, 11, 45), 94.0),
#   (datetime.datetime(2133, 4, 14, 12, 45), 97.0),
#   (datetime.datetime(2133, 4, 14, 13, 45), 103.0),
#   (datetime.datetime(2133, 4, 14, 14, 45), 105.0),
#   (datetime.datetime(2133, 4, 14, 15, 45), 112.0),
#   (datetime.datetime(2133, 4, 14, 16, 45), 92.0),
#   (datetime.datetime(2133, 4, 14, 17, 45), 93.0),
#   (datetime.datetime(2133, 4, 14, 18, 45), 103.0),
#   (datetime.datetime(2133, 4, 14, 19, 45), 102.0),
#   (datetime.datetime(2133, 4, 14, 20, 45), 102.0),
#   (datetime.datetime(2133, 4, 14, 21, 45), 102.0),
#   (datetime.datetime(2133, 4, 14, 22, 45), 100.0),
#   (datetime.datetime(2133, 4, 14, 23, 45), 97.0),
#   (datetime.datetime(2133, 4, 15, 0, 45), 96.0),
#   (datetime.datetime(2133, 4, 15, 1, 45), 106.0),
#   (datetime.datetime(2133, 4, 15, 2, 45), 108.0),
#   (datetime.datetime(2133, 4, 15, 3, 45), 114.0),
#   (datetime.datetime(2133, 4, 15, 4, 45), 122.0),
#   (datetime.datetime(2133, 4, 15, 5, 45), 127.0),
#   (datetime.datetime(2133, 4, 15, 6, 45), 129.0),
#   (datetime.datetime(2133, 4, 15, 7, 45), 133.0),
#   (datetime.datetime(2133, 4, 15, 8, 45), 131.0),
#   (datetime.datetime(2133, 4, 15, 9, 45), 128.0),
#   (datetime.datetime(2133, 4, 15, 10, 45), 126.0),
#   (datetime.datetime(2133, 4, 15, 11, 45), 123.0),
#   (datetime.datetime(2133, 4, 15, 12, 45), 127.0),
#   (datetime.datetime(2133, 4, 15, 13, 45), 111.0),
#   (datetime.datetime(2133, 4, 15, 14, 45), 114.0),
#   (datetime.datetime(2133, 4, 15, 15, 45), 110.0),
#   (datetime.datetime(2133, 4, 15, 16, 45), 104.0),
#   (datetime.datetime(2133, 4, 15, 17, 45), 105.0),
#   (datetime.datetime(2133, 4, 15, 18, 45), 122.0),
#   (datetime.datetime(2133, 4, 15, 19, 45), 127.0),
#   (datetime.datetime(2133, 4, 15, 20, 45), 117.0),
#   (datetime.datetime(2133, 4, 15, 21, 45), 114.0),
#   (datetime.datetime(2133, 4, 15, 22, 45), 106.0),
#   (datetime.datetime(2133, 4, 15, 23, 45), 115.0),
#   (datetime.datetime(2133, 4, 16, 0, 45), 114.0),
#   (datetime.datetime(2133, 4, 16, 1, 45), 114.0),
#   (datetime.datetime(2133, 4, 16, 2, 45), 120.0),
#   (datetime.datetime(2133, 4, 16, 3, 45), 116.0),
#   (datetime.datetime(2133, 4, 16, 4, 45), 107.0),
#   (datetime.datetime(2133, 4, 16, 5, 45), 105.0),
#   (datetime.datetime(2133, 4, 16, 6, 45), 104.0),
#   (datetime.datetime(2133, 4, 16, 7, 45), 101.0),
#   (datetime.datetime(2133, 4, 16, 8, 45), 102.0),
#   (datetime.datetime(2133, 4, 16, 9, 45), 109.0),
#   (datetime.datetime(2133, 4, 16, 10, 45), 105.0),
#   (datetime.datetime(2133, 4, 16, 11, 45), 123.0),
#   (datetime.datetime(2133, 4, 16, 12, 45), 120.0),
#   (datetime.datetime(2133, 4, 16, 13, 45), 121.0),
#   (datetime.datetime(2133, 4, 16, 14, 45), 118.0),
#   (datetime.datetime(2133, 4, 16, 15, 45), 123.0),
#   (datetime.datetime(2133, 4, 16, 16, 45), 122.0),
#   (datetime.datetime(2133, 4, 16, 17, 45), 126.0),
#   (datetime.datetime(2133, 4, 16, 18, 45), 122.0),
#   (datetime.datetime(2133, 4, 16, 19, 45), 115.0),
#   (datetime.datetime(2133, 4, 16, 20, 45), 114.0),
#   (datetime.datetime(2133, 4, 16, 21, 45), 115.0),
#   (datetime.datetime(2133, 4, 16, 22, 45), 126.0),
#   (datetime.datetime(2133, 4, 16, 23, 45), 124.0),
#   (datetime.datetime(2133, 4, 17, 0, 45), 117.0),
#   (datetime.datetime(2133, 4, 17, 1, 45), 118.0),
#   (datetime.datetime(2133, 4, 17, 2, 45), 118.0),
#   (datetime.datetime(2133, 4, 17, 3, 45), 118.0),
#   (datetime.datetime(2133, 4, 17, 4, 45), 108.0),
#   (datetime.datetime(2133, 4, 17, 5, 45), 98.0),
#   (datetime.datetime(2133, 4, 17, 6, 45), 99.0),
#   (datetime.datetime(2133, 4, 17, 7, 45), 106.0),
#   (datetime.datetime(2133, 4, 17, 8, 45), 104.0),
#   (datetime.datetime(2133, 4, 17, 9, 45), 104.0),
#   (datetime.datetime(2133, 4, 17, 10, 45), 101.0),
#   (datetime.datetime(2133, 4, 17, 11, 45), 93.0),
#   (datetime.datetime(2133, 4, 17, 12, 45), 96.0),
#   (datetime.datetime(2133, 4, 17, 13, 45), 97.0),
#   (datetime.datetime(2133, 4, 17, 14, 45), 99.0),
#   (datetime.datetime(2133, 4, 17, 15, 45), 99.0),
#   (datetime.datetime(2133, 4, 17, 16, 45), 103.0),
#   (datetime.datetime(2133, 4, 17, 17, 45), 103.0),
#   (datetime.datetime(2133, 4, 17, 18, 45), 106.0),
#   (datetime.datetime(2133, 4, 17, 19, 45), 94.0),
#   (datetime.datetime(2133, 4, 17, 20, 45), 91.0),
#   (datetime.datetime(2133, 4, 17, 21, 45), 96.0),
#   (datetime.datetime(2133, 4, 17, 22, 45), 96.0),
#   (datetime.datetime(2133, 4, 17, 23, 45), 101.0),
#   (datetime.datetime(2133, 4, 18, 0, 45), 100.0),
#   (datetime.datetime(2133, 4, 18, 1, 45), 104.0),
#   (datetime.datetime(2133, 4, 18, 2, 45), 109.0),
#   (datetime.datetime(2133, 4, 18, 3, 45), 100.0),
#   (datetime.datetime(2133, 4, 18, 4, 45), 106.0),
#   (datetime.datetime(2133, 4, 18, 5, 45), 108.0),
#   (datetime.datetime(2133, 4, 18, 6, 45), 104.0),
#   (datetime.datetime(2133, 4, 18, 7, 45), 111.0),
#   (datetime.datetime(2133, 4, 18, 8, 45), 116.0),
#   (datetime.datetime(2133, 4, 18, 9, 45), 97.0),
#   (datetime.datetime(2133, 4, 18, 10, 45), 105.0),
#   (datetime.datetime(2133, 4, 18, 11, 45), 107.0),
#   (datetime.datetime(2133, 4, 18, 12, 45), 107.0),
#   (datetime.datetime(2133, 4, 18, 13, 45), 109.0),
#   (datetime.datetime(2133, 4, 18, 14, 45), 114.0),
#   (datetime.datetime(2133, 4, 18, 15, 45), 117.0),
#   (datetime.datetime(2133, 4, 18, 16, 45), 106.0),
#   (datetime.datetime(2133, 4, 18, 17, 45), 98.0),
#   (datetime.datetime(2133, 4, 18, 18, 45), 97.0),
#   (datetime.datetime(2133, 4, 18, 19, 45), 101.0),
#   (datetime.datetime(2133, 4, 18, 20, 45), 101.0),
#   (datetime.datetime(2133, 4, 18, 21, 45), 98.0),
#   (datetime.datetime(2133, 4, 18, 22, 45), 109.0),
#   (datetime.datetime(2133, 4, 18, 23, 45), 104.0),
#   (datetime.datetime(2133, 4, 19, 0, 45), 97.0),
#   (datetime.datetime(2133, 4, 19, 1, 45), 101.0),
#   (datetime.datetime(2133, 4, 19, 2, 45), 102.0),
#   (datetime.datetime(2133, 4, 19, 3, 45), 106.0),
#   (datetime.datetime(2133, 4, 19, 4, 45), 112.0),
#   (datetime.datetime(2133, 4, 19, 5, 45), 110.0),
#   (datetime.datetime(2133, 4, 19, 6, 45), 112.0),
#   (datetime.datetime(2133, 4, 19, 7, 45), 100.0),
#   (datetime.datetime(2133, 4, 19, 8, 45), 101.0),
#   (datetime.datetime(2133, 4, 19, 9, 45), 107.0),
#   (datetime.datetime(2133, 4, 19, 10, 45), 110.0),
#   (datetime.datetime(2133, 4, 19, 11, 45), 118.0),
#   (datetime.datetime(2133, 4, 19, 12, 45), 113.0),
#   (datetime.datetime(2133, 4, 19, 13, 45), 112.0),
#   (datetime.datetime(2133, 4, 19, 14, 45), 113.0),
#   (datetime.datetime(2133, 4, 19, 15, 45), 99.0),
#   (datetime.datetime(2133, 4, 19, 16, 45), 101.0),
#   (datetime.datetime(2133, 4, 19, 17, 45), 107.0),
#   (datetime.datetime(2133, 4, 19, 18, 45), 110.0),
#   (datetime.datetime(2133, 4, 19, 19, 45), 107.0),
#   (datetime.datetime(2133, 4, 19, 20, 45), 110.0),
#   (datetime.datetime(2133, 4, 19, 21, 45), 122.0),
#   (datetime.datetime(2133, 4, 19, 22, 45), 102.0),
#   (datetime.datetime(2133, 4, 19, 23, 45), 102.0),
#   (datetime.datetime(2133, 4, 20, 0, 45), 105.0),
#   (datetime.datetime(2133, 4, 20, 1, 45), 111.0),
#   (datetime.datetime(2133, 4, 20, 2, 45), 118.0),
#   (datetime.datetime(2133, 4, 20, 3, 45), 118.0),
#   (datetime.datetime(2133, 4, 20, 4, 45), 117.0),
#   (datetime.datetime(2133, 4, 20, 5, 45), 119.0),
#   (datetime.datetime(2133, 4, 20, 6, 45), 119.0),
#   (datetime.datetime(2133, 4, 20, 7, 45), 112.0),
#   (datetime.datetime(2133, 4, 20, 8, 45), 113.0),
#   (datetime.datetime(2133, 4, 20, 9, 45), 116.0),
#   (datetime.datetime(2133, 4, 20, 10, 45), 110.0),
#   (datetime.datetime(2133, 4, 20, 11, 45), 105.0),
#   (datetime.datetime(2133, 4, 20, 12, 45), 106.0),
#   (datetime.datetime(2133, 4, 20, 13, 45), 102.0),
#   (datetime.datetime(2133, 4, 20, 14, 45), 120.0),
#   (datetime.datetime(2133, 4, 20, 15, 45), 114.0),
#   (datetime.datetime(2133, 4, 20, 16, 45), 113.0),
#   (datetime.datetime(2133, 4, 20, 17, 45), 124.0),
#   (datetime.datetime(2133, 4, 20, 18, 45), 108.0),
#   (datetime.datetime(2133, 4, 20, 19, 45), 113.0),
#   (datetime.datetime(2133, 4, 20, 20, 45), 112.0),
#   (datetime.datetime(2133, 4, 20, 21, 45), 112.0),
#   (datetime.datetime(2133, 4, 20, 22, 45), 115.0),
#   (datetime.datetime(2133, 4, 20, 23, 45), 126.0),
#   (datetime.datetime(2133, 4, 21, 0, 45), 122.0),
#   (datetime.datetime(2133, 4, 21, 1, 45), 117.0),
#   (datetime.datetime(2133, 4, 21, 2, 45), 118.0),
#   (datetime.datetime(2133, 4, 21, 3, 45), 124.0),
#   (datetime.datetime(2133, 4, 21, 4, 45), 121.0),
#   (datetime.datetime(2133, 4, 21, 5, 45), 128.0),
#   (datetime.datetime(2133, 4, 21, 6, 45), 123.0),
#   (datetime.datetime(2133, 4, 21, 7, 45), 123.0),
#   (datetime.datetime(2133, 4, 21, 8, 45), 134.0),
#   (datetime.datetime(2133, 4, 21, 9, 45), 122.0),
#   (datetime.datetime(2133, 4, 21, 10, 45), 122.0),
#   (datetime.datetime(2133, 4, 21, 11, 45), 126.0),
#   (datetime.datetime(2133, 4, 21, 12, 45), 122.0),
#   (datetime.datetime(2133, 4, 21, 13, 45), 128.0),
#   (datetime.datetime(2133, 4, 21, 14, 45), 125.0),
#   (datetime.datetime(2133, 4, 21, 15, 45), 118.0),
#   (datetime.datetime(2133, 4, 21, 16, 45), 125.0),
#   (datetime.datetime(2133, 4, 21, 17, 45), nan),
#   (datetime.datetime(2133, 4, 21, 18, 45), 114.0),
#   (datetime.datetime(2133, 4, 21, 19, 45), 113.0),
#   (datetime.datetime(2133, 4, 21, 20, 45), 127.0),
#   (datetime.datetime(2133, 4, 21, 21, 45), 120.0),
#   (datetime.datetime(2133, 4, 21, 22, 45), 116.0),
#   (datetime.datetime(2133, 4, 21, 23, 45), 116.0),
#   (datetime.datetime(2133, 4, 22, 0, 45), 116.0),
#   (datetime.datetime(2133, 4, 22, 1, 45), 118.0),
#   (datetime.datetime(2133, 4, 22, 2, 45), 129.0),
#   (datetime.datetime(2133, 4, 22, 3, 45), 122.0),
#   (datetime.datetime(2133, 4, 22, 4, 45), 122.0),
#   (datetime.datetime(2133, 4, 22, 5, 45), 127.0),
#   (datetime.datetime(2133, 4, 22, 6, 45), 132.0),
#   (datetime.datetime(2133, 4, 22, 7, 45), 137.0),
#   (datetime.datetime(2133, 4, 22, 8, 45), 137.0),
#   (datetime.datetime(2133, 4, 22, 9, 45), 144.0),
#   (datetime.datetime(2133, 4, 22, 10, 45), 144.0),
#   (datetime.datetime(2133, 4, 22, 11, 45), 139.0),
#   (datetime.datetime(2133, 4, 22, 12, 45), 122.0),
#   (datetime.datetime(2133, 4, 22, 13, 45), 123.0),
#   (datetime.datetime(2133, 4, 22, 14, 45), 128.0),
#   (datetime.datetime(2133, 4, 22, 15, 45), 118.0),
#   (datetime.datetime(2133, 4, 22, 16, 45), 105.0),
#   (datetime.datetime(2133, 4, 22, 17, 45), nan),
#   (datetime.datetime(2133, 4, 22, 18, 45), 106.0),
#   (datetime.datetime(2133, 4, 22, 19, 45), 112.0),
#   (datetime.datetime(2133, 4, 22, 20, 45), 112.0),
#   (datetime.datetime(2133, 4, 22, 21, 45), 106.0),
#   (datetime.datetime(2133, 4, 22, 22, 45), 111.0),
#   (datetime.datetime(2133, 4, 22, 23, 45), 110.0),
#   (datetime.datetime(2133, 4, 23, 0, 45), 118.0),
#   (datetime.datetime(2133, 4, 23, 1, 45), 139.0),
#   (datetime.datetime(2133, 4, 23, 2, 45), 111.0),
#   (datetime.datetime(2133, 4, 23, 3, 45), 110.0),
#   (datetime.datetime(2133, 4, 23, 4, 45), 111.0),
#   (datetime.datetime(2133, 4, 23, 5, 45), 124.0),
#   (datetime.datetime(2133, 4, 23, 6, 45), 121.0),
#   (datetime.datetime(2133, 4, 23, 7, 45), 117.0),
#   (datetime.datetime(2133, 4, 23, 8, 45), 121.0),
#   (datetime.datetime(2133, 4, 23, 9, 45), 123.0),
#   (datetime.datetime(2133, 4, 23, 10, 45), 110.0),
#   (datetime.datetime(2133, 4, 23, 11, 45), 115.0),
#   (datetime.datetime(2133, 4, 23, 12, 45), 115.0),
#   (datetime.datetime(2133, 4, 23, 13, 45), 112.0),
#   (datetime.datetime(2133, 4, 23, 14, 45), 109.0),
#   (datetime.datetime(2133, 4, 23, 15, 45), 104.0),
#   (datetime.datetime(2133, 4, 23, 16, 45), 104.0),
#   (datetime.datetime(2133, 4, 23, 17, 45), 102.0),
#   (datetime.datetime(2133, 4, 23, 18, 45), 102.0),
#   (datetime.datetime(2133, 4, 23, 19, 45), 116.0),
#   (datetime.datetime(2133, 4, 23, 20, 45), 112.0),
#   (datetime.datetime(2133, 4, 23, 21, 45), 110.0),
#   (datetime.datetime(2133, 4, 23, 22, 45), 106.0),
#   (datetime.datetime(2133, 4, 23, 23, 45), 113.0),
#   (datetime.datetime(2133, 4, 24, 0, 45), 114.0),
#   (datetime.datetime(2133, 4, 24, 1, 45), 111.0),
#   (datetime.datetime(2133, 4, 24, 2, 45), 112.0),
#   (datetime.datetime(2133, 4, 24, 3, 45), 113.0),
#   (datetime.datetime(2133, 4, 24, 4, 45), 115.0),
#   (datetime.datetime(2133, 4, 24, 5, 45), 117.0),
#   (datetime.datetime(2133, 4, 24, 6, 45), 121.0),
#   (datetime.datetime(2133, 4, 24, 7, 45), 113.0),
#   (datetime.datetime(2133, 4, 24, 8, 45), 110.0),
#   (datetime.datetime(2133, 4, 24, 9, 45), 110.0),
#   (datetime.datetime(2133, 4, 24, 10, 45), 115.0),
#   (datetime.datetime(2133, 4, 24, 11, 45), 123.0),
#   (datetime.datetime(2133, 4, 24, 12, 45), 115.0),
#   (datetime.datetime(2133, 4, 24, 13, 45), 109.0),
#   (datetime.datetime(2133, 4, 24, 14, 45), 112.0),
#   (datetime.datetime(2133, 4, 24, 15, 45), 121.0),
#   (datetime.datetime(2133, 4, 24, 16, 45), 116.0),
#   (datetime.datetime(2133, 4, 24, 17, 45), 105.0),
#   (datetime.datetime(2133, 4, 24, 18, 45), 101.0),
#   (datetime.datetime(2133, 4, 24, 19, 45), 118.0),
#   (datetime.datetime(2133, 4, 24, 20, 45), 98.0),
#   (datetime.datetime(2133, 4, 24, 21, 45), 97.0),
#   (datetime.datetime(2133, 4, 24, 22, 45), 106.0),
#   (datetime.datetime(2133, 4, 24, 23, 45), 108.0),
#   (datetime.datetime(2133, 4, 25, 0, 45), 109.0),
#   (datetime.datetime(2133, 4, 25, 1, 45), 105.0),
#   (datetime.datetime(2133, 4, 25, 2, 45), 103.0),
#   (datetime.datetime(2133, 4, 25, 3, 45), 103.0),
#   (datetime.datetime(2133, 4, 25, 4, 45), 102.0),
#   (datetime.datetime(2133, 4, 25, 5, 45), 100.0),
#   (datetime.datetime(2133, 4, 25, 6, 45), 120.0),
#   (datetime.datetime(2133, 4, 25, 7, 45), 110.0),
#   (datetime.datetime(2133, 4, 25, 8, 45), 106.0),
#   (datetime.datetime(2133, 4, 25, 9, 45), 104.0),
#   (datetime.datetime(2133, 4, 25, 10, 45), 106.0),
#   (datetime.datetime(2133, 4, 25, 11, 45), 109.0),
#   (datetime.datetime(2133, 4, 25, 12, 45), 104.0),
#   (datetime.datetime(2133, 4, 25, 13, 45), 110.0),
#   (datetime.datetime(2133, 4, 25, 14, 45), 117.0),
#   (datetime.datetime(2133, 4, 25, 15, 45), 104.0),
#   (datetime.datetime(2133, 4, 25, 16, 45), 111.0),
#   (datetime.datetime(2133, 4, 25, 17, 45), 105.0),
#   (datetime.datetime(2133, 4, 25, 18, 45), 106.0),
#   (datetime.datetime(2133, 4, 25, 19, 45), 110.0),
#   (datetime.datetime(2133, 4, 25, 20, 45), 105.0),
#   (datetime.datetime(2133, 4, 25, 21, 45), 101.0),
#   (datetime.datetime(2133, 4, 25, 22, 45), 101.0),
#   (datetime.datetime(2133, 4, 25, 23, 45), 98.0),
#   (datetime.datetime(2133, 4, 26, 0, 45), 97.0),
#   (datetime.datetime(2133, 4, 26, 1, 45), 96.0),
#   (datetime.datetime(2133, 4, 26, 2, 45), 96.0),
#   (datetime.datetime(2133, 4, 26, 3, 45), 102.0),
#   (datetime.datetime(2133, 4, 26, 4, 45), 101.0),
#   (datetime.datetime(2133, 4, 26, 5, 45), 102.0),
#   (datetime.datetime(2133, 4, 26, 6, 45), 116.0),
#   (datetime.datetime(2133, 4, 26, 7, 45), 118.0),
#   (datetime.datetime(2133, 4, 26, 8, 45), 115.0),
#   (datetime.datetime(2133, 4, 26, 9, 45), 118.0),
#   (datetime.datetime(2133, 4, 26, 10, 45), 115.0),
#   (datetime.datetime(2133, 4, 26, 11, 45), 112.0),
#   (datetime.datetime(2133, 4, 26, 12, 45), 113.0),
#   (datetime.datetime(2133, 4, 26, 13, 45), 115.0),
#   (datetime.datetime(2133, 4, 26, 14, 45), 117.0),
#   (datetime.datetime(2133, 4, 26, 15, 45), 116.0),
#   (datetime.datetime(2133, 4, 26, 16, 45), 114.0),
#   (datetime.datetime(2133, 4, 26, 17, 45), 105.0),
#   (datetime.datetime(2133, 4, 26, 18, 45), 109.0),
#   (datetime.datetime(2133, 4, 26, 19, 45), 105.0),
#   (datetime.datetime(2133, 4, 26, 20, 45), 105.0),
#   (datetime.datetime(2133, 4, 26, 21, 45), 105.0),
#   (datetime.datetime(2133, 4, 26, 22, 45), 101.0),
#   (datetime.datetime(2133, 4, 26, 23, 45), 108.0),
#   (datetime.datetime(2133, 4, 27, 0, 45), 99.0),
#   (datetime.datetime(2133, 4, 27, 1, 45), 101.0),
#   (datetime.datetime(2133, 4, 27, 2, 45), 102.0),
#   (datetime.datetime(2133, 4, 27, 3, 45), 101.0),
#   (datetime.datetime(2133, 4, 27, 4, 45), 103.0),
#   (datetime.datetime(2133, 4, 27, 5, 45), nan),
#   (datetime.datetime(2133, 4, 27, 6, 45), 102.0),
#   (datetime.datetime(2133, 4, 27, 7, 45), 108.0),
#   (datetime.datetime(2133, 4, 27, 8, 45), 105.0),
#   (datetime.datetime(2133, 4, 27, 9, 45), 103.0),
#   (datetime.datetime(2133, 4, 27, 10, 45), 119.0),
#   (datetime.datetime(2133, 4, 27, 11, 45), nan),
#   (datetime.datetime(2133, 4, 27, 12, 45), 118.0),
#   (datetime.datetime(2133, 4, 27, 13, 45), 101.0),
#   (datetime.datetime(2133, 4, 27, 14, 45), 109.0),
#   (datetime.datetime(2133, 4, 27, 15, 45), 107.0),
#   (datetime.datetime(2133, 4, 27, 16, 45), 113.0),
#   (datetime.datetime(2133, 4, 27, 17, 45), 114.0),
#   (datetime.datetime(2133, 4, 27, 18, 45), 114.0),
#   (datetime.datetime(2133, 4, 27, 19, 45), 110.0),
#   (datetime.datetime(2133, 4, 27, 20, 45), 110.0),
#   (datetime.datetime(2133, 4, 27, 21, 45), 116.0),
#   (datetime.datetime(2133, 4, 27, 22, 45), 103.0),
#   (datetime.datetime(2133, 4, 27, 23, 45), 108.0),
#   (datetime.datetime(2133, 4, 28, 0, 45), 150.0),
#   (datetime.datetime(2133, 4, 28, 1, 45), 102.0),
#   (datetime.datetime(2133, 4, 28, 2, 45), 107.0),
#   (datetime.datetime(2133, 4, 28, 3, 45), 109.0),
#   (datetime.datetime(2133, 4, 28, 4, 45), 110.0),
#   (datetime.datetime(2133, 4, 28, 5, 45), 114.0),
#   (datetime.datetime(2133, 4, 28, 6, 45), 109.0),
#   (datetime.datetime(2133, 4, 28, 7, 45), 108.0),
#   (datetime.datetime(2133, 4, 28, 8, 45), 106.0),
#   (datetime.datetime(2133, 4, 28, 9, 45), 109.0),
#   (datetime.datetime(2133, 4, 28, 10, 45), 119.0),
#   (datetime.datetime(2133, 4, 28, 11, 45), 116.0),
#   (datetime.datetime(2133, 4, 28, 12, 45), 116.0),
#   (datetime.datetime(2133, 4, 28, 13, 45), 114.0),
#   (datetime.datetime(2133, 4, 28, 14, 45), 112.0),
#   (datetime.datetime(2133, 4, 28, 15, 45), 113.0),
#   (datetime.datetime(2133, 4, 28, 16, 45), 112.0),
#   (datetime.datetime(2133, 4, 28, 17, 45), 112.0),
#   (datetime.datetime(2133, 4, 28, 18, 45), 120.0),
#   (datetime.datetime(2133, 4, 28, 19, 45), 116.0),
#   (datetime.datetime(2133, 4, 28, 20, 45), 150.0),
#   (datetime.datetime(2133, 4, 28, 21, 45), 122.0),
#   (datetime.datetime(2133, 4, 28, 22, 45), 121.0),
#   (datetime.datetime(2133, 4, 28, 23, 45), 119.0),
#   (datetime.datetime(2133, 4, 29, 0, 45), 119.0),
#   (datetime.datetime(2133, 4, 29, 1, 45), 110.0),
#   (datetime.datetime(2133, 4, 29, 2, 45), 109.0),
#   (datetime.datetime(2133, 4, 29, 3, 45), 123.0),
#   (datetime.datetime(2133, 4, 29, 4, 45), 126.0),
#   (datetime.datetime(2133, 4, 29, 5, 45), 124.0),
#   (datetime.datetime(2133, 4, 29, 6, 45), 123.0),
#   (datetime.datetime(2133, 4, 29, 7, 45), 119.0),
#   (datetime.datetime(2133, 4, 29, 8, 45), 120.0),
#   (datetime.datetime(2133, 4, 29, 9, 45), 126.0),
#   (datetime.datetime(2133, 4, 29, 10, 45), 124.0),
#   (datetime.datetime(2133, 4, 29, 11, 45), 121.0),
#   (datetime.datetime(2133, 4, 29, 12, 45), 120.0),
#   (datetime.datetime(2133, 4, 29, 13, 45), 122.0),
#   (datetime.datetime(2133, 4, 29, 14, 45), 127.0),
#   (datetime.datetime(2133, 4, 29, 15, 45), 124.0),
#   (datetime.datetime(2133, 4, 29, 16, 45), 123.0),
#   (datetime.datetime(2133, 4, 29, 17, 45), 123.0),
#   (datetime.datetime(2133, 4, 29, 18, 45), 125.0),
#   (datetime.datetime(2133, 4, 29, 19, 45), 124.0),
#   (datetime.datetime(2133, 4, 29, 20, 45), 122.0),
#   (datetime.datetime(2133, 4, 29, 21, 45), 113.0),
#   (datetime.datetime(2133, 4, 29, 22, 45), 119.0),
#   (datetime.datetime(2133, 4, 29, 23, 45), 120.0),
#   (datetime.datetime(2133, 4, 30, 0, 45), 120.0),
#   (datetime.datetime(2133, 4, 30, 1, 45), 119.0),
#   (datetime.datetime(2133, 4, 30, 2, 45), 118.0),
#   (datetime.datetime(2133, 4, 30, 3, 45), 118.0),
#   (datetime.datetime(2133, 4, 30, 4, 45), 119.0),
#   (datetime.datetime(2133, 4, 30, 5, 45), 121.0),
#   (datetime.datetime(2133, 4, 30, 6, 45), 121.0),
#   (datetime.datetime(2133, 4, 30, 7, 45), 125.0),
#   (datetime.datetime(2133, 4, 30, 8, 45), 120.0),
#   (datetime.datetime(2133, 4, 30, 9, 45), 121.0),
#   (datetime.datetime(2133, 4, 30, 10, 45), 123.0),
#   (datetime.datetime(2133, 4, 30, 11, 45), 122.0),
#   (datetime.datetime(2133, 4, 30, 12, 45), 123.0),
#   (datetime.datetime(2133, 4, 30, 13, 45), 124.0),
#   (datetime.datetime(2133, 4, 30, 14, 45), 124.0),
#   (datetime.datetime(2133, 4, 30, 15, 45), 116.0),
#   (datetime.datetime(2133, 4, 30, 16, 45), 118.0),
#   (datetime.datetime(2133, 4, 30, 17, 45), 118.0),
#   (datetime.datetime(2133, 4, 30, 18, 45), 118.0),
#   (datetime.datetime(2133, 4, 30, 19, 45), 124.0),
#   (datetime.datetime(2133, 4, 30, 20, 45), 128.0),
#   (datetime.datetime(2133, 4, 30, 21, 45), 134.0),
#   (datetime.datetime(2133, 4, 30, 22, 45), 108.0),
#   (datetime.datetime(2133, 4, 30, 23, 45), 106.0),
#   (datetime.datetime(2133, 5, 1, 0, 45), 102.0),
#   (datetime.datetime(2133, 5, 1, 1, 45), 99.0),
#   (datetime.datetime(2133, 5, 1, 2, 45), 112.0),
#   (datetime.datetime(2133, 5, 1, 3, 45), 121.0),
#   (datetime.datetime(2133, 5, 1, 4, 45), 121.0),
#   (datetime.datetime(2133, 5, 1, 5, 45), 112.0),
#   (datetime.datetime(2133, 5, 1, 6, 45), 103.0),
#   (datetime.datetime(2133, 5, 1, 7, 45), 105.0),
#   (datetime.datetime(2133, 5, 1, 8, 45), 113.0),
#   (datetime.datetime(2133, 5, 1, 9, 45), 121.0),
#   (datetime.datetime(2133, 5, 1, 10, 45), 119.0),
#   (datetime.datetime(2133, 5, 1, 11, 45), 113.0),
#   (datetime.datetime(2133, 5, 1, 12, 45), 106.0),
#   (datetime.datetime(2133, 5, 1, 13, 45), 114.0),
#   (datetime.datetime(2133, 5, 1, 14, 45), 120.0),
#   (datetime.datetime(2133, 5, 1, 15, 45), 122.0),
#   (datetime.datetime(2133, 5, 1, 16, 45), 108.0),
#   (datetime.datetime(2133, 5, 1, 17, 45), 122.0),
#   (datetime.datetime(2133, 5, 1, 18, 45), 115.0),
#   (datetime.datetime(2133, 5, 1, 19, 45), 113.0),
#   (datetime.datetime(2133, 5, 1, 20, 45), 114.0),
#   (datetime.datetime(2133, 5, 1, 21, 45), 109.0),
#   (datetime.datetime(2133, 5, 1, 22, 45), 113.0),
#   (datetime.datetime(2133, 5, 1, 23, 45), 114.0),
#   (datetime.datetime(2133, 5, 2, 0, 45), 112.0),
#   (datetime.datetime(2133, 5, 2, 1, 45), 114.0),
#   (datetime.datetime(2133, 5, 2, 2, 45), 116.0),
#   (datetime.datetime(2133, 5, 2, 3, 45), 115.0),
#   (datetime.datetime(2133, 5, 2, 4, 45), 116.0),
#   (datetime.datetime(2133, 5, 2, 5, 45), 116.0),
#   (datetime.datetime(2133, 5, 2, 6, 45), 118.0),
#   (datetime.datetime(2133, 5, 2, 7, 45), 116.0),
#   (datetime.datetime(2133, 5, 2, 8, 45), 117.0),
#   (datetime.datetime(2133, 5, 2, 9, 45), 116.0),
#   (datetime.datetime(2133, 5, 2, 10, 45), 115.0),
#   (datetime.datetime(2133, 5, 2, 11, 45), 104.0),
#   (datetime.datetime(2133, 5, 2, 12, 45), 98.0),
#   (datetime.datetime(2133, 5, 2, 13, 45), 95.0),
#   (datetime.datetime(2133, 5, 2, 14, 45), 107.0),
#   (datetime.datetime(2133, 5, 2, 15, 45), 112.0),
#   (datetime.datetime(2133, 5, 2, 16, 45), 112.0),
#   (datetime.datetime(2133, 5, 2, 17, 45), 114.0),
#   (datetime.datetime(2133, 5, 2, 18, 45), 119.0),
#   (datetime.datetime(2133, 5, 2, 19, 45), 113.0),
#   (datetime.datetime(2133, 5, 2, 20, 45), 118.0),
#   (datetime.datetime(2133, 5, 2, 21, 45), 108.0),
#   (datetime.datetime(2133, 5, 2, 22, 45), 107.0),
#   (datetime.datetime(2133, 5, 2, 23, 45), 107.0),
#   (datetime.datetime(2133, 5, 3, 0, 45), 105.0),
#   (datetime.datetime(2133, 5, 3, 1, 45), 107.0),
#   (datetime.datetime(2133, 5, 3, 2, 45), 108.0),
#   (datetime.datetime(2133, 5, 3, 3, 45), 120.0),
#   (datetime.datetime(2133, 5, 3, 4, 45), 121.0),
#   (datetime.datetime(2133, 5, 3, 5, 45), 120.0),
#   (datetime.datetime(2133, 5, 3, 6, 45), 119.0),
#   (datetime.datetime(2133, 5, 3, 7, 45), 122.0),
#   (datetime.datetime(2133, 5, 3, 8, 45), 122.0),
#   (datetime.datetime(2133, 5, 3, 9, 45), 123.0),
#   (datetime.datetime(2133, 5, 3, 10, 45), 123.0),
#   (datetime.datetime(2133, 5, 3, 11, 45), 122.0),
#   (datetime.datetime(2133, 5, 3, 12, 45), 118.0),
#   (datetime.datetime(2133, 5, 3, 13, 45), 116.0),
#   (datetime.datetime(2133, 5, 3, 14, 45), 123.0),
#   (datetime.datetime(2133, 5, 3, 15, 45), 117.0),
#   (datetime.datetime(2133, 5, 3, 16, 45), 115.0),
#   (datetime.datetime(2133, 5, 3, 17, 45), 107.0),
#   (datetime.datetime(2133, 5, 3, 18, 45), 104.0),
#   (datetime.datetime(2133, 5, 3, 19, 45), 114.0),
#   (datetime.datetime(2133, 5, 3, 20, 45), 118.0),
#   (datetime.datetime(2133, 5, 3, 21, 45), 112.0),
#   (datetime.datetime(2133, 5, 3, 22, 45), 113.0),
#   (datetime.datetime(2133, 5, 3, 23, 45), 116.0),
#   (datetime.datetime(2133, 5, 4, 0, 45), 114.0),
#   (datetime.datetime(2133, 5, 4, 1, 45), 122.0),
#   (datetime.datetime(2133, 5, 4, 2, 45), 110.0),
#   (datetime.datetime(2133, 5, 4, 3, 45), 110.0),
#   (datetime.datetime(2133, 5, 4, 4, 45), 111.0),
#   (datetime.datetime(2133, 5, 4, 5, 45), 111.0),
#   (datetime.datetime(2133, 5, 4, 6, 45), 115.0),
#   (datetime.datetime(2133, 5, 4, 7, 45), 119.0),
#   (datetime.datetime(2133, 5, 4, 8, 45), 122.0),
#   (datetime.datetime(2133, 5, 4, 9, 45), 117.0),
#   (datetime.datetime(2133, 5, 4, 10, 45), 117.0),
#   (datetime.datetime(2133, 5, 4, 11, 45), 119.0),
#   (datetime.datetime(2133, 5, 4, 12, 45), 113.0),
#   (datetime.datetime(2133, 5, 4, 13, 45), 111.0),
#   (datetime.datetime(2133, 5, 4, 14, 45), 104.0),
#   (datetime.datetime(2133, 5, 4, 15, 45), 111.0),
#   (datetime.datetime(2133, 5, 4, 16, 45), 110.0),
#   (datetime.datetime(2133, 5, 4, 17, 45), 112.0),
#   (datetime.datetime(2133, 5, 4, 18, 45), 114.0),
#   (datetime.datetime(2133, 5, 4, 19, 45), 116.0),
#   (datetime.datetime(2133, 5, 4, 20, 45), 108.0),
#   (datetime.datetime(2133, 5, 4, 21, 45), 111.0),
#   (datetime.datetime(2133, 5, 4, 22, 45), 118.0),
#   (datetime.datetime(2133, 5, 4, 23, 45), 114.0),
#   (datetime.datetime(2133, 5, 5, 0, 45), 112.0),
#   (datetime.datetime(2133, 5, 5, 1, 45), 109.0),
#   (datetime.datetime(2133, 5, 5, 2, 45), 111.0),
#   (datetime.datetime(2133, 5, 5, 3, 45), 117.0),
#   (datetime.datetime(2133, 5, 5, 4, 45), 114.0),
#   (datetime.datetime(2133, 5, 5, 5, 45), 104.0),
#   (datetime.datetime(2133, 5, 5, 6, 45), 108.0),
#   (datetime.datetime(2133, 5, 5, 7, 45), 121.0),
#   (datetime.datetime(2133, 5, 5, 8, 45), 122.0),
#   (datetime.datetime(2133, 5, 5, 9, 45), 119.0),
#   (datetime.datetime(2133, 5, 5, 10, 45), 122.0),
#   (datetime.datetime(2133, 5, 5, 11, 45), 123.0),
#   (datetime.datetime(2133, 5, 5, 12, 45), 108.0),
#   (datetime.datetime(2133, 5, 5, 13, 45), 109.0),
#   (datetime.datetime(2133, 5, 5, 14, 45), 113.0),
#   (datetime.datetime(2133, 5, 5, 15, 45), 108.0),
#   (datetime.datetime(2133, 5, 5, 16, 45), 99.0),
#   (datetime.datetime(2133, 5, 5, 17, 45), 99.0),
#   (datetime.datetime(2133, 5, 5, 18, 45), 99.0),
#   (datetime.datetime(2133, 5, 5, 19, 45), 117.0),
#   (datetime.datetime(2133, 5, 5, 20, 45), 116.0),
#   (datetime.datetime(2133, 5, 5, 21, 45), 111.0),
#   (datetime.datetime(2133, 5, 5, 22, 45), 112.0),
#   (datetime.datetime(2133, 5, 5, 23, 45), 118.0),
#   (datetime.datetime(2133, 5, 6, 0, 45), 119.0),
#   (datetime.datetime(2133, 5, 6, 1, 45), 118.0),
#   (datetime.datetime(2133, 5, 6, 2, 45), 119.0),
#   (datetime.datetime(2133, 5, 6, 3, 45), 126.0),
#   (datetime.datetime(2133, 5, 6, 4, 45), 127.0),
#   (datetime.datetime(2133, 5, 6, 5, 45), 129.0),
#   (datetime.datetime(2133, 5, 6, 6, 45), 129.0),
#   (datetime.datetime(2133, 5, 6, 7, 45), 131.0),
#   (datetime.datetime(2133, 5, 6, 8, 45), 125.0),
#   (datetime.datetime(2133, 5, 6, 9, 45), 123.0),
#   (datetime.datetime(2133, 5, 6, 10, 45), 133.0),
#   (datetime.datetime(2133, 5, 6, 11, 45), 131.0),
#   (datetime.datetime(2133, 5, 6, 12, 45), 130.0),
#   (datetime.datetime(2133, 5, 6, 13, 45), 130.0),
#   (datetime.datetime(2133, 5, 6, 14, 45), 130.0),
#   (datetime.datetime(2133, 5, 6, 15, 45), 126.0),
#   (datetime.datetime(2133, 5, 6, 16, 45), 122.0),
#   (datetime.datetime(2133, 5, 6, 17, 45), 122.0),
#   (datetime.datetime(2133, 5, 6, 18, 45), 128.0),
#   (datetime.datetime(2133, 5, 6, 19, 45), 122.0),
#   (datetime.datetime(2133, 5, 6, 20, 45), 118.0),
#   (datetime.datetime(2133, 5, 6, 21, 45), 118.0),
#   (datetime.datetime(2133, 5, 6, 22, 45), 118.0),
#   (datetime.datetime(2133, 5, 6, 23, 45), 120.0),
#   (datetime.datetime(2133, 5, 7, 0, 45), 106.0),
#   (datetime.datetime(2133, 5, 7, 1, 45), 108.0),
#   (datetime.datetime(2133, 5, 7, 2, 45), 117.0),
#   (datetime.datetime(2133, 5, 7, 3, 45), 109.0),
#   (datetime.datetime(2133, 5, 7, 4, 45), 109.0),
#   (datetime.datetime(2133, 5, 7, 5, 45), 104.0),
#   (datetime.datetime(2133, 5, 7, 6, 45), 104.0),
#   (datetime.datetime(2133, 5, 7, 7, 45), 110.0),
#   (datetime.datetime(2133, 5, 7, 8, 45), 107.0),
#   (datetime.datetime(2133, 5, 7, 9, 45), 111.0),
#   (datetime.datetime(2133, 5, 7, 10, 45), 115.0),
#   (datetime.datetime(2133, 5, 7, 11, 45), 113.0),
#   (datetime.datetime(2133, 5, 7, 12, 45), 111.0),
#   (datetime.datetime(2133, 5, 7, 13, 45), 117.0),
#   (datetime.datetime(2133, 5, 7, 14, 45), 117.0),
#   (datetime.datetime(2133, 5, 7, 15, 45), 106.0),
#   (datetime.datetime(2133, 5, 7, 16, 45), 108.0),
#   (datetime.datetime(2133, 5, 7, 17, 45), 112.0),
#   (datetime.datetime(2133, 5, 7, 18, 45), 110.0),
#   (datetime.datetime(2133, 5, 7, 19, 45), 128.0),
#   (datetime.datetime(2133, 5, 7, 20, 45), 127.0),
#   (datetime.datetime(2133, 5, 7, 21, 45), 128.0),
#   (datetime.datetime(2133, 5, 7, 22, 45), 128.0),
#   (datetime.datetime(2133, 5, 7, 23, 45), 122.0),
#   (datetime.datetime(2133, 5, 8, 0, 45), 122.0),
#   (datetime.datetime(2133, 5, 8, 1, 45), 121.0),
#   (datetime.datetime(2133, 5, 8, 2, 45), 129.0),
#   (datetime.datetime(2133, 5, 8, 3, 45), 129.0),
#   (datetime.datetime(2133, 5, 8, 4, 45), 133.0),
#   (datetime.datetime(2133, 5, 8, 5, 45), 133.0),
#   (datetime.datetime(2133, 5, 8, 6, 45), 128.0),
#   (datetime.datetime(2133, 5, 8, 7, 45), 128.0),
#   (datetime.datetime(2133, 5, 8, 8, 45), 125.0),
#   (datetime.datetime(2133, 5, 8, 9, 45), 124.0),
#   (datetime.datetime(2133, 5, 8, 10, 45), 120.0),
#   (datetime.datetime(2133, 5, 8, 11, 45), 119.0),
#   (datetime.datetime(2133, 5, 8, 12, 45), 113.0),
#   (datetime.datetime(2133, 5, 8, 13, 45), 109.0),
#   (datetime.datetime(2133, 5, 8, 14, 45), 108.0),
#   (datetime.datetime(2133, 5, 8, 15, 45), 111.0),
#   (datetime.datetime(2133, 5, 8, 16, 45), 109.0),
#   (datetime.datetime(2133, 5, 8, 17, 45), 113.0),
#   (datetime.datetime(2133, 5, 8, 18, 45), 115.0),
#   (datetime.datetime(2133, 5, 8, 19, 45), 112.0),
#   (datetime.datetime(2133, 5, 8, 20, 45), 112.0),
#   (datetime.datetime(2133, 5, 8, 21, 45), 112.0),
#   (datetime.datetime(2133, 5, 8, 22, 45), 112.0),
#   (datetime.datetime(2133, 5, 8, 23, 45), 110.0),
#   (datetime.datetime(2133, 5, 9, 0, 45), 114.0),
#   (datetime.datetime(2133, 5, 9, 1, 45), 123.0),
#   (datetime.datetime(2133, 5, 9, 2, 45), 128.0),
#   (datetime.datetime(2133, 5, 9, 3, 45), 139.0),
#   (datetime.datetime(2133, 5, 9, 4, 45), 137.0),
#   (datetime.datetime(2133, 5, 9, 5, 45), 139.0),
#   (datetime.datetime(2133, 5, 9, 6, 45), 128.0),
#   (datetime.datetime(2133, 5, 9, 7, 45), 123.0),
#   (datetime.datetime(2133, 5, 9, 8, 45), 117.0),
#   (datetime.datetime(2133, 5, 9, 9, 45), 118.0),
#   (datetime.datetime(2133, 5, 9, 10, 45), 118.0),
#   (datetime.datetime(2133, 5, 9, 11, 45), 117.0),
#   (datetime.datetime(2133, 5, 9, 12, 45), 112.0),
#   (datetime.datetime(2133, 5, 9, 13, 45), 112.0),
#   (datetime.datetime(2133, 5, 9, 14, 45), 109.0),
#   (datetime.datetime(2133, 5, 9, 15, 45), 104.0),
#   (datetime.datetime(2133, 5, 9, 16, 45), 104.0),
#   (datetime.datetime(2133, 5, 9, 17, 45), 102.0),
#   (datetime.datetime(2133, 5, 9, 18, 45), 106.0),
#   (datetime.datetime(2133, 5, 9, 19, 45), 109.0),
#   (datetime.datetime(2133, 5, 9, 20, 45), 114.0),
#   (datetime.datetime(2133, 5, 9, 21, 45), 112.0),
#   (datetime.datetime(2133, 5, 9, 22, 45), 115.0),
#   (datetime.datetime(2133, 5, 9, 23, 45), 110.0),
#   (datetime.datetime(2133, 5, 10, 0, 45), 111.0),
#   (datetime.datetime(2133, 5, 10, 1, 45), 109.0),
#   (datetime.datetime(2133, 5, 10, 2, 45), 111.0),
#   (datetime.datetime(2133, 5, 10, 3, 45), 111.0),
#   (datetime.datetime(2133, 5, 10, 4, 45), 124.0),
#   (datetime.datetime(2133, 5, 10, 5, 45), 120.0),
#   (datetime.datetime(2133, 5, 10, 6, 45), 119.0),
#   (datetime.datetime(2133, 5, 10, 7, 45), 126.0),
#   (datetime.datetime(2133, 5, 10, 8, 45), 124.0),
#   (datetime.datetime(2133, 5, 10, 9, 45), 125.0),
#   (datetime.datetime(2133, 5, 10, 10, 45), 128.0),
#   (datetime.datetime(2133, 5, 10, 11, 45), 126.0),
#   (datetime.datetime(2133, 5, 10, 12, 45), 125.0),
#   (datetime.datetime(2133, 5, 10, 13, 45), 120.0),
#   (datetime.datetime(2133, 5, 10, 14, 45), 116.0),
#   (datetime.datetime(2133, 5, 10, 15, 45), 117.0),
#   (datetime.datetime(2133, 5, 10, 16, 45), 117.0),
#   (datetime.datetime(2133, 5, 10, 17, 45), 115.0),
#   (datetime.datetime(2133, 5, 10, 18, 45), 117.0),
#   (datetime.datetime(2133, 5, 10, 19, 45), 121.0),
#   (datetime.datetime(2133, 5, 10, 20, 45), 125.0),
#   (datetime.datetime(2133, 5, 10, 21, 45), 126.0),
# ...
#   (datetime.datetime(2133, 4, 28, 15, 45), nan),
#   (datetime.datetime(2133, 4, 28, 16, 45), nan),
#   (datetime.datetime(2133, 4, 28, 17, 45), nan),
#   (datetime.datetime(2133, 4, 28, 18, 45), nan),
#   (datetime.datetime(2133, 4, 28, 19, 45), nan),
#   (datetime.datetime(2133, 4, 28, 20, 45), nan),
#   (datetime.datetime(2133, 4, 28, 21, 45), nan),
#   (datetime.datetime(2133, 4, 28, 22, 45), nan),
#   (datetime.datetime(2133, 4, 28, 23, 45), nan),
#   (datetime.datetime(2133, 4, 29, 0, 45), nan),
#   (datetime.datetime(2133, 4, 29, 1, 45), 21.9),
#   (datetime.datetime(2133, 4, 29, 2, 45), nan),
#   (datetime.datetime(2133, 4, 29, 3, 45), nan),
#   (datetime.datetime(2133, 4, 29, 4, 45), nan),
#   (datetime.datetime(2133, 4, 29, 5, 45), nan),
#   (datetime.datetime(2133, 4, 29, 6, 45), nan),
#   (datetime.datetime(2133, 4, 29, 7, 45), nan),
#   (datetime.datetime(2133, 4, 29, 8, 45), nan),
#   (datetime.datetime(2133, 4, 29, 9, 45), nan),
#   (datetime.datetime(2133, 4, 29, 10, 45), 21.7),
#   (datetime.datetime(2133, 4, 29, 11, 45), nan),
#   (datetime.datetime(2133, 4, 29, 12, 45), nan),
#   (datetime.datetime(2133, 4, 29, 13, 45), nan),
#   (datetime.datetime(2133, 4, 29, 14, 45), nan),
#   (datetime.datetime(2133, 4, 29, 15, 45), nan),
#   (datetime.datetime(2133, 4, 29, 16, 45), 22.4),
#   (datetime.datetime(2133, 4, 29, 17, 45), nan),
#   (datetime.datetime(2133, 4, 29, 18, 45), nan),
#   (datetime.datetime(2133, 4, 29, 19, 45), nan),
#   (datetime.datetime(2133, 4, 29, 20, 45), nan),
#   (datetime.datetime(2133, 4, 29, 21, 45), nan),
#   (datetime.datetime(2133, 4, 29, 22, 45), nan),
#   (datetime.datetime(2133, 4, 29, 23, 45), nan),
#   (datetime.datetime(2133, 4, 30, 0, 45), nan),
#   (datetime.datetime(2133, 4, 30, 1, 45), nan),
#   (datetime.datetime(2133, 4, 30, 2, 45), 22.6),
#   (datetime.datetime(2133, 4, 30, 3, 45), nan),
#   (datetime.datetime(2133, 4, 30, 4, 45), nan),
#   (datetime.datetime(2133, 4, 30, 5, 45), nan),
#   (datetime.datetime(2133, 4, 30, 6, 45), nan),
#   (datetime.datetime(2133, 4, 30, 7, 45), nan),
#   (datetime.datetime(2133, 4, 30, 8, 45), nan),
#   (datetime.datetime(2133, 4, 30, 9, 45), nan),
#   (datetime.datetime(2133, 4, 30, 10, 45), nan),
#   (datetime.datetime(2133, 4, 30, 11, 45), nan),
#   (datetime.datetime(2133, 4, 30, 12, 45), nan),
#   (datetime.datetime(2133, 4, 30, 13, 45), nan),
#   (datetime.datetime(2133, 4, 30, 14, 45), nan),
#   (datetime.datetime(2133, 4, 30, 15, 45), nan),
#   (datetime.datetime(2133, 4, 30, 16, 45), nan),
#   (datetime.datetime(2133, 4, 30, 17, 45), nan),
#   (datetime.datetime(2133, 4, 30, 18, 45), nan),
#   (datetime.datetime(2133, 4, 30, 19, 45), nan),
#   (datetime.datetime(2133, 4, 30, 20, 45), nan),
#   (datetime.datetime(2133, 4, 30, 21, 45), nan),
#   (datetime.datetime(2133, 4, 30, 22, 45), nan),
#   (datetime.datetime(2133, 4, 30, 23, 45), nan),
#   (datetime.datetime(2133, 5, 1, 0, 45), nan),
#   (datetime.datetime(2133, 5, 1, 1, 45), nan),
#   (datetime.datetime(2133, 5, 1, 2, 45), 22.6),
#   (datetime.datetime(2133, 5, 1, 3, 45), nan),
#   (datetime.datetime(2133, 5, 1, 4, 45), nan),
#   (datetime.datetime(2133, 5, 1, 5, 45), nan),
#   (datetime.datetime(2133, 5, 1, 6, 45), nan),
#   (datetime.datetime(2133, 5, 1, 7, 45), nan),
#   (datetime.datetime(2133, 5, 1, 8, 45), nan),
#   (datetime.datetime(2133, 5, 1, 9, 45), nan),
#   (datetime.datetime(2133, 5, 1, 10, 45), nan),
#   (datetime.datetime(2133, 5, 1, 11, 45), nan),
#   (datetime.datetime(2133, 5, 1, 12, 45), nan),
#   (datetime.datetime(2133, 5, 1, 13, 45), nan),
#   (datetime.datetime(2133, 5, 1, 14, 45), nan),
#   (datetime.datetime(2133, 5, 1, 15, 45), nan),
#   (datetime.datetime(2133, 5, 1, 16, 45), nan),
#   (datetime.datetime(2133, 5, 1, 17, 45), nan),
#   (datetime.datetime(2133, 5, 1, 18, 45), nan),
#   (datetime.datetime(2133, 5, 1, 19, 45), nan),
#   (datetime.datetime(2133, 5, 1, 20, 45), nan),
#   (datetime.datetime(2133, 5, 1, 21, 45), nan),
#   (datetime.datetime(2133, 5, 1, 22, 45), nan),
#   (datetime.datetime(2133, 5, 1, 23, 45), nan),
#   (datetime.datetime(2133, 5, 2, 0, 45), nan),
#   (datetime.datetime(2133, 5, 2, 1, 45), 20.2),
#   (datetime.datetime(2133, 5, 2, 2, 45), nan),
#   (datetime.datetime(2133, 5, 2, 3, 45), nan),
#   (datetime.datetime(2133, 5, 2, 4, 45), nan),
#   (datetime.datetime(2133, 5, 2, 5, 45), nan),
#   (datetime.datetime(2133, 5, 2, 6, 45), nan),
#   (datetime.datetime(2133, 5, 2, 7, 45), nan),
#   (datetime.datetime(2133, 5, 2, 8, 45), nan),
#   (datetime.datetime(2133, 5, 2, 9, 45), nan),
#   (datetime.datetime(2133, 5, 2, 10, 45), nan),
#   (datetime.datetime(2133, 5, 2, 11, 45), 20.4),
#   (datetime.datetime(2133, 5, 2, 12, 45), nan),
#   (datetime.datetime(2133, 5, 2, 13, 45), 21.9),
#   (datetime.datetime(2133, 5, 2, 14, 45), nan),
#   (datetime.datetime(2133, 5, 2, 15, 45), nan),
#   (datetime.datetime(2133, 5, 2, 16, 45), nan),
#   (datetime.datetime(2133, 5, 2, 17, 45), nan),
#   (datetime.datetime(2133, 5, 2, 18, 45), nan),
#   (datetime.datetime(2133, 5, 2, 19, 45), nan),
#   (datetime.datetime(2133, 5, 2, 20, 45), nan),
#   (datetime.datetime(2133, 5, 2, 21, 45), nan),
#   (datetime.datetime(2133, 5, 2, 22, 45), nan),
#   (datetime.datetime(2133, 5, 2, 23, 45), nan),
#   (datetime.datetime(2133, 5, 3, 0, 45), nan),
#   (datetime.datetime(2133, 5, 3, 1, 45), 26.2),
#   (datetime.datetime(2133, 5, 3, 2, 45), nan),
#   (datetime.datetime(2133, 5, 3, 3, 45), nan),
#   (datetime.datetime(2133, 5, 3, 4, 45), nan),
#   (datetime.datetime(2133, 5, 3, 5, 45), nan),
#   (datetime.datetime(2133, 5, 3, 6, 45), nan),
#   (datetime.datetime(2133, 5, 3, 7, 45), nan),
#   (datetime.datetime(2133, 5, 3, 8, 45), nan),
#   (datetime.datetime(2133, 5, 3, 9, 45), nan),
#   (datetime.datetime(2133, 5, 3, 10, 45), nan),
#   (datetime.datetime(2133, 5, 3, 11, 45), nan),
#   (datetime.datetime(2133, 5, 3, 12, 45), nan),
#   (datetime.datetime(2133, 5, 3, 13, 45), nan),
#   (datetime.datetime(2133, 5, 3, 14, 45), nan),
#   (datetime.datetime(2133, 5, 3, 15, 45), nan),
#   (datetime.datetime(2133, 5, 3, 16, 45), nan),
#   (datetime.datetime(2133, 5, 3, 17, 45), nan),
#   (datetime.datetime(2133, 5, 3, 18, 45), nan),
#   (datetime.datetime(2133, 5, 3, 19, 45), nan),
#   (datetime.datetime(2133, 5, 3, 20, 45), nan),
#   (datetime.datetime(2133, 5, 3, 21, 45), nan),
#   (datetime.datetime(2133, 5, 3, 22, 45), nan),
#   (datetime.datetime(2133, 5, 3, 23, 45), nan),
#   (datetime.datetime(2133, 5, 4, 0, 45), nan),
#   (datetime.datetime(2133, 5, 4, 1, 45), 27.6),
#   (datetime.datetime(2133, 5, 4, 2, 45), nan),
#   (datetime.datetime(2133, 5, 4, 3, 45), nan),
#   (datetime.datetime(2133, 5, 4, 4, 45), nan),
#   (datetime.datetime(2133, 5, 4, 5, 45), nan),
#   (datetime.datetime(2133, 5, 4, 6, 45), nan),
#   (datetime.datetime(2133, 5, 4, 7, 45), nan),
#   (datetime.datetime(2133, 5, 4, 8, 45), nan),
#   (datetime.datetime(2133, 5, 4, 9, 45), nan),
#   (datetime.datetime(2133, 5, 4, 10, 45), nan),
#   (datetime.datetime(2133, 5, 4, 11, 45), nan),
#   (datetime.datetime(2133, 5, 4, 12, 45), nan),
#   (datetime.datetime(2133, 5, 4, 13, 45), nan),
#   (datetime.datetime(2133, 5, 4, 14, 45), nan),
#   (datetime.datetime(2133, 5, 4, 15, 45), nan),
#   (datetime.datetime(2133, 5, 4, 16, 45), nan),
#   (datetime.datetime(2133, 5, 4, 17, 45), nan),
#   (datetime.datetime(2133, 5, 4, 18, 45), nan),
#   (datetime.datetime(2133, 5, 4, 19, 45), nan),
#   (datetime.datetime(2133, 5, 4, 20, 45), nan),
#   (datetime.datetime(2133, 5, 4, 21, 45), nan),
#   (datetime.datetime(2133, 5, 4, 22, 45), nan),
#   (datetime.datetime(2133, 5, 4, 23, 45), nan),
#   (datetime.datetime(2133, 5, 5, 0, 45), 26.1),
#   (datetime.datetime(2133, 5, 5, 1, 45), nan),
#   (datetime.datetime(2133, 5, 5, 2, 45), nan),
#   (datetime.datetime(2133, 5, 5, 3, 45), nan),
#   (datetime.datetime(2133, 5, 5, 4, 45), nan),
#   (datetime.datetime(2133, 5, 5, 5, 45), nan),
#   (datetime.datetime(2133, 5, 5, 6, 45), nan),
#   (datetime.datetime(2133, 5, 5, 7, 45), nan),
#   (datetime.datetime(2133, 5, 5, 8, 45), nan),
#   (datetime.datetime(2133, 5, 5, 9, 45), nan),
#   (datetime.datetime(2133, 5, 5, 10, 45), nan),
#   (datetime.datetime(2133, 5, 5, 11, 45), nan),
#   (datetime.datetime(2133, 5, 5, 12, 45), nan),
#   (datetime.datetime(2133, 5, 5, 13, 45), nan),
#   (datetime.datetime(2133, 5, 5, 14, 45), nan),
#   (datetime.datetime(2133, 5, 5, 15, 45), nan),
#   (datetime.datetime(2133, 5, 5, 16, 45), nan),
#   (datetime.datetime(2133, 5, 5, 17, 45), nan),
#   (datetime.datetime(2133, 5, 5, 18, 45), nan),
#   (datetime.datetime(2133, 5, 5, 19, 45), nan),
#   (datetime.datetime(2133, 5, 5, 20, 45), nan),
#   (datetime.datetime(2133, 5, 5, 21, 45), nan),
#   (datetime.datetime(2133, 5, 5, 22, 45), nan),
#   (datetime.datetime(2133, 5, 5, 23, 45), nan),
#   (datetime.datetime(2133, 5, 6, 0, 45), nan),
#   (datetime.datetime(2133, 5, 6, 1, 45), 27.9),
#   (datetime.datetime(2133, 5, 6, 2, 45), nan),
#   (datetime.datetime(2133, 5, 6, 3, 45), nan),
#   (datetime.datetime(2133, 5, 6, 4, 45), nan),
#   (datetime.datetime(2133, 5, 6, 5, 45), nan),
#   (datetime.datetime(2133, 5, 6, 6, 45), nan),
#   (datetime.datetime(2133, 5, 6, 7, 45), nan),
#   (datetime.datetime(2133, 5, 6, 8, 45), nan),
#   (datetime.datetime(2133, 5, 6, 9, 45), nan),
#   (datetime.datetime(2133, 5, 6, 10, 45), nan),
#   (datetime.datetime(2133, 5, 6, 11, 45), nan),
#   (datetime.datetime(2133, 5, 6, 12, 45), nan),
#   (datetime.datetime(2133, 5, 6, 13, 45), nan),
#   (datetime.datetime(2133, 5, 6, 14, 45), nan),
#   (datetime.datetime(2133, 5, 6, 15, 45), nan),
#   (datetime.datetime(2133, 5, 6, 16, 45), nan),
#   (datetime.datetime(2133, 5, 6, 17, 45), nan),
#   (datetime.datetime(2133, 5, 6, 18, 45), nan),
#   (datetime.datetime(2133, 5, 6, 19, 45), nan),
#   (datetime.datetime(2133, 5, 6, 20, 45), nan),
#   (datetime.datetime(2133, 5, 6, 21, 45), nan),
#   (datetime.datetime(2133, 5, 6, 22, 45), nan),
#   (datetime.datetime(2133, 5, 6, 23, 45), nan),
#   (datetime.datetime(2133, 5, 7, 0, 45), 23.5),
#   (datetime.datetime(2133, 5, 7, 1, 45), nan),
#   (datetime.datetime(2133, 5, 7, 2, 45), nan),
#   (datetime.datetime(2133, 5, 7, 3, 45), nan),
#   (datetime.datetime(2133, 5, 7, 4, 45), 25.2),
#   (datetime.datetime(2133, 5, 7, 5, 45), nan),
#   (datetime.datetime(2133, 5, 7, 6, 45), nan),
#   (datetime.datetime(2133, 5, 7, 7, 45), nan),
#   (datetime.datetime(2133, 5, 7, 8, 45), nan),
#   (datetime.datetime(2133, 5, 7, 9, 45), nan),
#   (datetime.datetime(2133, 5, 7, 10, 45), nan),
#   (datetime.datetime(2133, 5, 7, 11, 45), nan),
#   (datetime.datetime(2133, 5, 7, 12, 45), nan),
#   (datetime.datetime(2133, 5, 7, 13, 45), nan),
#   (datetime.datetime(2133, 5, 7, 14, 45), nan),
#   (datetime.datetime(2133, 5, 7, 15, 45), 24.3),
#   (datetime.datetime(2133, 5, 7, 16, 45), nan),
#   (datetime.datetime(2133, 5, 7, 17, 45), nan),
#   (datetime.datetime(2133, 5, 7, 18, 45), nan),
#   (datetime.datetime(2133, 5, 7, 19, 45), nan),
#   (datetime.datetime(2133, 5, 7, 20, 45), nan),
#   (datetime.datetime(2133, 5, 7, 21, 45), nan),
#   (datetime.datetime(2133, 5, 7, 22, 45), nan),
#   (datetime.datetime(2133, 5, 7, 23, 45), nan),
#   (datetime.datetime(2133, 5, 8, 0, 45), nan),
#   (datetime.datetime(2133, 5, 8, 1, 45), 23.2),
#   (datetime.datetime(2133, 5, 8, 2, 45), nan),
#   (datetime.datetime(2133, 5, 8, 3, 45), nan),
#   (datetime.datetime(2133, 5, 8, 4, 45), nan),
#   (datetime.datetime(2133, 5, 8, 5, 45), nan),
#   (datetime.datetime(2133, 5, 8, 6, 45), nan),
#   (datetime.datetime(2133, 5, 8, 7, 45), nan),
#   (datetime.datetime(2133, 5, 8, 8, 45), nan),
#   (datetime.datetime(2133, 5, 8, 9, 45), nan),
#   (datetime.datetime(2133, 5, 8, 10, 45), nan),
#   (datetime.datetime(2133, 5, 8, 11, 45), nan),
#   (datetime.datetime(2133, 5, 8, 12, 45), nan),
#   (datetime.datetime(2133, 5, 8, 13, 45), nan),
#   (datetime.datetime(2133, 5, 8, 14, 45), nan),
#   (datetime.datetime(2133, 5, 8, 15, 45), nan),
#   (datetime.datetime(2133, 5, 8, 16, 45), 19.9),
#   (datetime.datetime(2133, 5, 8, 17, 45), 19.9),
#   (datetime.datetime(2133, 5, 8, 18, 45), nan),
#   (datetime.datetime(2133, 5, 8, 19, 45), nan),
#   (datetime.datetime(2133, 5, 8, 20, 45), nan),
#   (datetime.datetime(2133, 5, 8, 21, 45), nan),
#   (datetime.datetime(2133, 5, 8, 22, 45), 22.7),
#   (datetime.datetime(2133, 5, 8, 23, 45), nan),
#   (datetime.datetime(2133, 5, 9, 0, 45), nan),
#   (datetime.datetime(2133, 5, 9, 1, 45), 25.1),
#   (datetime.datetime(2133, 5, 9, 2, 45), nan),
#   (datetime.datetime(2133, 5, 9, 3, 45), nan),
#   (datetime.datetime(2133, 5, 9, 4, 45), nan),
#   (datetime.datetime(2133, 5, 9, 5, 45), nan),
#   (datetime.datetime(2133, 5, 9, 6, 45), nan),
#   (datetime.datetime(2133, 5, 9, 7, 45), nan),
#   (datetime.datetime(2133, 5, 9, 8, 45), nan),
#   (datetime.datetime(2133, 5, 9, 9, 45), nan),
#   (datetime.datetime(2133, 5, 9, 10, 45), nan),
#   (datetime.datetime(2133, 5, 9, 11, 45), nan),
#   (datetime.datetime(2133, 5, 9, 12, 45), nan),
#   (datetime.datetime(2133, 5, 9, 13, 45), nan),
#   (datetime.datetime(2133, 5, 9, 14, 45), nan),
#   (datetime.datetime(2133, 5, 9, 15, 45), nan),
#   (datetime.datetime(2133, 5, 9, 16, 45), nan),
#   (datetime.datetime(2133, 5, 9, 17, 45), nan),
#   (datetime.datetime(2133, 5, 9, 18, 45), nan),
#   (datetime.datetime(2133, 5, 9, 19, 45), nan),
#   (datetime.datetime(2133, 5, 9, 20, 45), 23.9),
#   (datetime.datetime(2133, 5, 9, 21, 45), nan),
#   (datetime.datetime(2133, 5, 9, 22, 45), nan),
#   (datetime.datetime(2133, 5, 9, 23, 45), nan),
#   (datetime.datetime(2133, 5, 10, 0, 45), nan),
#   (datetime.datetime(2133, 5, 10, 1, 45), nan),
#   (datetime.datetime(2133, 5, 10, 2, 45), nan),
#   (datetime.datetime(2133, 5, 10, 3, 45), nan),
#   (datetime.datetime(2133, 5, 10, 4, 45), 24.8),
#   (datetime.datetime(2133, 5, 10, 5, 45), nan),
#   (datetime.datetime(2133, 5, 10, 6, 45), nan),
#   (datetime.datetime(2133, 5, 10, 7, 45), nan),
#   (datetime.datetime(2133, 5, 10, 8, 45), nan),
#   (datetime.datetime(2133, 5, 10, 9, 45), nan),
#   (datetime.datetime(2133, 5, 10, 10, 45), nan),
#   (datetime.datetime(2133, 5, 10, 11, 45), nan),
#   (datetime.datetime(2133, 5, 10, 12, 45), nan),
#   (datetime.datetime(2133, 5, 10, 13, 45), nan),
#   (datetime.datetime(2133, 5, 10, 14, 45), nan),
#   (datetime.datetime(2133, 5, 10, 15, 45), nan),
#   (datetime.datetime(2133, 5, 10, 16, 45), nan),
#   (datetime.datetime(2133, 5, 10, 17, 45), nan),
#   (datetime.datetime(2133, 5, 10, 18, 45), nan),
#   (datetime.datetime(2133, 5, 10, 19, 45), nan),
#   (datetime.datetime(2133, 5, 10, 20, 45), nan),
#   (datetime.datetime(2133, 5, 10, 21, 45), nan),
#   (datetime.datetime(2133, 5, 10, 22, 45), nan),
#   (datetime.datetime(2133, 5, 10, 23, 45), nan),
#   (datetime.datetime(2133, 5, 11, 0, 45), nan),
#   (datetime.datetime(2133, 5, 11, 1, 45), 22.5),
#   (datetime.datetime(2133, 5, 11, 2, 45), nan),
#   (datetime.datetime(2133, 5, 11, 3, 45), nan),
#   (datetime.datetime(2133, 5, 11, 4, 45), nan),
#   (datetime.datetime(2133, 5, 11, 5, 45), nan),
#   (datetime.datetime(2133, 5, 11, 6, 45), nan),
#   (datetime.datetime(2133, 5, 11, 7, 45), nan),
#   (datetime.datetime(2133, 5, 11, 8, 45), nan),
#   (datetime.datetime(2133, 5, 11, 9, 45), nan),
#   (datetime.datetime(2133, 5, 11, 10, 45), nan),
#   (datetime.datetime(2133, 5, 11, 11, 45), nan),
#   (datetime.datetime(2133, 5, 11, 12, 45), nan),
#   (datetime.datetime(2133, 5, 11, 13, 45), nan),
#   (datetime.datetime(2133, 5, 11, 14, 45), nan),
#   (datetime.datetime(2133, 5, 11, 15, 45), nan),
#   (datetime.datetime(2133, 5, 11, 16, 45), nan),
#   (datetime.datetime(2133, 5, 11, 17, 45), nan),
#   (datetime.datetime(2133, 5, 11, 18, 45), nan),
#   (datetime.datetime(2133, 5, 11, 19, 45), nan),
#   (datetime.datetime(2133, 5, 11, 20, 45), nan),
#   (datetime.datetime(2133, 5, 11, 21, 45), nan),
#   (datetime.datetime(2133, 5, 11, 22, 45), nan),
#   (datetime.datetime(2133, 5, 11, 23, 45), nan),
#   (datetime.datetime(2133, 5, 12, 0, 45), nan),
#   (datetime.datetime(2133, 5, 12, 1, 45), 22.3),
#   (datetime.datetime(2133, 5, 12, 2, 45), nan),
#   (datetime.datetime(2133, 5, 12, 3, 45), nan),
#   (datetime.datetime(2133, 5, 12, 4, 45), nan),
#   (datetime.datetime(2133, 5, 12, 5, 45), nan),
#   (datetime.datetime(2133, 5, 12, 6, 45), nan),
#   (datetime.datetime(2133, 5, 12, 7, 45), nan),
#   (datetime.datetime(2133, 5, 12, 8, 45), nan),
#   (datetime.datetime(2133, 5, 12, 9, 45), nan),
#   (datetime.datetime(2133, 5, 12, 10, 45), nan),
#   (datetime.datetime(2133, 5, 12, 11, 45), nan),
#   ...]}

# %%
# Normalize for feature values
hadm_input_norm = dict()
for hadm_id in hadm_input:
  features = hadm_input[hadm_id]  
  normalized_fs = dict()
  for kk in features:
    min, max = feature_range[kk]
    vs = features[kk]
    norm_vs = list()
    for tt, vv in vs:
      if vv != np.nan:
        norm_vs.append((tt, (vv - min) / (max - min)))
      else:
        norm_vs.append(tt, np.nan)
    normalized_fs[kk] = norm_vs

  hadm_input_norm[hadm_id] = normalized_fs

# %%
hadm_input_norm
# Out:
# {141549: {'PULSE': [(datetime.datetime(2133, 2, 16, 10, 17),
#     0.46959459459459457),
#    (datetime.datetime(2133, 2, 16, 11, 17), 0.46959459459459457),
#    (datetime.datetime(2133, 2, 16, 12, 17), 0.44932432432432434),
#    (datetime.datetime(2133, 2, 16, 13, 17), 0.46283783783783783),
#    (datetime.datetime(2133, 2, 16, 14, 17), 0.4560810810810811),
#    (datetime.datetime(2133, 2, 16, 15, 17), 0.44932432432432434),
#    (datetime.datetime(2133, 2, 16, 16, 17), 0.47635135135135137),
#    (datetime.datetime(2133, 2, 16, 17, 17), 0.5101351351351351),
#    (datetime.datetime(2133, 2, 16, 18, 17), 0.5574324324324325),
#    (datetime.datetime(2133, 2, 16, 19, 17), 0.5709459459459459),
#    (datetime.datetime(2133, 2, 16, 20, 17), 0.5641891891891891),
#    (datetime.datetime(2133, 2, 16, 21, 17), 0.5641891891891891),
#    (datetime.datetime(2133, 2, 16, 22, 17), 0.5641891891891891),
#    (datetime.datetime(2133, 2, 16, 23, 17), 0.5641891891891891),
#    (datetime.datetime(2133, 2, 17, 0, 17), 0.5506756756756757),
#    (datetime.datetime(2133, 2, 17, 1, 17), 0.5844594594594594),
#    (datetime.datetime(2133, 2, 17, 2, 17), 0.6047297297297297),
#    (datetime.datetime(2133, 2, 17, 3, 17), 0.6047297297297297),
#    (datetime.datetime(2133, 2, 17, 4, 17), 0.5506756756756757),
#    (datetime.datetime(2133, 2, 17, 5, 17), 0.5574324324324325),
#    (datetime.datetime(2133, 2, 17, 6, 17), 0.543918918918919),
#    (datetime.datetime(2133, 2, 17, 7, 17), 0.5304054054054054),
#    (datetime.datetime(2133, 2, 17, 8, 17), 0.5371621621621622),
#    (datetime.datetime(2133, 2, 17, 9, 17), 0.5709459459459459),
#    (datetime.datetime(2133, 2, 17, 10, 17), 0.46283783783783783),
#    (datetime.datetime(2133, 2, 17, 11, 17), 0.4222972972972973),
#    (datetime.datetime(2133, 2, 17, 12, 17), 0.4155405405405405),
#    (datetime.datetime(2133, 2, 17, 13, 17), 0.4358108108108108),
#    (datetime.datetime(2133, 2, 17, 14, 17), 0.4358108108108108),
#    (datetime.datetime(2133, 2, 17, 15, 17), 0.44256756756756754),
#    (datetime.datetime(2133, 2, 17, 16, 17), 0.47635135135135137),
#    (datetime.datetime(2133, 2, 17, 17, 17), 0.46283783783783783),
#    (datetime.datetime(2133, 2, 17, 18, 17), 0.38175675675675674),
#    (datetime.datetime(2133, 2, 17, 19, 17), 0.4155405405405405),
#    (datetime.datetime(2133, 2, 17, 20, 17), 0.3885135135135135),
#    (datetime.datetime(2133, 2, 17, 21, 17), 0.42905405405405406),
#    (datetime.datetime(2133, 2, 17, 22, 17), 0.42905405405405406),
#    (datetime.datetime(2133, 2, 17, 23, 17), 0.4222972972972973),
#    (datetime.datetime(2133, 2, 18, 0, 17), 0.3952702702702703),
#    (datetime.datetime(2133, 2, 18, 1, 17), 0.3952702702702703),
#    (datetime.datetime(2133, 2, 18, 2, 17), 0.42905405405405406),
#    (datetime.datetime(2133, 2, 18, 3, 17), 0.4358108108108108),
#    (datetime.datetime(2133, 2, 18, 4, 17), 0.42905405405405406),
#    (datetime.datetime(2133, 2, 18, 5, 17), 0.3952702702702703),
#    (datetime.datetime(2133, 2, 18, 6, 17), 0.3952702702702703),
#    (datetime.datetime(2133, 2, 18, 7, 17), 0.40878378378378377),
#    (datetime.datetime(2133, 2, 18, 8, 17), 0.4155405405405405),
#    (datetime.datetime(2133, 2, 18, 9, 17), 0.4560810810810811),
#    (datetime.datetime(2133, 2, 18, 10, 17), 0.375),
#    (datetime.datetime(2133, 2, 18, 11, 17), 0.3614864864864865),
#    (datetime.datetime(2133, 2, 18, 12, 17), 0.38175675675675674),
#    (datetime.datetime(2133, 2, 18, 13, 17), 0.4222972972972973),
#    (datetime.datetime(2133, 2, 18, 14, 17), 0.4358108108108108),
#    (datetime.datetime(2133, 2, 18, 15, 17), 0.40878378378378377),
#    (datetime.datetime(2133, 2, 18, 16, 17), 0.40878378378378377),
#    (datetime.datetime(2133, 2, 18, 17, 17), 0.40202702702702703),
#    (datetime.datetime(2133, 2, 18, 18, 17), 0.3885135135135135),
#    (datetime.datetime(2133, 2, 18, 19, 17), 0.4155405405405405),
#    (datetime.datetime(2133, 2, 18, 20, 17), 0.36824324324324326),
#    (datetime.datetime(2133, 2, 18, 21, 17), 0.3885135135135135),
#    (datetime.datetime(2133, 2, 18, 22, 17), 0.40878378378378377),
#    (datetime.datetime(2133, 2, 18, 23, 17), 0.40202702702702703),
#    (datetime.datetime(2133, 2, 19, 0, 17), 0.40202702702702703),
#    (datetime.datetime(2133, 2, 19, 1, 17), 0.40202702702702703),
#    (datetime.datetime(2133, 2, 19, 2, 17), 0.3952702702702703),
#    (datetime.datetime(2133, 2, 19, 3, 17), 0.375),
#    (datetime.datetime(2133, 2, 19, 4, 17), 0.38175675675675674),
#    (datetime.datetime(2133, 2, 19, 5, 17), 0.3614864864864865),
#    (datetime.datetime(2133, 2, 19, 6, 17), nan),
#    (datetime.datetime(2133, 2, 19, 7, 17), 0.42905405405405406),
#    (datetime.datetime(2133, 2, 19, 8, 17), 0.4222972972972973),
#    (datetime.datetime(2133, 2, 19, 9, 17), 0.375),
#    (datetime.datetime(2133, 2, 19, 10, 17), 0.375),
#    (datetime.datetime(2133, 2, 19, 11, 17), 0.38175675675675674),
#    (datetime.datetime(2133, 2, 19, 12, 17), 0.3885135135135135),
#    (datetime.datetime(2133, 2, 19, 13, 17), 0.3952702702702703),
#    (datetime.datetime(2133, 2, 19, 14, 17), 0.38175675675675674),
#    (datetime.datetime(2133, 2, 19, 15, 17), 0.42905405405405406),
#    (datetime.datetime(2133, 2, 19, 16, 17), 0.4155405405405405),
#    (datetime.datetime(2133, 2, 19, 17, 17), 0.4222972972972973),
#    (datetime.datetime(2133, 2, 19, 18, 17), 0.3885135135135135),
#    (datetime.datetime(2133, 2, 19, 19, 17), 0.375),
#    (datetime.datetime(2133, 2, 19, 20, 17), 0.38175675675675674),
#    (datetime.datetime(2133, 2, 19, 21, 17), 0.38175675675675674),
#    (datetime.datetime(2133, 2, 19, 22, 17), 0.36824324324324326),
#    (datetime.datetime(2133, 2, 19, 23, 17), 0.375),
#    (datetime.datetime(2133, 2, 20, 0, 17), 0.36824324324324326),
#    (datetime.datetime(2133, 2, 20, 1, 17), 0.3952702702702703),
#    (datetime.datetime(2133, 2, 20, 2, 17), 0.38175675675675674),
#    (datetime.datetime(2133, 2, 20, 3, 17), 0.375),
#    (datetime.datetime(2133, 2, 20, 4, 17), 0.375),
#    (datetime.datetime(2133, 2, 20, 5, 17), 0.3885135135135135),
#    (datetime.datetime(2133, 2, 20, 6, 17), 0.3952702702702703),
#    (datetime.datetime(2133, 2, 20, 7, 17), 0.4358108108108108),
#    (datetime.datetime(2133, 2, 20, 8, 17), 0.3952702702702703),
#    (datetime.datetime(2133, 2, 20, 9, 17), 0.38175675675675674),
#    (datetime.datetime(2133, 2, 20, 10, 17), 0.375),
#    (datetime.datetime(2133, 2, 20, 11, 17), 0.3885135135135135),
#    (datetime.datetime(2133, 2, 20, 12, 17), 0.38175675675675674),
#    (datetime.datetime(2133, 2, 20, 13, 17), 0.3885135135135135),
#    (datetime.datetime(2133, 2, 20, 14, 17), 0.375),
#    (datetime.datetime(2133, 2, 20, 15, 17), 0.375),
#    (datetime.datetime(2133, 2, 20, 16, 17), 0.4155405405405405),
#    (datetime.datetime(2133, 2, 20, 17, 17), 0.34797297297297297),
#    (datetime.datetime(2133, 2, 20, 18, 17), 0.34121621621621623),
#    (datetime.datetime(2133, 2, 20, 19, 17), 0.375),
#    (datetime.datetime(2133, 2, 20, 20, 17), 0.375),
#    (datetime.datetime(2133, 2, 20, 21, 17), 0.3952702702702703),
#    (datetime.datetime(2133, 2, 20, 22, 17), 0.4155405405405405),
#    (datetime.datetime(2133, 2, 20, 23, 17), 0.36824324324324326),
#    (datetime.datetime(2133, 2, 21, 0, 17), 0.3547297297297297),
#    (datetime.datetime(2133, 2, 21, 1, 17), 0.3547297297297297),
#    (datetime.datetime(2133, 2, 21, 2, 17), 0.375),
#    (datetime.datetime(2133, 2, 21, 3, 17), 0.38175675675675674),
#    (datetime.datetime(2133, 2, 21, 4, 17), 0.4155405405405405),
#    (datetime.datetime(2133, 2, 21, 5, 17), 0.3614864864864865),
#    (datetime.datetime(2133, 2, 21, 6, 17), 0.3952702702702703),
#    (datetime.datetime(2133, 2, 21, 7, 17), 0.4222972972972973),
#    (datetime.datetime(2133, 2, 21, 8, 17), 0.42905405405405406),
#    (datetime.datetime(2133, 2, 21, 9, 17), 0.3952702702702703),
#    (datetime.datetime(2133, 2, 21, 10, 17), 0.36824324324324326),
#    (datetime.datetime(2133, 2, 21, 11, 17), 0.3885135135135135),
#    (datetime.datetime(2133, 2, 21, 12, 17), 0.375),
#    (datetime.datetime(2133, 2, 21, 13, 17), 0.375),
#    (datetime.datetime(2133, 2, 21, 14, 17), 0.3614864864864865),
#    (datetime.datetime(2133, 2, 21, 15, 17), 0.3614864864864865),
#    (datetime.datetime(2133, 2, 21, 16, 17), 0.3614864864864865),
#    (datetime.datetime(2133, 2, 21, 17, 17), 0.3614864864864865),
#    (datetime.datetime(2133, 2, 21, 18, 17), 0.34797297297297297),
#    (datetime.datetime(2133, 2, 21, 19, 17), 0.3547297297297297),
#    (datetime.datetime(2133, 2, 21, 20, 17), 0.3547297297297297),
#    (datetime.datetime(2133, 2, 21, 21, 17), 0.34797297297297297),
#    (datetime.datetime(2133, 2, 21, 22, 17), 0.34797297297297297),
#    (datetime.datetime(2133, 2, 21, 23, 17), 0.3547297297297297),
#    (datetime.datetime(2133, 2, 22, 0, 17), 0.3614864864864865),
#    (datetime.datetime(2133, 2, 22, 1, 17), 0.375),
#    (datetime.datetime(2133, 2, 22, 2, 17), 0.36824324324324326),
#    (datetime.datetime(2133, 2, 22, 3, 17), 0.3952702702702703),
#    (datetime.datetime(2133, 2, 22, 4, 17), 0.40202702702702703),
#    (datetime.datetime(2133, 2, 22, 5, 17), 0.375),
#    (datetime.datetime(2133, 2, 22, 6, 17), 0.375),
#    (datetime.datetime(2133, 2, 22, 7, 17), 0.4222972972972973),
#    (datetime.datetime(2133, 2, 22, 8, 17), 0.38175675675675674),
#    (datetime.datetime(2133, 2, 22, 9, 17), 0.3885135135135135),
#    (datetime.datetime(2133, 2, 22, 10, 17), 0.3885135135135135),
#    (datetime.datetime(2133, 2, 22, 11, 17), 0.3885135135135135),
#    (datetime.datetime(2133, 2, 22, 12, 17), 0.38175675675675674),
#    (datetime.datetime(2133, 2, 22, 13, 17), 0.3885135135135135),
#    (datetime.datetime(2133, 2, 22, 14, 17), 0.40202702702702703),
#    (datetime.datetime(2133, 2, 22, 15, 17), 0.4222972972972973),
#    (datetime.datetime(2133, 2, 22, 16, 17), 0.36824324324324326),
#    (datetime.datetime(2133, 2, 22, 17, 17), 0.3614864864864865),
#    (datetime.datetime(2133, 2, 22, 18, 17), 0.375),
#    (datetime.datetime(2133, 2, 22, 19, 17), 0.36824324324324326),
#    (datetime.datetime(2133, 2, 22, 20, 17), 0.375),
#    (datetime.datetime(2133, 2, 22, 21, 17), 0.3885135135135135),
#    (datetime.datetime(2133, 2, 22, 22, 17), 0.375),
#    (datetime.datetime(2133, 2, 22, 23, 17), 0.3344594594594595),
#    (datetime.datetime(2133, 2, 23, 0, 17), 0.32094594594594594),
#    (datetime.datetime(2133, 2, 23, 1, 17), 0.3141891891891892),
#    (datetime.datetime(2133, 2, 23, 2, 17), 0.3344594594594595),
#    (datetime.datetime(2133, 2, 23, 3, 17), 0.3277027027027027),
#    (datetime.datetime(2133, 2, 23, 4, 17), 0.32094594594594594),
#    (datetime.datetime(2133, 2, 23, 5, 17), 0.3141891891891892),
#    (datetime.datetime(2133, 2, 23, 6, 17), 0.3277027027027027),
#    (datetime.datetime(2133, 2, 23, 7, 17), 0.34121621621621623),
#    (datetime.datetime(2133, 2, 23, 8, 17), 0.34797297297297297),
#    (datetime.datetime(2133, 2, 23, 9, 17), 0.34121621621621623),
#    (datetime.datetime(2133, 2, 23, 10, 17), 0.3277027027027027),
#    (datetime.datetime(2133, 2, 23, 11, 17), 0.3344594594594595),
#    (datetime.datetime(2133, 2, 23, 12, 17), 0.32094594594594594),
#    (datetime.datetime(2133, 2, 23, 13, 17), 0.34797297297297297),
#    (datetime.datetime(2133, 2, 23, 14, 17), nan),
#    (datetime.datetime(2133, 2, 23, 15, 17), 0.375)],
#   'RESP': [(datetime.datetime(2133, 2, 16, 10, 17), 0.625),
#    (datetime.datetime(2133, 2, 16, 11, 17), 0.5625),
#    (datetime.datetime(2133, 2, 16, 12, 17), 0.5),
#    (datetime.datetime(2133, 2, 16, 13, 17), 0.5),
#    (datetime.datetime(2133, 2, 16, 14, 17), 0.65625),
#    (datetime.datetime(2133, 2, 16, 15, 17), 0.46875),
#    (datetime.datetime(2133, 2, 16, 16, 17), 0.53125),
#    (datetime.datetime(2133, 2, 16, 17, 17), 0.5625),
#    (datetime.datetime(2133, 2, 16, 18, 17), 0.53125),
#    (datetime.datetime(2133, 2, 16, 19, 17), 0.5),
#    (datetime.datetime(2133, 2, 16, 20, 17), 0.59375),
#    (datetime.datetime(2133, 2, 16, 21, 17), 0.875),
#    (datetime.datetime(2133, 2, 16, 22, 17), 0.75),
#    (datetime.datetime(2133, 2, 16, 23, 17), 0.59375),
#    (datetime.datetime(2133, 2, 17, 0, 17), 0.59375),
#    (datetime.datetime(2133, 2, 17, 1, 17), 0.4375),
#    (datetime.datetime(2133, 2, 17, 2, 17), 0.5625),
#    (datetime.datetime(2133, 2, 17, 3, 17), 0.5),
#    (datetime.datetime(2133, 2, 17, 4, 17), 0.65625),
#    (datetime.datetime(2133, 2, 17, 5, 17), 0.53125),
#    (datetime.datetime(2133, 2, 17, 6, 17), 0.5625),
#    (datetime.datetime(2133, 2, 17, 7, 17), 0.65625),
#    (datetime.datetime(2133, 2, 17, 8, 17), 0.5625),
#    (datetime.datetime(2133, 2, 17, 9, 17), 0.46875),
#    (datetime.datetime(2133, 2, 17, 10, 17), 0.5625),
#    (datetime.datetime(2133, 2, 17, 11, 17), 0.5),
#    (datetime.datetime(2133, 2, 17, 12, 17), 0.6875),
#    (datetime.datetime(2133, 2, 17, 13, 17), 0.65625),
#    (datetime.datetime(2133, 2, 17, 14, 17), 0.5),
#    (datetime.datetime(2133, 2, 17, 15, 17), 0.5625),
#    (datetime.datetime(2133, 2, 17, 16, 17), 0.5625),
#    (datetime.datetime(2133, 2, 17, 17, 17), 0.5625),
#    (datetime.datetime(2133, 2, 17, 18, 17), 0.78125),
#    (datetime.datetime(2133, 2, 17, 19, 17), 0.75),
#    (datetime.datetime(2133, 2, 17, 20, 17), 0.75),
#    (datetime.datetime(2133, 2, 17, 21, 17), 0.5625),
#    (datetime.datetime(2133, 2, 17, 22, 17), 0.90625),
#    (datetime.datetime(2133, 2, 17, 23, 17), 0.53125),
#    (datetime.datetime(2133, 2, 18, 0, 17), 0.53125),
#    (datetime.datetime(2133, 2, 18, 1, 17), 0.59375),
#    (datetime.datetime(2133, 2, 18, 2, 17), 0.5625),
#    (datetime.datetime(2133, 2, 18, 3, 17), 0.6875),
#    (datetime.datetime(2133, 2, 18, 4, 17), nan),
#    (datetime.datetime(2133, 2, 18, 5, 17), 0.5625),
#    (datetime.datetime(2133, 2, 18, 6, 17), 0.5),
#    (datetime.datetime(2133, 2, 18, 7, 17), 0.65625),
#    (datetime.datetime(2133, 2, 18, 8, 17), 0.53125),
#    (datetime.datetime(2133, 2, 18, 9, 17), 0.6875),
#    (datetime.datetime(2133, 2, 18, 10, 17), 0.625),
#    (datetime.datetime(2133, 2, 18, 11, 17), 0.71875),
#    (datetime.datetime(2133, 2, 18, 12, 17), 0.6875),
#    (datetime.datetime(2133, 2, 18, 13, 17), 0.75),
#    (datetime.datetime(2133, 2, 18, 14, 17), 0.4375),
#    (datetime.datetime(2133, 2, 18, 15, 17), 0.625),
#    (datetime.datetime(2133, 2, 18, 16, 17), 0.5625),
#    (datetime.datetime(2133, 2, 18, 17, 17), 0.625),
#    (datetime.datetime(2133, 2, 18, 18, 17), 0.3125),
#    (datetime.datetime(2133, 2, 18, 19, 17), 0.625),
#    (datetime.datetime(2133, 2, 18, 20, 17), 0.625),
#    (datetime.datetime(2133, 2, 18, 21, 17), 0.625),
#    (datetime.datetime(2133, 2, 18, 22, 17), 0.625),
#    (datetime.datetime(2133, 2, 18, 23, 17), 0.625),
#    (datetime.datetime(2133, 2, 19, 0, 17), 0.625),
#    (datetime.datetime(2133, 2, 19, 1, 17), 0.59375),
#    (datetime.datetime(2133, 2, 19, 2, 17), 0.65625),
#    (datetime.datetime(2133, 2, 19, 3, 17), 0.53125),
#    (datetime.datetime(2133, 2, 19, 4, 17), 0.46875),
#    (datetime.datetime(2133, 2, 19, 5, 17), 0.625),
#    (datetime.datetime(2133, 2, 19, 6, 17), nan),
#    (datetime.datetime(2133, 2, 19, 7, 17), 0.625),
#    (datetime.datetime(2133, 2, 19, 8, 17), 0.59375),
#    (datetime.datetime(2133, 2, 19, 9, 17), 0.625),
#    (datetime.datetime(2133, 2, 19, 10, 17), 0.4375),
#    (datetime.datetime(2133, 2, 19, 11, 17), 0.59375),
#    (datetime.datetime(2133, 2, 19, 12, 17), 0.625),
#    (datetime.datetime(2133, 2, 19, 13, 17), 0.625),
#    (datetime.datetime(2133, 2, 19, 14, 17), 0.625),
#    (datetime.datetime(2133, 2, 19, 15, 17), 0.53125),
#    (datetime.datetime(2133, 2, 19, 16, 17), 0.53125),
#    (datetime.datetime(2133, 2, 19, 17, 17), 0.625),
#    (datetime.datetime(2133, 2, 19, 18, 17), 0.625),
#    (datetime.datetime(2133, 2, 19, 19, 17), 0.625),
#    (datetime.datetime(2133, 2, 19, 20, 17), 0.5),
#    (datetime.datetime(2133, 2, 19, 21, 17), 0.625),
#    (datetime.datetime(2133, 2, 19, 22, 17), 0.625),
#    (datetime.datetime(2133, 2, 19, 23, 17), 0.625),
#    (datetime.datetime(2133, 2, 20, 0, 17), 0.625),
#    (datetime.datetime(2133, 2, 20, 1, 17), 0.5625),
#    (datetime.datetime(2133, 2, 20, 2, 17), 0.625),
#    (datetime.datetime(2133, 2, 20, 3, 17), 0.59375),
#    (datetime.datetime(2133, 2, 20, 4, 17), 0.59375),
#    (datetime.datetime(2133, 2, 20, 5, 17), 0.5625),
#    (datetime.datetime(2133, 2, 20, 6, 17), 0.625),
#    (datetime.datetime(2133, 2, 20, 7, 17), 0.5),
#    (datetime.datetime(2133, 2, 20, 8, 17), 0.59375),
#    (datetime.datetime(2133, 2, 20, 9, 17), 0.59375),
#    (datetime.datetime(2133, 2, 20, 10, 17), 0.625),
#    (datetime.datetime(2133, 2, 20, 11, 17), 0.59375),
#    (datetime.datetime(2133, 2, 20, 12, 17), 0.5625),
#    (datetime.datetime(2133, 2, 20, 13, 17), 0.59375),
#    (datetime.datetime(2133, 2, 20, 14, 17), 0.625),
#    (datetime.datetime(2133, 2, 20, 15, 17), 0.625),
#    (datetime.datetime(2133, 2, 20, 16, 17), 0.625),
#    (datetime.datetime(2133, 2, 20, 17, 17), 0.625),
#    (datetime.datetime(2133, 2, 20, 18, 17), nan),
#    (datetime.datetime(2133, 2, 20, 19, 17), nan),
#    (datetime.datetime(2133, 2, 20, 20, 17), nan),
#    (datetime.datetime(2133, 2, 20, 21, 17), nan),
#    (datetime.datetime(2133, 2, 20, 22, 17), nan),
#    (datetime.datetime(2133, 2, 20, 23, 17), nan),
#    (datetime.datetime(2133, 2, 21, 0, 17), nan),
#    (datetime.datetime(2133, 2, 21, 1, 17), nan),
#    (datetime.datetime(2133, 2, 21, 2, 17), nan),
#    (datetime.datetime(2133, 2, 21, 3, 17), nan),
#    (datetime.datetime(2133, 2, 21, 4, 17), nan),
#    (datetime.datetime(2133, 2, 21, 5, 17), nan),
#    (datetime.datetime(2133, 2, 21, 6, 17), nan),
#    (datetime.datetime(2133, 2, 21, 7, 17), nan),
#    (datetime.datetime(2133, 2, 21, 8, 17), nan),
#    (datetime.datetime(2133, 2, 21, 9, 17), nan),
#    (datetime.datetime(2133, 2, 21, 10, 17), nan),
#    (datetime.datetime(2133, 2, 21, 11, 17), nan),
#    (datetime.datetime(2133, 2, 21, 12, 17), nan),
#    (datetime.datetime(2133, 2, 21, 13, 17), nan),
#    (datetime.datetime(2133, 2, 21, 14, 17), nan),
#    (datetime.datetime(2133, 2, 21, 15, 17), nan),
#    (datetime.datetime(2133, 2, 21, 16, 17), nan),
#    (datetime.datetime(2133, 2, 21, 17, 17), nan),
#    (datetime.datetime(2133, 2, 21, 18, 17), nan),
#    (datetime.datetime(2133, 2, 21, 19, 17), nan),
#    (datetime.datetime(2133, 2, 21, 20, 17), nan),
#    (datetime.datetime(2133, 2, 21, 21, 17), nan),
#    (datetime.datetime(2133, 2, 21, 22, 17), nan),
#    (datetime.datetime(2133, 2, 21, 23, 17), nan),
#    (datetime.datetime(2133, 2, 22, 0, 17), nan),
#    (datetime.datetime(2133, 2, 22, 1, 17), nan),
#    (datetime.datetime(2133, 2, 22, 2, 17), nan),
#    (datetime.datetime(2133, 2, 22, 3, 17), nan),
#    (datetime.datetime(2133, 2, 22, 4, 17), nan),
#    (datetime.datetime(2133, 2, 22, 5, 17), nan),
#    (datetime.datetime(2133, 2, 22, 6, 17), nan),
#    (datetime.datetime(2133, 2, 22, 7, 17), nan),
#    (datetime.datetime(2133, 2, 22, 8, 17), nan),
#    (datetime.datetime(2133, 2, 22, 9, 17), nan),
#    (datetime.datetime(2133, 2, 22, 10, 17), nan),
#    (datetime.datetime(2133, 2, 22, 11, 17), nan),
#    (datetime.datetime(2133, 2, 22, 12, 17), nan),
#    (datetime.datetime(2133, 2, 22, 13, 17), nan),
#    (datetime.datetime(2133, 2, 22, 14, 17), nan),
#    (datetime.datetime(2133, 2, 22, 15, 17), nan),
#    (datetime.datetime(2133, 2, 22, 16, 17), nan),
#    (datetime.datetime(2133, 2, 22, 17, 17), nan),
#    (datetime.datetime(2133, 2, 22, 18, 17), nan),
#    (datetime.datetime(2133, 2, 22, 19, 17), nan),
#    (datetime.datetime(2133, 2, 22, 20, 17), nan),
#    (datetime.datetime(2133, 2, 22, 21, 17), nan),
#    (datetime.datetime(2133, 2, 22, 22, 17), nan),
#    (datetime.datetime(2133, 2, 22, 23, 17), nan),
#    (datetime.datetime(2133, 2, 23, 0, 17), nan),
#    (datetime.datetime(2133, 2, 23, 1, 17), nan),
#    (datetime.datetime(2133, 2, 23, 2, 17), nan),
#    (datetime.datetime(2133, 2, 23, 3, 17), nan),
#    (datetime.datetime(2133, 2, 23, 4, 17), nan),
#    (datetime.datetime(2133, 2, 23, 5, 17), nan),
#    (datetime.datetime(2133, 2, 23, 6, 17), nan),
#    (datetime.datetime(2133, 2, 23, 7, 17), nan),
#    (datetime.datetime(2133, 2, 23, 8, 17), nan),
#    (datetime.datetime(2133, 2, 23, 9, 17), nan),
#    (datetime.datetime(2133, 2, 23, 10, 17), nan),
#    (datetime.datetime(2133, 2, 23, 11, 17), nan),
#    (datetime.datetime(2133, 2, 23, 12, 17), nan),
#    (datetime.datetime(2133, 2, 23, 13, 17), nan),
#    (datetime.datetime(2133, 2, 23, 14, 17), nan),
#    (datetime.datetime(2133, 2, 23, 15, 17), nan)],
#   'SBP': [(datetime.datetime(2133, 2, 16, 10, 17), 0.3068181818181818),
#    (datetime.datetime(2133, 2, 16, 11, 17), 0.3977272727272727),
#    (datetime.datetime(2133, 2, 16, 12, 17), 0.32196969696969696),
#    (datetime.datetime(2133, 2, 16, 13, 17), 0.4053030303030303),
#    (datetime.datetime(2133, 2, 16, 14, 17), 0.375),
#    (datetime.datetime(2133, 2, 16, 15, 17), 0.45075757575757575),
#    (datetime.datetime(2133, 2, 16, 16, 17), 0.5416666666666666),
#    (datetime.datetime(2133, 2, 16, 17, 17), 0.6553030303030303),
#    (datetime.datetime(2133, 2, 16, 18, 17), 0.7992424242424242),
#    (datetime.datetime(2133, 2, 16, 19, 17), 0.6553030303030303),
#    (datetime.datetime(2133, 2, 16, 20, 17), 0.7537878787878788),
#    (datetime.datetime(2133, 2, 16, 21, 17), 0.625),
#    (datetime.datetime(2133, 2, 16, 22, 17), 0.7613636363636364),
#    (datetime.datetime(2133, 2, 16, 23, 17), 0.8598484848484849),
#    (datetime.datetime(2133, 2, 17, 0, 17), 0.8901515151515151),
#    (datetime.datetime(2133, 2, 17, 1, 17), 0.928030303030303),
#    (datetime.datetime(2133, 2, 17, 2, 17), 0.9204545454545454),
#    (datetime.datetime(2133, 2, 17, 3, 17), 0.7613636363636364),
#    (datetime.datetime(2133, 2, 17, 4, 17), 0.7765151515151515),
#    (datetime.datetime(2133, 2, 17, 5, 17), 0.7234848484848485),
#    (datetime.datetime(2133, 2, 17, 6, 17), 0.7689393939393939),
#    (datetime.datetime(2133, 2, 17, 7, 17), 0.7689393939393939),
#    (datetime.datetime(2133, 2, 17, 8, 17), 0.8901515151515151),
#    (datetime.datetime(2133, 2, 17, 9, 17), 0.7007575757575758),
#    (datetime.datetime(2133, 2, 17, 10, 17), 0.6325757575757576),
#    (datetime.datetime(2133, 2, 17, 11, 17), 0.6022727272727273),
#    (datetime.datetime(2133, 2, 17, 12, 17), 0.6325757575757576),
#    (datetime.datetime(2133, 2, 17, 13, 17), 0.6477272727272727),
#    (datetime.datetime(2133, 2, 17, 14, 17), 0.7083333333333334),
#    (datetime.datetime(2133, 2, 17, 15, 17), 0.6098484848484849),
#    (datetime.datetime(2133, 2, 17, 16, 17), 0.7007575757575758),
#    (datetime.datetime(2133, 2, 17, 17, 17), 0.6553030303030303),
#    (datetime.datetime(2133, 2, 17, 18, 17), 0.6553030303030303),
#    (datetime.datetime(2133, 2, 17, 19, 17), 0.5113636363636364),
#    (datetime.datetime(2133, 2, 17, 20, 17), 0.6856060606060606),
#    (datetime.datetime(2133, 2, 17, 21, 17), 0.6856060606060606),
#    (datetime.datetime(2133, 2, 17, 22, 17), 0.4962121212121212),
#    (datetime.datetime(2133, 2, 17, 23, 17), 0.48863636363636365),
#    (datetime.datetime(2133, 2, 18, 0, 17), 0.42803030303030304),
#    (datetime.datetime(2133, 2, 18, 1, 17), 0.5037878787878788),
#    (datetime.datetime(2133, 2, 18, 2, 17), 0.6174242424242424),
#    (datetime.datetime(2133, 2, 18, 3, 17), 0.5568181818181818),
#    (datetime.datetime(2133, 2, 18, 4, 17), 0.5795454545454546),
#    (datetime.datetime(2133, 2, 18, 5, 17), 0.571969696969697),
#    (datetime.datetime(2133, 2, 18, 6, 17), 0.6098484848484849),
#    (datetime.datetime(2133, 2, 18, 7, 17), 0.571969696969697),
#    (datetime.datetime(2133, 2, 18, 8, 17), 0.5189393939393939),
#    (datetime.datetime(2133, 2, 18, 9, 17), 0.4734848484848485),
#    (datetime.datetime(2133, 2, 18, 10, 17), 0.4128787878787879),
#    (datetime.datetime(2133, 2, 18, 11, 17), 0.375),
#    (datetime.datetime(2133, 2, 18, 12, 17), 0.4659090909090909),
#    (datetime.datetime(2133, 2, 18, 13, 17), 0.5340909090909091),
#    (datetime.datetime(2133, 2, 18, 14, 17), 0.3522727272727273),
#    (datetime.datetime(2133, 2, 18, 15, 17), 0.4053030303030303),
#    (datetime.datetime(2133, 2, 18, 16, 17), 0.4583333333333333),
#    (datetime.datetime(2133, 2, 18, 17, 17), 0.5265151515151515),
#    (datetime.datetime(2133, 2, 18, 18, 17), 0.6325757575757576),
#    (datetime.datetime(2133, 2, 18, 19, 17), 0.6704545454545454),
#    (datetime.datetime(2133, 2, 18, 20, 17), 0.6628787878787878),
#    (datetime.datetime(2133, 2, 18, 21, 17), 0.7386363636363636),
#    (datetime.datetime(2133, 2, 18, 22, 17), 0.7386363636363636),
#    (datetime.datetime(2133, 2, 18, 23, 17), 0.5946969696969697),
#    (datetime.datetime(2133, 2, 19, 0, 17), 0.7083333333333334),
#    (datetime.datetime(2133, 2, 19, 1, 17), 0.7840909090909091),
#    (datetime.datetime(2133, 2, 19, 2, 17), 0.5946969696969697),
#    (datetime.datetime(2133, 2, 19, 3, 17), 0.6022727272727273),
#    (datetime.datetime(2133, 2, 19, 4, 17), 0.6022727272727273),
#    (datetime.datetime(2133, 2, 19, 5, 17), 0.5946969696969697),
#    (datetime.datetime(2133, 2, 19, 6, 17), nan),
#    (datetime.datetime(2133, 2, 19, 7, 17), 0.678030303030303),
#    (datetime.datetime(2133, 2, 19, 8, 17), 0.6856060606060606),
#    (datetime.datetime(2133, 2, 19, 9, 17), 0.678030303030303),
#    (datetime.datetime(2133, 2, 19, 10, 17), 0.7007575757575758),
#    (datetime.datetime(2133, 2, 19, 11, 17), 0.7083333333333334),
#    (datetime.datetime(2133, 2, 19, 12, 17), 0.571969696969697),
#    (datetime.datetime(2133, 2, 19, 13, 17), 0.5871212121212122),
#    (datetime.datetime(2133, 2, 19, 14, 17), 0.6477272727272727),
#    (datetime.datetime(2133, 2, 19, 15, 17), 0.571969696969697),
#    (datetime.datetime(2133, 2, 19, 16, 17), 0.6325757575757576),
#    (datetime.datetime(2133, 2, 19, 17, 17), 0.7689393939393939),
#    (datetime.datetime(2133, 2, 19, 18, 17), 0.6098484848484849),
#    (datetime.datetime(2133, 2, 19, 19, 17), 0.6098484848484849),
#    (datetime.datetime(2133, 2, 19, 20, 17), 0.7462121212121212),
#    (datetime.datetime(2133, 2, 19, 21, 17), 0.7083333333333334),
#    (datetime.datetime(2133, 2, 19, 22, 17), 0.5946969696969697),
#    (datetime.datetime(2133, 2, 19, 23, 17), 0.5643939393939394),
#    (datetime.datetime(2133, 2, 20, 0, 17), 0.5946969696969697),
#    (datetime.datetime(2133, 2, 20, 1, 17), 0.5871212121212122),
#    (datetime.datetime(2133, 2, 20, 2, 17), 0.6628787878787878),
#    (datetime.datetime(2133, 2, 20, 3, 17), 0.7159090909090909),
#    (datetime.datetime(2133, 2, 20, 4, 17), 0.7462121212121212),
#    (datetime.datetime(2133, 2, 20, 5, 17), 0.7765151515151515),
#    (datetime.datetime(2133, 2, 20, 6, 17), 0.6704545454545454),
#    (datetime.datetime(2133, 2, 20, 7, 17), 0.6553030303030303),
#    (datetime.datetime(2133, 2, 20, 8, 17), 0.6022727272727273),
#    (datetime.datetime(2133, 2, 20, 9, 17), 0.6022727272727273),
#    (datetime.datetime(2133, 2, 20, 10, 17), 0.5643939393939394),
#    (datetime.datetime(2133, 2, 20, 11, 17), 0.7310606060606061),
#    (datetime.datetime(2133, 2, 20, 12, 17), 0.6477272727272727),
#    (datetime.datetime(2133, 2, 20, 13, 17), 0.678030303030303),
#    (datetime.datetime(2133, 2, 20, 14, 17), 0.5037878787878788),
#    (datetime.datetime(2133, 2, 20, 15, 17), 0.6856060606060606),
#    (datetime.datetime(2133, 2, 20, 16, 17), 0.5871212121212122),
#    (datetime.datetime(2133, 2, 20, 17, 17), 0.571969696969697),
#    (datetime.datetime(2133, 2, 20, 18, 17), 0.5795454545454546),
#    (datetime.datetime(2133, 2, 20, 19, 17), 0.6931818181818182),
#    (datetime.datetime(2133, 2, 20, 20, 17), 0.7765151515151515),
#    (datetime.datetime(2133, 2, 20, 21, 17), 0.7765151515151515),
#    (datetime.datetime(2133, 2, 20, 22, 17), 0.8371212121212122),
#    (datetime.datetime(2133, 2, 20, 23, 17), 0.6325757575757576),
#    (datetime.datetime(2133, 2, 21, 0, 17), 0.6098484848484849),
#    (datetime.datetime(2133, 2, 21, 1, 17), 0.6174242424242424),
#    (datetime.datetime(2133, 2, 21, 2, 17), 0.8825757575757576),
#    (datetime.datetime(2133, 2, 21, 3, 17), 0.5871212121212122),
#    (datetime.datetime(2133, 2, 21, 4, 17), 0.7234848484848485),
#    (datetime.datetime(2133, 2, 21, 5, 17), 0.5643939393939394),
#    (datetime.datetime(2133, 2, 21, 6, 17), 0.678030303030303),
#    (datetime.datetime(2133, 2, 21, 7, 17), 0.6704545454545454),
#    (datetime.datetime(2133, 2, 21, 8, 17), 0.8295454545454546),
#    (datetime.datetime(2133, 2, 21, 9, 17), 0.7613636363636364),
#    (datetime.datetime(2133, 2, 21, 10, 17), 0.7159090909090909),
#    (datetime.datetime(2133, 2, 21, 11, 17), 0.7310606060606061),
#    (datetime.datetime(2133, 2, 21, 12, 17), 0.5037878787878788),
#    (datetime.datetime(2133, 2, 21, 13, 17), 0.5946969696969697),
#    (datetime.datetime(2133, 2, 21, 14, 17), 0.5113636363636364),
#    (datetime.datetime(2133, 2, 21, 15, 17), 0.5871212121212122),
#    (datetime.datetime(2133, 2, 21, 16, 17), 0.6325757575757576),
#    (datetime.datetime(2133, 2, 21, 17, 17), 0.8522727272727273),
#    (datetime.datetime(2133, 2, 21, 18, 17), 0.6704545454545454),
#    (datetime.datetime(2133, 2, 21, 19, 17), 0.5946969696969697),
#    (datetime.datetime(2133, 2, 21, 20, 17), 0.6022727272727273),
#    (datetime.datetime(2133, 2, 21, 21, 17), 0.6553030303030303),
#    (datetime.datetime(2133, 2, 21, 22, 17), 0.6477272727272727),
#    (datetime.datetime(2133, 2, 21, 23, 17), 0.7159090909090909),
#    (datetime.datetime(2133, 2, 22, 0, 17), 0.6931818181818182),
#    (datetime.datetime(2133, 2, 22, 1, 17), 0.7159090909090909),
#    (datetime.datetime(2133, 2, 22, 2, 17), 0.7840909090909091),
#    (datetime.datetime(2133, 2, 22, 3, 17), 0.7765151515151515),
#    (datetime.datetime(2133, 2, 22, 4, 17), 0.7992424242424242),
#    (datetime.datetime(2133, 2, 22, 5, 17), 0.5189393939393939),
#    (datetime.datetime(2133, 2, 22, 6, 17), 0.7007575757575758),
#    (datetime.datetime(2133, 2, 22, 7, 17), 0.7765151515151515),
#    (datetime.datetime(2133, 2, 22, 8, 17), 0.6856060606060606),
#    (datetime.datetime(2133, 2, 22, 9, 17), 0.7159090909090909),
#    (datetime.datetime(2133, 2, 22, 10, 17), 0.7007575757575758),
#    (datetime.datetime(2133, 2, 22, 11, 17), 0.7007575757575758),
#    (datetime.datetime(2133, 2, 22, 12, 17), 0.7234848484848485),
#    (datetime.datetime(2133, 2, 22, 13, 17), 0.7007575757575758),
#    (datetime.datetime(2133, 2, 22, 14, 17), 0.678030303030303),
#    (datetime.datetime(2133, 2, 22, 15, 17), 0.7310606060606061),
#    (datetime.datetime(2133, 2, 22, 16, 17), 0.5568181818181818),
#    (datetime.datetime(2133, 2, 22, 17, 17), 0.6022727272727273),
#    (datetime.datetime(2133, 2, 22, 18, 17), 0.5871212121212122),
#    (datetime.datetime(2133, 2, 22, 19, 17), 0.6325757575757576),
#    (datetime.datetime(2133, 2, 22, 20, 17), 0.7007575757575758),
#    (datetime.datetime(2133, 2, 22, 21, 17), 0.6856060606060606),
#    (datetime.datetime(2133, 2, 22, 22, 17), 0.6628787878787878),
#    (datetime.datetime(2133, 2, 22, 23, 17), 0.5568181818181818),
#    (datetime.datetime(2133, 2, 23, 0, 17), 0.6477272727272727),
#    (datetime.datetime(2133, 2, 23, 1, 17), 0.5946969696969697),
#    (datetime.datetime(2133, 2, 23, 2, 17), 0.7992424242424242),
#    (datetime.datetime(2133, 2, 23, 3, 17), 0.6022727272727273),
#    (datetime.datetime(2133, 2, 23, 4, 17), 0.7007575757575758),
#    (datetime.datetime(2133, 2, 23, 5, 17), 0.7537878787878788),
#    (datetime.datetime(2133, 2, 23, 6, 17), 0.8825757575757576),
#    (datetime.datetime(2133, 2, 23, 7, 17), 0.821969696969697),
#    (datetime.datetime(2133, 2, 23, 8, 17), 0.7916666666666666),
#    (datetime.datetime(2133, 2, 23, 9, 17), 0.6704545454545454),
#    (datetime.datetime(2133, 2, 23, 10, 17), 0.6628787878787878),
#    (datetime.datetime(2133, 2, 23, 11, 17), 0.8522727272727273),
#    (datetime.datetime(2133, 2, 23, 12, 17), 0.7083333333333334),
#    (datetime.datetime(2133, 2, 23, 13, 17), 0.7916666666666666),
#    (datetime.datetime(2133, 2, 23, 14, 17), nan),
#    (datetime.datetime(2133, 2, 23, 15, 17), 0.7613636363636364)],
#   'DBP': [(datetime.datetime(2133, 2, 16, 10, 17), 0.5197368421052632),
#    (datetime.datetime(2133, 2, 16, 11, 17), 0.625),
#    (datetime.datetime(2133, 2, 16, 12, 17), 0.5592105263157895),
#    (datetime.datetime(2133, 2, 16, 13, 17), 0.6381578947368421),
#    (datetime.datetime(2133, 2, 16, 14, 17), 0.5328947368421053),
#    (datetime.datetime(2133, 2, 16, 15, 17), 0.6776315789473685),
#    (datetime.datetime(2133, 2, 16, 16, 17), 0.7697368421052632),
#    (datetime.datetime(2133, 2, 16, 17, 17), 0.8881578947368421),
#    (datetime.datetime(2133, 2, 16, 18, 17), 0.875),
#    (datetime.datetime(2133, 2, 16, 19, 17), 0.5986842105263158),
#    (datetime.datetime(2133, 2, 16, 20, 17), 0.6644736842105263),
#    (datetime.datetime(2133, 2, 16, 21, 17), 0.5592105263157895),
#    (datetime.datetime(2133, 2, 16, 22, 17), 0.875),
#    (datetime.datetime(2133, 2, 16, 23, 17), 0.8486842105263158),
#    (datetime.datetime(2133, 2, 17, 0, 17), 0.875),
#    (datetime.datetime(2133, 2, 17, 1, 17), 0.9407894736842105),
#    (datetime.datetime(2133, 2, 17, 2, 17), 0.9013157894736842),
#    (datetime.datetime(2133, 2, 17, 3, 17), 0.7960526315789473),
#    (datetime.datetime(2133, 2, 17, 4, 17), 0.8092105263157895),
#    (datetime.datetime(2133, 2, 17, 5, 17), 0.7697368421052632),
#    (datetime.datetime(2133, 2, 17, 6, 17), 0.8486842105263158),
#    (datetime.datetime(2133, 2, 17, 7, 17), 0.8618421052631579),
#    (datetime.datetime(2133, 2, 17, 8, 17), 0.9013157894736842),
#    (datetime.datetime(2133, 2, 17, 9, 17), 0.7960526315789473),
#    (datetime.datetime(2133, 2, 17, 10, 17), 0.7302631578947368),
#    (datetime.datetime(2133, 2, 17, 11, 17), 0.7171052631578947),
#    (datetime.datetime(2133, 2, 17, 12, 17), 0.756578947368421),
#    (datetime.datetime(2133, 2, 17, 13, 17), 0.7828947368421053),
#    (datetime.datetime(2133, 2, 17, 14, 17), 0.8486842105263158),
#    (datetime.datetime(2133, 2, 17, 15, 17), 0.743421052631579),
#    (datetime.datetime(2133, 2, 17, 16, 17), 0.7960526315789473),
#    (datetime.datetime(2133, 2, 17, 17, 17), 0.756578947368421),
#    (datetime.datetime(2133, 2, 17, 18, 17), 0.8092105263157895),
#    (datetime.datetime(2133, 2, 17, 19, 17), 0.6381578947368421),
#    (datetime.datetime(2133, 2, 17, 20, 17), 0.7697368421052632),
#    (datetime.datetime(2133, 2, 17, 21, 17), 0.743421052631579),
#    (datetime.datetime(2133, 2, 17, 22, 17), 0.6381578947368421),
#    (datetime.datetime(2133, 2, 17, 23, 17), 0.6118421052631579),
#    (datetime.datetime(2133, 2, 18, 0, 17), 0.5328947368421053),
#    (datetime.datetime(2133, 2, 18, 1, 17), 0.5723684210526315),
#    (datetime.datetime(2133, 2, 18, 2, 17), 0.7302631578947368),
#    (datetime.datetime(2133, 2, 18, 3, 17), 0.625),
#    (datetime.datetime(2133, 2, 18, 4, 17), 0.6644736842105263),
#    (datetime.datetime(2133, 2, 18, 5, 17), 0.6513157894736842),
#    (datetime.datetime(2133, 2, 18, 6, 17), 0.743421052631579),
#    (datetime.datetime(2133, 2, 18, 7, 17), 0.7171052631578947),
#    (datetime.datetime(2133, 2, 18, 8, 17), 0.6644736842105263),
#    (datetime.datetime(2133, 2, 18, 9, 17), 0.6118421052631579),
#    (datetime.datetime(2133, 2, 18, 10, 17), 0.5460526315789473),
#    (datetime.datetime(2133, 2, 18, 11, 17), 0.46710526315789475),
#    (datetime.datetime(2133, 2, 18, 12, 17), 0.5592105263157895),
#    (datetime.datetime(2133, 2, 18, 13, 17), 0.7171052631578947),
#    (datetime.datetime(2133, 2, 18, 14, 17), 0.48026315789473684),
#    (datetime.datetime(2133, 2, 18, 15, 17), 0.48026315789473684),
#    (datetime.datetime(2133, 2, 18, 16, 17), 0.5328947368421053),
#    (datetime.datetime(2133, 2, 18, 17, 17), 0.625),
#    (datetime.datetime(2133, 2, 18, 18, 17), 0.7697368421052632),
#    (datetime.datetime(2133, 2, 18, 19, 17), 0.8092105263157895),
#    (datetime.datetime(2133, 2, 18, 20, 17), 0.7960526315789473),
#    (datetime.datetime(2133, 2, 18, 21, 17), 0.8618421052631579),
#    (datetime.datetime(2133, 2, 18, 22, 17), 0.8223684210526315),
#    (datetime.datetime(2133, 2, 18, 23, 17), 0.6776315789473685),
#    (datetime.datetime(2133, 2, 19, 0, 17), 0.8092105263157895),
#    (datetime.datetime(2133, 2, 19, 1, 17), 0.7697368421052632),
#    (datetime.datetime(2133, 2, 19, 2, 17), 0.6118421052631579),
#    (datetime.datetime(2133, 2, 19, 3, 17), 0.6513157894736842),
#    (datetime.datetime(2133, 2, 19, 4, 17), 0.7039473684210527),
#    (datetime.datetime(2133, 2, 19, 5, 17), 0.6776315789473685),
#    (datetime.datetime(2133, 2, 19, 6, 17), nan),
#    (datetime.datetime(2133, 2, 19, 7, 17), 0.756578947368421),
#    (datetime.datetime(2133, 2, 19, 8, 17), 0.7828947368421053),
#    (datetime.datetime(2133, 2, 19, 9, 17), 0.8355263157894737),
#    (datetime.datetime(2133, 2, 19, 10, 17), 0.8486842105263158),
#    (datetime.datetime(2133, 2, 19, 11, 17), 0.8092105263157895),
#    (datetime.datetime(2133, 2, 19, 12, 17), 0.625),
#    (datetime.datetime(2133, 2, 19, 13, 17), 0.7039473684210527),
#    (datetime.datetime(2133, 2, 19, 14, 17), 0.7697368421052632),
#    (datetime.datetime(2133, 2, 19, 15, 17), 0.8223684210526315),
#    (datetime.datetime(2133, 2, 19, 16, 17), 0.7302631578947368),
#    (datetime.datetime(2133, 2, 19, 17, 17), 0.9013157894736842),
#    (datetime.datetime(2133, 2, 19, 18, 17), 0.7039473684210527),
#    (datetime.datetime(2133, 2, 19, 19, 17), 0.743421052631579),
#    (datetime.datetime(2133, 2, 19, 20, 17), 0.9144736842105263),
#    (datetime.datetime(2133, 2, 19, 21, 17), 0.8092105263157895),
#    (datetime.datetime(2133, 2, 19, 22, 17), 0.7039473684210527),
#    (datetime.datetime(2133, 2, 19, 23, 17), 0.6776315789473685),
#    (datetime.datetime(2133, 2, 20, 0, 17), 0.7039473684210527),
#    (datetime.datetime(2133, 2, 20, 1, 17), 0.6907894736842105),
#    (datetime.datetime(2133, 2, 20, 2, 17), 0.756578947368421),
#    (datetime.datetime(2133, 2, 20, 3, 17), 0.875),
#    (datetime.datetime(2133, 2, 20, 4, 17), 0.875),
#    (datetime.datetime(2133, 2, 20, 5, 17), 0.9013157894736842),
#    (datetime.datetime(2133, 2, 20, 6, 17), 0.7828947368421053),
#    (datetime.datetime(2133, 2, 20, 7, 17), 0.756578947368421),
#    (datetime.datetime(2133, 2, 20, 8, 17), 0.756578947368421),
#    (datetime.datetime(2133, 2, 20, 9, 17), 0.756578947368421),
#    (datetime.datetime(2133, 2, 20, 10, 17), 0.7039473684210527),
#    (datetime.datetime(2133, 2, 20, 11, 17), 1.3092105263157894),
#    (datetime.datetime(2133, 2, 20, 12, 17), 0.7960526315789473),
#    (datetime.datetime(2133, 2, 20, 13, 17), 0.8223684210526315),
#    (datetime.datetime(2133, 2, 20, 14, 17), 0.7039473684210527),
#    (datetime.datetime(2133, 2, 20, 15, 17), 0.8486842105263158),
#    (datetime.datetime(2133, 2, 20, 16, 17), 0.8618421052631579),
#    (datetime.datetime(2133, 2, 20, 17, 17), 0.7828947368421053),
#    (datetime.datetime(2133, 2, 20, 18, 17), 0.8486842105263158),
#    (datetime.datetime(2133, 2, 20, 19, 17), 0.7697368421052632),
#    (datetime.datetime(2133, 2, 20, 20, 17), 0.8355263157894737),
#    (datetime.datetime(2133, 2, 20, 21, 17), 0.8486842105263158),
#    (datetime.datetime(2133, 2, 20, 22, 17), 0.8618421052631579),
#    (datetime.datetime(2133, 2, 20, 23, 17), 0.7697368421052632),
#    (datetime.datetime(2133, 2, 21, 0, 17), 0.7697368421052632),
#    (datetime.datetime(2133, 2, 21, 1, 17), 0.7171052631578947),
#    (datetime.datetime(2133, 2, 21, 2, 17), 1.8355263157894737),
#    (datetime.datetime(2133, 2, 21, 3, 17), 0.7039473684210527),
#    (datetime.datetime(2133, 2, 21, 4, 17), 0.9144736842105263),
#    (datetime.datetime(2133, 2, 21, 5, 17), 0.7171052631578947),
#    (datetime.datetime(2133, 2, 21, 6, 17), 0.7960526315789473),
#    (datetime.datetime(2133, 2, 21, 7, 17), 0.7697368421052632),
#    (datetime.datetime(2133, 2, 21, 8, 17), 0.9013157894736842),
#    (datetime.datetime(2133, 2, 21, 9, 17), 0.9013157894736842),
#    (datetime.datetime(2133, 2, 21, 10, 17), 0.875),
#    (datetime.datetime(2133, 2, 21, 11, 17), 0.8355263157894737),
#    (datetime.datetime(2133, 2, 21, 12, 17), 0.6513157894736842),
#    (datetime.datetime(2133, 2, 21, 13, 17), 0.756578947368421),
#    (datetime.datetime(2133, 2, 21, 14, 17), 0.6907894736842105),
#    (datetime.datetime(2133, 2, 21, 15, 17), 0.6644736842105263),
#    (datetime.datetime(2133, 2, 21, 16, 17), 0.743421052631579),
#    (datetime.datetime(2133, 2, 21, 17, 17), 1.019736842105263),
#    (datetime.datetime(2133, 2, 21, 18, 17), 1.5460526315789473),
#    (datetime.datetime(2133, 2, 21, 19, 17), 1.138157894736842),
#    (datetime.datetime(2133, 2, 21, 20, 17), 0.9144736842105263),
#    (datetime.datetime(2133, 2, 21, 21, 17), 0.8618421052631579),
#    (datetime.datetime(2133, 2, 21, 22, 17), 0.7828947368421053),
#    (datetime.datetime(2133, 2, 21, 23, 17), 0.8355263157894737),
#    (datetime.datetime(2133, 2, 22, 0, 17), 0.8486842105263158),
#    (datetime.datetime(2133, 2, 22, 1, 17), 0.8618421052631579),
#    (datetime.datetime(2133, 2, 22, 2, 17), 0.8486842105263158),
#    (datetime.datetime(2133, 2, 22, 3, 17), 0.8355263157894737),
#    (datetime.datetime(2133, 2, 22, 4, 17), 0.8355263157894737),
#    (datetime.datetime(2133, 2, 22, 5, 17), 1.243421052631579),
#    (datetime.datetime(2133, 2, 22, 6, 17), 1.125),
#    (datetime.datetime(2133, 2, 22, 7, 17), 0.8486842105263158),
#    (datetime.datetime(2133, 2, 22, 8, 17), 0.756578947368421),
#    (datetime.datetime(2133, 2, 22, 9, 17), 0.8881578947368421),
#    (datetime.datetime(2133, 2, 22, 10, 17), 0.8355263157894737),
#    (datetime.datetime(2133, 2, 22, 11, 17), 0.8223684210526315),
#    (datetime.datetime(2133, 2, 22, 12, 17), 0.8092105263157895),
#    (datetime.datetime(2133, 2, 22, 13, 17), 0.7697368421052632),
#    (datetime.datetime(2133, 2, 22, 14, 17), 0.7302631578947368),
#    (datetime.datetime(2133, 2, 22, 15, 17), 0.756578947368421),
#    (datetime.datetime(2133, 2, 22, 16, 17), 0.7039473684210527),
#    (datetime.datetime(2133, 2, 22, 17, 17), 0.7302631578947368),
#    (datetime.datetime(2133, 2, 22, 18, 17), 0.6776315789473685),
#    (datetime.datetime(2133, 2, 22, 19, 17), 0.7171052631578947),
#    (datetime.datetime(2133, 2, 22, 20, 17), 0.7697368421052632),
#    (datetime.datetime(2133, 2, 22, 21, 17), 1.138157894736842),
#    (datetime.datetime(2133, 2, 22, 22, 17), 0.7697368421052632),
#    (datetime.datetime(2133, 2, 22, 23, 17), 0.7171052631578947),
#    (datetime.datetime(2133, 2, 23, 0, 17), 0.7960526315789473),
#    (datetime.datetime(2133, 2, 23, 1, 17), 0.756578947368421),
#    (datetime.datetime(2133, 2, 23, 2, 17), 0.9144736842105263),
#    (datetime.datetime(2133, 2, 23, 3, 17), 0.7697368421052632),
#    (datetime.datetime(2133, 2, 23, 4, 17), 0.8486842105263158),
#    (datetime.datetime(2133, 2, 23, 5, 17), 0.8881578947368421),
#    (datetime.datetime(2133, 2, 23, 6, 17), 0.993421052631579),
#    (datetime.datetime(2133, 2, 23, 7, 17), 0.875),
#    (datetime.datetime(2133, 2, 23, 8, 17), 0.8618421052631579),
#    (datetime.datetime(2133, 2, 23, 9, 17), 0.7697368421052632),
#    (datetime.datetime(2133, 2, 23, 10, 17), 0.7960526315789473),
#    (datetime.datetime(2133, 2, 23, 11, 17), 0.9407894736842105),
#    (datetime.datetime(2133, 2, 23, 12, 17), 0.8355263157894737),
#    (datetime.datetime(2133, 2, 23, 13, 17), 0.8618421052631579),
#    (datetime.datetime(2133, 2, 23, 14, 17), nan),
#    (datetime.datetime(2133, 2, 23, 15, 17), 0.9276315789473685)],
#   'FiO2': [(datetime.datetime(2133, 2, 16, 10, 17), 0.375),
#    (datetime.datetime(2133, 2, 16, 11, 17), nan),
#    (datetime.datetime(2133, 2, 16, 12, 17), 0.37689393928133685),
#    (datetime.datetime(2133, 2, 16, 13, 17), nan),
#    (datetime.datetime(2133, 2, 16, 14, 17), nan),
#    (datetime.datetime(2133, 2, 16, 15, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 16, 16, 17), nan),
#    (datetime.datetime(2133, 2, 16, 17, 17), nan),
#    (datetime.datetime(2133, 2, 16, 18, 17), nan),
#    (datetime.datetime(2133, 2, 16, 19, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 16, 20, 17), nan),
#    (datetime.datetime(2133, 2, 16, 21, 17), nan),
#    (datetime.datetime(2133, 2, 16, 22, 17), nan),
#    (datetime.datetime(2133, 2, 16, 23, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 17, 0, 17), nan),
#    (datetime.datetime(2133, 2, 17, 1, 17), nan),
#    (datetime.datetime(2133, 2, 17, 2, 17), nan),
#    (datetime.datetime(2133, 2, 17, 3, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 17, 4, 17), nan),
#    (datetime.datetime(2133, 2, 17, 5, 17), nan),
#    (datetime.datetime(2133, 2, 17, 6, 17), nan),
#    (datetime.datetime(2133, 2, 17, 7, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 17, 8, 17), nan),
#    (datetime.datetime(2133, 2, 17, 9, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 17, 10, 17), nan),
#    (datetime.datetime(2133, 2, 17, 11, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 17, 12, 17), nan),
#    (datetime.datetime(2133, 2, 17, 13, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 17, 14, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 17, 15, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 17, 16, 17), nan),
#    (datetime.datetime(2133, 2, 17, 17, 17), nan),
#    (datetime.datetime(2133, 2, 17, 18, 17), nan),
#    (datetime.datetime(2133, 2, 17, 19, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 17, 20, 17), nan),
#    (datetime.datetime(2133, 2, 17, 21, 17), nan),
#    (datetime.datetime(2133, 2, 17, 22, 17), nan),
#    (datetime.datetime(2133, 2, 17, 23, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 18, 0, 17), nan),
#    (datetime.datetime(2133, 2, 18, 1, 17), nan),
#    (datetime.datetime(2133, 2, 18, 2, 17), nan),
#    (datetime.datetime(2133, 2, 18, 3, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 18, 4, 17), nan),
#    (datetime.datetime(2133, 2, 18, 5, 17), nan),
#    (datetime.datetime(2133, 2, 18, 6, 17), nan),
#    (datetime.datetime(2133, 2, 18, 7, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 18, 8, 17), nan),
#    (datetime.datetime(2133, 2, 18, 9, 17), nan),
#    (datetime.datetime(2133, 2, 18, 10, 17), nan),
#    (datetime.datetime(2133, 2, 18, 11, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 18, 12, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 18, 13, 17), nan),
#    (datetime.datetime(2133, 2, 18, 14, 17), nan),
#    (datetime.datetime(2133, 2, 18, 15, 17), 0.3787878787508197),
#    (datetime.datetime(2133, 2, 18, 16, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 18, 17, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 18, 18, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 18, 19, 17), nan),
#    (datetime.datetime(2133, 2, 18, 20, 17), nan),
#    (datetime.datetime(2133, 2, 18, 21, 17), nan),
#    (datetime.datetime(2133, 2, 18, 22, 17), nan),
#    (datetime.datetime(2133, 2, 18, 23, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 19, 0, 17), nan),
#    (datetime.datetime(2133, 2, 19, 1, 17), nan),
#    (datetime.datetime(2133, 2, 19, 2, 17), nan),
#    (datetime.datetime(2133, 2, 19, 3, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 19, 4, 17), nan),
#    (datetime.datetime(2133, 2, 19, 5, 17), nan),
#    (datetime.datetime(2133, 2, 19, 6, 17), nan),
#    (datetime.datetime(2133, 2, 19, 7, 17), nan),
#    (datetime.datetime(2133, 2, 19, 8, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 19, 9, 17), nan),
#    (datetime.datetime(2133, 2, 19, 10, 17), nan),
#    (datetime.datetime(2133, 2, 19, 11, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 19, 12, 17), nan),
#    (datetime.datetime(2133, 2, 19, 13, 17), nan),
#    (datetime.datetime(2133, 2, 19, 14, 17), nan),
#    (datetime.datetime(2133, 2, 19, 15, 17), nan),
#    (datetime.datetime(2133, 2, 19, 16, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 19, 17, 17), nan),
#    (datetime.datetime(2133, 2, 19, 18, 17), nan),
#    (datetime.datetime(2133, 2, 19, 19, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 19, 20, 17), nan),
#    (datetime.datetime(2133, 2, 19, 21, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 19, 22, 17), nan),
#    (datetime.datetime(2133, 2, 19, 23, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 20, 0, 17), nan),
#    (datetime.datetime(2133, 2, 20, 1, 17), nan),
#    (datetime.datetime(2133, 2, 20, 2, 17), nan),
#    (datetime.datetime(2133, 2, 20, 3, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 20, 4, 17), nan),
#    (datetime.datetime(2133, 2, 20, 5, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 20, 6, 17), nan),
#    (datetime.datetime(2133, 2, 20, 7, 17), 0.37563131309377895),
#    (datetime.datetime(2133, 2, 20, 8, 17), nan),
#    (datetime.datetime(2133, 2, 20, 9, 17), 0.375),
#    (datetime.datetime(2133, 2, 20, 10, 17), nan),
#    (datetime.datetime(2133, 2, 20, 11, 17), 0.375),
#    (datetime.datetime(2133, 2, 20, 12, 17), nan),
#    (datetime.datetime(2133, 2, 20, 13, 17), 0.375),
#    (datetime.datetime(2133, 2, 20, 14, 17), nan),
#    (datetime.datetime(2133, 2, 20, 15, 17), 0.375),
#    (datetime.datetime(2133, 2, 20, 16, 17), nan),
#    (datetime.datetime(2133, 2, 20, 17, 17), 0.375),
#    (datetime.datetime(2133, 2, 20, 18, 17), nan),
#    (datetime.datetime(2133, 2, 20, 19, 17), 0.375),
#    (datetime.datetime(2133, 2, 20, 20, 17), nan),
# ...
#    (datetime.datetime(2133, 4, 29, 5, 45), nan),
#    (datetime.datetime(2133, 4, 29, 6, 45), nan),
#    (datetime.datetime(2133, 4, 29, 7, 45), nan),
#    (datetime.datetime(2133, 4, 29, 8, 45), nan),
#    (datetime.datetime(2133, 4, 29, 9, 45), nan),
#    (datetime.datetime(2133, 4, 29, 10, 45), 0.16346152126369054),
#    (datetime.datetime(2133, 4, 29, 11, 45), nan),
#    (datetime.datetime(2133, 4, 29, 12, 45), nan),
#    (datetime.datetime(2133, 4, 29, 13, 45), nan),
#    (datetime.datetime(2133, 4, 29, 14, 45), nan),
#    (datetime.datetime(2133, 4, 29, 15, 45), nan),
#    (datetime.datetime(2133, 4, 29, 16, 45), 0.18910254941273563),
#    (datetime.datetime(2133, 4, 29, 17, 45), nan),
#    (datetime.datetime(2133, 4, 29, 18, 45), nan),
#    (datetime.datetime(2133, 4, 29, 19, 45), nan),
#    (datetime.datetime(2133, 4, 29, 20, 45), nan),
#    (datetime.datetime(2133, 4, 29, 21, 45), nan),
#    (datetime.datetime(2133, 4, 29, 22, 45), nan),
#    (datetime.datetime(2133, 4, 29, 23, 45), nan),
#    (datetime.datetime(2133, 4, 30, 0, 45), nan),
#    (datetime.datetime(2133, 4, 30, 1, 45), nan),
#    (datetime.datetime(2133, 4, 30, 2, 45), 0.19642855745532006),
#    (datetime.datetime(2133, 4, 30, 3, 45), nan),
#    (datetime.datetime(2133, 4, 30, 4, 45), nan),
#    (datetime.datetime(2133, 4, 30, 5, 45), nan),
#    (datetime.datetime(2133, 4, 30, 6, 45), nan),
#    (datetime.datetime(2133, 4, 30, 7, 45), nan),
#    (datetime.datetime(2133, 4, 30, 8, 45), nan),
#    (datetime.datetime(2133, 4, 30, 9, 45), nan),
#    (datetime.datetime(2133, 4, 30, 10, 45), nan),
#    (datetime.datetime(2133, 4, 30, 11, 45), nan),
#    (datetime.datetime(2133, 4, 30, 12, 45), nan),
#    (datetime.datetime(2133, 4, 30, 13, 45), nan),
#    (datetime.datetime(2133, 4, 30, 14, 45), nan),
#    (datetime.datetime(2133, 4, 30, 15, 45), nan),
#    (datetime.datetime(2133, 4, 30, 16, 45), nan),
#    (datetime.datetime(2133, 4, 30, 17, 45), nan),
#    (datetime.datetime(2133, 4, 30, 18, 45), nan),
#    (datetime.datetime(2133, 4, 30, 19, 45), nan),
#    (datetime.datetime(2133, 4, 30, 20, 45), nan),
#    (datetime.datetime(2133, 4, 30, 21, 45), nan),
#    (datetime.datetime(2133, 4, 30, 22, 45), nan),
#    (datetime.datetime(2133, 4, 30, 23, 45), nan),
#    (datetime.datetime(2133, 5, 1, 0, 45), nan),
#    (datetime.datetime(2133, 5, 1, 1, 45), nan),
#    (datetime.datetime(2133, 5, 1, 2, 45), 0.19642855745532006),
#    (datetime.datetime(2133, 5, 1, 3, 45), nan),
#    (datetime.datetime(2133, 5, 1, 4, 45), nan),
#    (datetime.datetime(2133, 5, 1, 5, 45), nan),
#    (datetime.datetime(2133, 5, 1, 6, 45), nan),
#    (datetime.datetime(2133, 5, 1, 7, 45), nan),
#    (datetime.datetime(2133, 5, 1, 8, 45), nan),
#    (datetime.datetime(2133, 5, 1, 9, 45), nan),
#    (datetime.datetime(2133, 5, 1, 10, 45), nan),
#    (datetime.datetime(2133, 5, 1, 11, 45), nan),
#    (datetime.datetime(2133, 5, 1, 12, 45), nan),
#    (datetime.datetime(2133, 5, 1, 13, 45), nan),
#    (datetime.datetime(2133, 5, 1, 14, 45), nan),
#    (datetime.datetime(2133, 5, 1, 15, 45), nan),
#    (datetime.datetime(2133, 5, 1, 16, 45), nan),
#    (datetime.datetime(2133, 5, 1, 17, 45), nan),
#    (datetime.datetime(2133, 5, 1, 18, 45), nan),
#    (datetime.datetime(2133, 5, 1, 19, 45), nan),
#    (datetime.datetime(2133, 5, 1, 20, 45), nan),
#    (datetime.datetime(2133, 5, 1, 21, 45), nan),
#    (datetime.datetime(2133, 5, 1, 22, 45), nan),
#    (datetime.datetime(2133, 5, 1, 23, 45), nan),
#    (datetime.datetime(2133, 5, 2, 0, 45), nan),
#    (datetime.datetime(2133, 5, 2, 1, 45), 0.10851646094430811),
#    (datetime.datetime(2133, 5, 2, 2, 45), nan),
#    (datetime.datetime(2133, 5, 2, 3, 45), nan),
#    (datetime.datetime(2133, 5, 2, 4, 45), nan),
#    (datetime.datetime(2133, 5, 2, 5, 45), nan),
#    (datetime.datetime(2133, 5, 2, 6, 45), nan),
#    (datetime.datetime(2133, 5, 2, 7, 45), nan),
#    (datetime.datetime(2133, 5, 2, 8, 45), nan),
#    (datetime.datetime(2133, 5, 2, 9, 45), nan),
#    (datetime.datetime(2133, 5, 2, 10, 45), nan),
#    (datetime.datetime(2133, 5, 2, 11, 45), 0.1158424689868924),
#    (datetime.datetime(2133, 5, 2, 12, 45), nan),
#    (datetime.datetime(2133, 5, 2, 13, 45), 0.17078752930627483),
#    (datetime.datetime(2133, 5, 2, 14, 45), nan),
#    (datetime.datetime(2133, 5, 2, 15, 45), nan),
#    (datetime.datetime(2133, 5, 2, 16, 45), nan),
#    (datetime.datetime(2133, 5, 2, 17, 45), nan),
#    (datetime.datetime(2133, 5, 2, 18, 45), nan),
#    (datetime.datetime(2133, 5, 2, 19, 45), nan),
#    (datetime.datetime(2133, 5, 2, 20, 45), nan),
#    (datetime.datetime(2133, 5, 2, 21, 45), nan),
#    (datetime.datetime(2133, 5, 2, 22, 45), nan),
#    (datetime.datetime(2133, 5, 2, 23, 45), nan),
#    (datetime.datetime(2133, 5, 3, 0, 45), nan),
#    (datetime.datetime(2133, 5, 3, 1, 45), 0.32829670222183777),
#    (datetime.datetime(2133, 5, 3, 2, 45), nan),
#    (datetime.datetime(2133, 5, 3, 3, 45), nan),
#    (datetime.datetime(2133, 5, 3, 4, 45), nan),
#    (datetime.datetime(2133, 5, 3, 5, 45), nan),
#    (datetime.datetime(2133, 5, 3, 6, 45), nan),
#    (datetime.datetime(2133, 5, 3, 7, 45), nan),
#    (datetime.datetime(2133, 5, 3, 8, 45), nan),
#    (datetime.datetime(2133, 5, 3, 9, 45), nan),
#    (datetime.datetime(2133, 5, 3, 10, 45), nan),
#    (datetime.datetime(2133, 5, 3, 11, 45), nan),
#    (datetime.datetime(2133, 5, 3, 12, 45), nan),
#    (datetime.datetime(2133, 5, 3, 13, 45), nan),
#    (datetime.datetime(2133, 5, 3, 14, 45), nan),
#    (datetime.datetime(2133, 5, 3, 15, 45), nan),
#    (datetime.datetime(2133, 5, 3, 16, 45), nan),
#    (datetime.datetime(2133, 5, 3, 17, 45), nan),
#    (datetime.datetime(2133, 5, 3, 18, 45), nan),
#    (datetime.datetime(2133, 5, 3, 19, 45), nan),
#    (datetime.datetime(2133, 5, 3, 20, 45), nan),
#    (datetime.datetime(2133, 5, 3, 21, 45), nan),
#    (datetime.datetime(2133, 5, 3, 22, 45), nan),
#    (datetime.datetime(2133, 5, 3, 23, 45), nan),
#    (datetime.datetime(2133, 5, 4, 0, 45), nan),
#    (datetime.datetime(2133, 5, 4, 1, 45), 0.3795787585199281),
#    (datetime.datetime(2133, 5, 4, 2, 45), nan),
#    (datetime.datetime(2133, 5, 4, 3, 45), nan),
#    (datetime.datetime(2133, 5, 4, 4, 45), nan),
#    (datetime.datetime(2133, 5, 4, 5, 45), nan),
#    (datetime.datetime(2133, 5, 4, 6, 45), nan),
#    (datetime.datetime(2133, 5, 4, 7, 45), nan),
#    (datetime.datetime(2133, 5, 4, 8, 45), nan),
#    (datetime.datetime(2133, 5, 4, 9, 45), nan),
#    (datetime.datetime(2133, 5, 4, 10, 45), nan),
#    (datetime.datetime(2133, 5, 4, 11, 45), nan),
#    (datetime.datetime(2133, 5, 4, 12, 45), nan),
#    (datetime.datetime(2133, 5, 4, 13, 45), nan),
#    (datetime.datetime(2133, 5, 4, 14, 45), nan),
#    (datetime.datetime(2133, 5, 4, 15, 45), nan),
#    (datetime.datetime(2133, 5, 4, 16, 45), nan),
#    (datetime.datetime(2133, 5, 4, 17, 45), nan),
#    (datetime.datetime(2133, 5, 4, 18, 45), nan),
#    (datetime.datetime(2133, 5, 4, 19, 45), nan),
#    (datetime.datetime(2133, 5, 4, 20, 45), nan),
#    (datetime.datetime(2133, 5, 4, 21, 45), nan),
#    (datetime.datetime(2133, 5, 4, 22, 45), nan),
#    (datetime.datetime(2133, 5, 4, 23, 45), nan),
#    (datetime.datetime(2133, 5, 5, 0, 45), 0.3246336982005457),
#    (datetime.datetime(2133, 5, 5, 1, 45), nan),
#    (datetime.datetime(2133, 5, 5, 2, 45), nan),
#    (datetime.datetime(2133, 5, 5, 3, 45), nan),
#    (datetime.datetime(2133, 5, 5, 4, 45), nan),
#    (datetime.datetime(2133, 5, 5, 5, 45), nan),
#    (datetime.datetime(2133, 5, 5, 6, 45), nan),
#    (datetime.datetime(2133, 5, 5, 7, 45), nan),
#    (datetime.datetime(2133, 5, 5, 8, 45), nan),
#    (datetime.datetime(2133, 5, 5, 9, 45), nan),
#    (datetime.datetime(2133, 5, 5, 10, 45), nan),
#    (datetime.datetime(2133, 5, 5, 11, 45), nan),
#    (datetime.datetime(2133, 5, 5, 12, 45), nan),
#    (datetime.datetime(2133, 5, 5, 13, 45), nan),
#    (datetime.datetime(2133, 5, 5, 14, 45), nan),
#    (datetime.datetime(2133, 5, 5, 15, 45), nan),
#    (datetime.datetime(2133, 5, 5, 16, 45), nan),
#    (datetime.datetime(2133, 5, 5, 17, 45), nan),
#    (datetime.datetime(2133, 5, 5, 18, 45), nan),
#    (datetime.datetime(2133, 5, 5, 19, 45), nan),
#    (datetime.datetime(2133, 5, 5, 20, 45), nan),
#    (datetime.datetime(2133, 5, 5, 21, 45), nan),
#    (datetime.datetime(2133, 5, 5, 22, 45), nan),
#    (datetime.datetime(2133, 5, 5, 23, 45), nan),
#    (datetime.datetime(2133, 5, 6, 0, 45), nan),
#    (datetime.datetime(2133, 5, 6, 1, 45), 0.3905677705838045),
#    (datetime.datetime(2133, 5, 6, 2, 45), nan),
#    (datetime.datetime(2133, 5, 6, 3, 45), nan),
#    (datetime.datetime(2133, 5, 6, 4, 45), nan),
#    (datetime.datetime(2133, 5, 6, 5, 45), nan),
#    (datetime.datetime(2133, 5, 6, 6, 45), nan),
#    (datetime.datetime(2133, 5, 6, 7, 45), nan),
#    (datetime.datetime(2133, 5, 6, 8, 45), nan),
#    (datetime.datetime(2133, 5, 6, 9, 45), nan),
#    (datetime.datetime(2133, 5, 6, 10, 45), nan),
#    (datetime.datetime(2133, 5, 6, 11, 45), nan),
#    (datetime.datetime(2133, 5, 6, 12, 45), nan),
#    (datetime.datetime(2133, 5, 6, 13, 45), nan),
#    (datetime.datetime(2133, 5, 6, 14, 45), nan),
#    (datetime.datetime(2133, 5, 6, 15, 45), nan),
#    (datetime.datetime(2133, 5, 6, 16, 45), nan),
#    (datetime.datetime(2133, 5, 6, 17, 45), nan),
#    (datetime.datetime(2133, 5, 6, 18, 45), nan),
#    (datetime.datetime(2133, 5, 6, 19, 45), nan),
#    (datetime.datetime(2133, 5, 6, 20, 45), nan),
#    (datetime.datetime(2133, 5, 6, 21, 45), nan),
#    (datetime.datetime(2133, 5, 6, 22, 45), nan),
#    (datetime.datetime(2133, 5, 6, 23, 45), nan),
#    (datetime.datetime(2133, 5, 7, 0, 45), 0.22939559364694945),
#    (datetime.datetime(2133, 5, 7, 1, 45), nan),
#    (datetime.datetime(2133, 5, 7, 2, 45), nan),
#    (datetime.datetime(2133, 5, 7, 3, 45), nan),
#    (datetime.datetime(2133, 5, 7, 4, 45), 0.29166666200891617),
#    (datetime.datetime(2133, 5, 7, 5, 45), nan),
#    (datetime.datetime(2133, 5, 7, 6, 45), nan),
#    (datetime.datetime(2133, 5, 7, 7, 45), nan),
#    (datetime.datetime(2133, 5, 7, 8, 45), nan),
#    (datetime.datetime(2133, 5, 7, 9, 45), nan),
#    (datetime.datetime(2133, 5, 7, 10, 45), nan),
#    (datetime.datetime(2133, 5, 7, 11, 45), nan),
#    (datetime.datetime(2133, 5, 7, 12, 45), nan),
#    (datetime.datetime(2133, 5, 7, 13, 45), nan),
#    (datetime.datetime(2133, 5, 7, 14, 45), nan),
#    (datetime.datetime(2133, 5, 7, 15, 45), 0.2586996258172868),
#    (datetime.datetime(2133, 5, 7, 16, 45), nan),
#    (datetime.datetime(2133, 5, 7, 17, 45), nan),
#    (datetime.datetime(2133, 5, 7, 18, 45), nan),
#    (datetime.datetime(2133, 5, 7, 19, 45), nan),
#    (datetime.datetime(2133, 5, 7, 20, 45), nan),
#    (datetime.datetime(2133, 5, 7, 21, 45), nan),
#    (datetime.datetime(2133, 5, 7, 22, 45), nan),
#    (datetime.datetime(2133, 5, 7, 23, 45), nan),
#    (datetime.datetime(2133, 5, 8, 0, 45), nan),
#    (datetime.datetime(2133, 5, 8, 1, 45), 0.21840658158307294),
#    (datetime.datetime(2133, 5, 8, 2, 45), nan),
#    (datetime.datetime(2133, 5, 8, 3, 45), nan),
#    (datetime.datetime(2133, 5, 8, 4, 45), nan),
#    (datetime.datetime(2133, 5, 8, 5, 45), nan),
#    (datetime.datetime(2133, 5, 8, 6, 45), nan),
#    (datetime.datetime(2133, 5, 8, 7, 45), nan),
#    (datetime.datetime(2133, 5, 8, 8, 45), nan),
#    (datetime.datetime(2133, 5, 8, 9, 45), nan),
#    (datetime.datetime(2133, 5, 8, 10, 45), nan),
#    (datetime.datetime(2133, 5, 8, 11, 45), nan),
#    (datetime.datetime(2133, 5, 8, 12, 45), nan),
#    (datetime.datetime(2133, 5, 8, 13, 45), nan),
#    (datetime.datetime(2133, 5, 8, 14, 45), nan),
#    (datetime.datetime(2133, 5, 8, 15, 45), nan),
#    (datetime.datetime(2133, 5, 8, 16, 45), 0.0975274488804316),
#    (datetime.datetime(2133, 5, 8, 17, 45), 0.0975274488804316),
#    (datetime.datetime(2133, 5, 8, 18, 45), nan),
#    (datetime.datetime(2133, 5, 8, 19, 45), nan),
#    (datetime.datetime(2133, 5, 8, 20, 45), nan),
#    (datetime.datetime(2133, 5, 8, 21, 45), nan),
#    (datetime.datetime(2133, 5, 8, 22, 45), 0.20009156147661214),
#    (datetime.datetime(2133, 5, 8, 23, 45), nan),
#    (datetime.datetime(2133, 5, 9, 0, 45), nan),
#    (datetime.datetime(2133, 5, 9, 1, 45), 0.28800365798762406),
#    (datetime.datetime(2133, 5, 9, 2, 45), nan),
#    (datetime.datetime(2133, 5, 9, 3, 45), nan),
#    (datetime.datetime(2133, 5, 9, 4, 45), nan),
#    (datetime.datetime(2133, 5, 9, 5, 45), nan),
#    (datetime.datetime(2133, 5, 9, 6, 45), nan),
#    (datetime.datetime(2133, 5, 9, 7, 45), nan),
#    (datetime.datetime(2133, 5, 9, 8, 45), nan),
#    (datetime.datetime(2133, 5, 9, 9, 45), nan),
#    (datetime.datetime(2133, 5, 9, 10, 45), nan),
#    (datetime.datetime(2133, 5, 9, 11, 45), nan),
#    (datetime.datetime(2133, 5, 9, 12, 45), nan),
#    (datetime.datetime(2133, 5, 9, 13, 45), nan),
#    (datetime.datetime(2133, 5, 9, 14, 45), nan),
#    (datetime.datetime(2133, 5, 9, 15, 45), nan),
#    (datetime.datetime(2133, 5, 9, 16, 45), nan),
#    (datetime.datetime(2133, 5, 9, 17, 45), nan),
#    (datetime.datetime(2133, 5, 9, 18, 45), nan),
#    (datetime.datetime(2133, 5, 9, 19, 45), nan),
#    (datetime.datetime(2133, 5, 9, 20, 45), 0.24404760973211806),
#    (datetime.datetime(2133, 5, 9, 21, 45), nan),
#    (datetime.datetime(2133, 5, 9, 22, 45), nan),
#    (datetime.datetime(2133, 5, 9, 23, 45), nan),
#    (datetime.datetime(2133, 5, 10, 0, 45), nan),
#    (datetime.datetime(2133, 5, 10, 1, 45), nan),
#    (datetime.datetime(2133, 5, 10, 2, 45), nan),
#    (datetime.datetime(2133, 5, 10, 3, 45), nan),
#    (datetime.datetime(2133, 5, 10, 4, 45), 0.2770146459237476),
#    (datetime.datetime(2133, 5, 10, 5, 45), nan),
#    (datetime.datetime(2133, 5, 10, 6, 45), nan),
#    (datetime.datetime(2133, 5, 10, 7, 45), nan),
#    (datetime.datetime(2133, 5, 10, 8, 45), nan),
#    (datetime.datetime(2133, 5, 10, 9, 45), nan),
#    (datetime.datetime(2133, 5, 10, 10, 45), nan),
#    (datetime.datetime(2133, 5, 10, 11, 45), nan),
#    (datetime.datetime(2133, 5, 10, 12, 45), nan),
#    (datetime.datetime(2133, 5, 10, 13, 45), nan),
#    (datetime.datetime(2133, 5, 10, 14, 45), nan),
#    (datetime.datetime(2133, 5, 10, 15, 45), nan),
#    (datetime.datetime(2133, 5, 10, 16, 45), nan),
#    (datetime.datetime(2133, 5, 10, 17, 45), nan),
#    (datetime.datetime(2133, 5, 10, 18, 45), nan),
#    (datetime.datetime(2133, 5, 10, 19, 45), nan),
#    (datetime.datetime(2133, 5, 10, 20, 45), nan),
#    (datetime.datetime(2133, 5, 10, 21, 45), nan),
#    (datetime.datetime(2133, 5, 10, 22, 45), nan),
#    (datetime.datetime(2133, 5, 10, 23, 45), nan),
#    (datetime.datetime(2133, 5, 11, 0, 45), nan),
#    (datetime.datetime(2133, 5, 11, 1, 45), 0.19276555343402785),
#    (datetime.datetime(2133, 5, 11, 2, 45), nan),
#    (datetime.datetime(2133, 5, 11, 3, 45), nan),
#    (datetime.datetime(2133, 5, 11, 4, 45), nan),
#    (datetime.datetime(2133, 5, 11, 5, 45), nan),
#    (datetime.datetime(2133, 5, 11, 6, 45), nan),
#    (datetime.datetime(2133, 5, 11, 7, 45), nan),
#    (datetime.datetime(2133, 5, 11, 8, 45), nan),
#    (datetime.datetime(2133, 5, 11, 9, 45), nan),
#    (datetime.datetime(2133, 5, 11, 10, 45), nan),
#    (datetime.datetime(2133, 5, 11, 11, 45), nan),
#    (datetime.datetime(2133, 5, 11, 12, 45), nan),
#    (datetime.datetime(2133, 5, 11, 13, 45), nan),
#    (datetime.datetime(2133, 5, 11, 14, 45), nan),
#    (datetime.datetime(2133, 5, 11, 15, 45), nan),
#    (datetime.datetime(2133, 5, 11, 16, 45), nan),
#    (datetime.datetime(2133, 5, 11, 17, 45), nan),
#    (datetime.datetime(2133, 5, 11, 18, 45), nan),
#    (datetime.datetime(2133, 5, 11, 19, 45), nan),
#    (datetime.datetime(2133, 5, 11, 20, 45), nan),
#    (datetime.datetime(2133, 5, 11, 21, 45), nan),
#    (datetime.datetime(2133, 5, 11, 22, 45), nan),
#    (datetime.datetime(2133, 5, 11, 23, 45), nan),
#    (datetime.datetime(2133, 5, 12, 0, 45), nan),
#    (datetime.datetime(2133, 5, 12, 1, 45), 0.18543954539144356),
#    (datetime.datetime(2133, 5, 12, 2, 45), nan),
#    (datetime.datetime(2133, 5, 12, 3, 45), nan),
#    (datetime.datetime(2133, 5, 12, 4, 45), nan),
#    (datetime.datetime(2133, 5, 12, 5, 45), nan),
#    (datetime.datetime(2133, 5, 12, 6, 45), nan),
#    (datetime.datetime(2133, 5, 12, 7, 45), nan),
#    (datetime.datetime(2133, 5, 12, 8, 45), nan),
#    (datetime.datetime(2133, 5, 12, 9, 45), nan),
#    (datetime.datetime(2133, 5, 12, 10, 45), nan),
#    (datetime.datetime(2133, 5, 12, 11, 45), nan),
#    ...]}}

# %%
# Make 3D Tensor for input data
# input_tensor = list()

# for hadm_id in hadm_input_norm:
#   fs = hadm_input_norm[hadm_id]
#   for idx, (kk, vs) in enumerate(fs.items()):
#     vs = np.array(vs)
#     vv = vs[:,1]
#     if idx == 0:
#       input_vv = np.array(vv).reshape(-1, 1)
      
#     else:
#       vv = np.array(vv).reshape(-1, 1)
#       input_vv = np.concatenate([input_vv, vv], axis=1)

#   print(input_vv.shape)
#   input_tensor.append(input_vv)
# Out:
# (174, 13)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-71-09ef05bfc879> in <module>
#       6   for idx, (kk, vs) in enumerate(fs.items()):
#       7     vs = np.array(vs)
# ----> 8     vv = vs[:,1]
#       9     if idx == 0:
#      10       input_vv = np.array(vv).reshape(-1, 1)
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
input_tensor
